# %% [markdown]
# ### 1. Scouting deportivo
# ![gerard.jpg](attachment:gerard.jpg)
#
# Se ha lesionado Gerard Moreno. El entrenador del Villarreal necesita una lista de jugadores similares para sustituirle.
# Utilizando el dataset proporcionado:
#
# 1. Busca la posición de Gerard y filtra el dataset para obtener los jugadores de la misma demarcación (`team_position`)
# 2. Selecciona solo las variables numéricas y excluye las relacionadas con los porteros (goalkeeping_XXX y gk_XXX) y otras que consideres irrelevantes
# 3. Implementa un algoritmo k-means con el número de clusters adecuado
# 4. Obtén un fichero csv con los jugadores que entren en el mismo cluster que Gerard, y ordénalos de mayor a menor valor de mercado

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/players_20.csv')
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 3        188         87    Slovenia      Atlético Madrid       91         93
# 4        175         74     Belgium          Real Madrid       91         91
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 3   77500000    125000               GK          Right
# 4   90000000    470000           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# 1                         5          4            5       High/Low
# 2                         5          5            5    High/Medium
# 3                         3          3            1  Medium/Medium
# 4                         4          4            4    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  40                  30                     43
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
# 4                         27                        22                  11
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
# 4                    12                    6                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                    89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                     8  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
# 4  61+3  49+3  49+3  49+3  61+3

# %%
# Posición de Gerard Moreno
df.loc[df.short_name.str.contains('Gerard Moreno')].team_position
# Out:
# 367    ST
# Name: team_position, dtype: object

# %%
# Filtrar strickers (delanteros)
df2 = df.loc[df.team_position=="ST"]
df2
# Out:
#        sofifa_id                                         player_url  \
# 12        202126  https://sofifa.com/player/202126/harry-kane/20...
# 17        153079  https://sofifa.com/player/153079/sergio-aguero...
# 19        176580  https://sofifa.com/player/176580/luis-suarez/2...
# 20        188545  https://sofifa.com/player/188545/robert-lewand...
# 34        179813  https://sofifa.com/player/179813/edinson-cavan...
# ...          ...                                                ...
# 17060     251585  https://sofifa.com/player/251585/john-mary/20/...
# 17184     246998  https://sofifa.com/player/246998/yoyo-mahdy/20...
# 17296     247279  https://sofifa.com/player/247279/lyndon-dykes/...
# 17993     252401  https://sofifa.com/player/252401/eddie-brown/2...
# 18148     242011  https://sofifa.com/player/242011/dean-walsh/20...
#
#            short_name                          long_name  age         dob  \
# 12            H. Kane                         Harry Kane   25  1993-07-28
# 17          S. Agüero  Sergio Leonel Agüero del Castillo   31  1988-06-02
# 19          L. Suárez           Luis Alberto Suárez Díaz   32  1987-01-24
# 20     R. Lewandowski                 Robert Lewandowski   30  1988-08-21
# 34          E. Cavani       Edinson Roberto Cavani Gómez   32  1987-02-14
# ...               ...                                ...  ...         ...
# 17060         J. Mary                          John Mary   26  1993-03-09
# 17184        Y. Mahdy                         Yoyo Mahdy   21  1998-01-20
# 17296        L. Dykes                       Lyndon Dykes   23  1995-10-07
# 17993        E. Brown                        Eddie Brown   18  2000-11-27
# 18148        D. Walsh                         Dean Walsh   22  1997-04-28
#
#        height_cm  weight_kg          nationality                 club  \
# 12           188         89              England    Tottenham Hotspur
# 17           173         70            Argentina      Manchester City
# 19           182         86              Uruguay         FC Barcelona
# 20           184         80               Poland    FC Bayern München
# 34           185         77              Uruguay  Paris Saint-Germain
# ...          ...        ...                  ...                  ...
# 17060        185         87             Cameroon          Shenzhen FC
# 17184        178         73  Republic of Ireland              UCD AFC
# 17296        188         75            Australia        Livingston FC
# 17993        188         84              England     Bolton Wanderers
# 18148        175         75  Republic of Ireland         Waterford FC
#
#        overall  potential  value_eur  wage_eur player_positions  \
# 12          89         91   83000000    220000               ST
# 17          89         89   60000000    300000               ST
# 19          89         89   53000000    355000               ST
# 20          89         89   64500000    235000               ST
# 34          88         88   47000000    195000               ST
# ...        ...        ...        ...       ...              ...
# 17060       56         58     110000      3000               ST
# 17184       55         69     180000      1000               ST
# 17296       55         63     120000      1000               ST
# 17993       51         68      80000      1000               ST
# 18148       50         59      50000      1000               ST
#
#       preferred_foot  international_reputation  weak_foot  skill_moves  \
# 12             Right                         3          4            3
# 17             Right                         4          4            4
# 19             Right                         5          4            3
# 20             Right                         4          4            4
# 34             Right                         4          4            3
# ...              ...                       ...        ...          ...
# 17060          Right                         1          3            2
# 17184          Right                         1          2            3
# 17296          Right                         1          3            2
# 17993          Right                         1          2            2
# 18148          Right                         1          3            2
#
#            work_rate body_type real_face  release_clause_eur  \
# 12         High/High    Normal       Yes         159800000.0
# 17       High/Medium    Stocky       Yes         111000000.0
# 19       High/Medium    Normal       Yes         108700000.0
# 20       High/Medium    Normal       Yes         106400000.0
# 34         High/High      Lean       Yes          87000000.0
# ...              ...       ...       ...                 ...
# 17060       High/Low    Stocky        No            179000.0
# 17184  Medium/Medium    Normal        No            392000.0
# 17296  Medium/Medium    Normal        No            234000.0
# 17993    High/Medium      Lean        No            190000.0
# 18148       High/Low    Normal        No             88000.0
#
#                                              player_tags team_position  \
# 12        #Engine, #Distance Shooter, #Clinical Finisher            ST
# 17      #Dribbler, #Clinical Finisher, #Complete Forward            ST
# 19     #Distance Shooter, #Strength, #Clinical Finish...            ST
# 20                                    #Clinical Finisher            ST
# 34                                               #Engine            ST
# ...                                                  ...           ...
# 17060                                                NaN            ST
# 17184                                                NaN            ST
# 17296                                                NaN            ST
# 17993                                                NaN            ST
# 18148                                                NaN            ST
#
#        team_jersey_number loaned_from      joined  contract_valid_until  \
# 12                   10.0         NaN  2010-07-01                2024.0
# 17                   10.0         NaN  2011-07-28                2021.0
# 19                    9.0         NaN  2014-07-11                2021.0
# 20                    9.0         NaN  2014-07-01                2021.0
# 34                    9.0         NaN  2013-07-16                2020.0
# ...                   ...         ...         ...                   ...
# 17060                12.0         NaN  2019-07-02                2023.0
# 17184                 9.0         NaN  2017-01-01                2019.0
# 17296                 9.0         NaN  2019-01-30                2022.0
# 17993                33.0         NaN  2019-07-01                2020.0
# 18148                15.0         NaN  2017-01-01                2022.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 12                 ST                   9.0  70.0      91.0     79.0
# 17                 ST                   9.0  80.0      90.0     77.0
# 19                NaN                   NaN  73.0      89.0     80.0
# 20                 LS                   9.0  77.0      87.0     74.0
# 34                NaN                   NaN  75.0      86.0     72.0
# ...               ...                   ...   ...       ...      ...
# 17060             NaN                   NaN  61.0      55.0     38.0
# 17184             NaN                   NaN  67.0      53.0     44.0
# 17296             NaN                   NaN  55.0      54.0     36.0
# 17993             NaN                   NaN  65.0      46.0     37.0
# 18148             NaN                   NaN  51.0      51.0     38.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 12          81.0       47.0    83.0        NaN          NaN         NaN
# 17          88.0       33.0    74.0        NaN          NaN         NaN
# 19          84.0       51.0    84.0        NaN          NaN         NaN
# 20          85.0       41.0    82.0        NaN          NaN         NaN
# 34          79.0       55.0    83.0        NaN          NaN         NaN
# ...          ...        ...     ...        ...          ...         ...
# 17060       52.0       20.0    61.0        NaN          NaN         NaN
# 17184       57.0       19.0    55.0        NaN          NaN         NaN
# 17296       50.0       27.0    60.0        NaN          NaN         NaN
# 17993       54.0       18.0    50.0        NaN          NaN         NaN
# 18148       46.0       21.0    45.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 12             NaN       NaN             NaN
# 17             NaN       NaN             NaN
# 19             NaN       NaN             NaN
# 20             NaN       NaN             NaN
# 34             NaN       NaN             NaN
# ...            ...       ...             ...
# 17060          NaN       NaN             NaN
# 17184          NaN       NaN             NaN
# 17296          NaN       NaN             NaN
# 17993          NaN       NaN             NaN
# 18148          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 12     Injury Free, Avoids Using Weaker Foot, Argues ...                  75
# 17           Avoids Using Weaker Foot, Outside Foot Shot                  70
# 19                   Diver, Speed Dribbler (CPU AI Only)                  78
# 20     Diver, Beat Offside Trap, Speed Dribbler (CPU ...                  62
# 34                             Long Passer (CPU AI Only)                  70
# ...                                                  ...                 ...
# 17060                                                NaN                  29
# 17184                                                NaN                  41
# 17296                                                NaN                  28
# 17993                                                NaN                  32
# 18148                                                NaN                  28
#
#        attacking_finishing  attacking_heading_accuracy  \
# 12                      94                          86
# 17                      93                          78
# 19                      91                          83
# 20                      88                          85
# 34                      88                          89
# ...                    ...                         ...
# 17060                   57                          64
# 17184                   54                          51
# 17296                   56                          75
# 17993                   48                          55
# 18148                   56                          50
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 12                          81                 85               80
# 17                          83                 85               88
# 19                          82                 90               85
# 20                          82                 88               85
# 34                          78                 90               79
# ...                        ...                ...              ...
# 17060                       42                 42               53
# 17184                       47                 53               58
# 17296                       44                 53               49
# 17993                       39                 39               55
# 18148                       44                 37               44
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 12              78                 68                  83                  84
# 17              83                 73                  64                  89
# 19              86                 82                  72                  84
# 20              77                 85                  65                  88
# 34              77                 76                  52                  81
# ...            ...                ...                 ...                 ...
# 17060           36                 28                  30                  49
# 17184           42                 33                  35                  55
# 17296           28                 22                  27                  49
# 17993           34                 28                  31                  52
# 18148           38                 29                  25                  43
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 12                        68                     72                71
# 17                        82                     78                84
# 19                        76                     70                79
# 20                        77                     77                78
# 34                        74                     76                74
# ...                      ...                    ...               ...
# 17060                     64                     58                59
# 17184                     65                     69                59
# 17296                     54                     55                54
# 17993                     64                     65                56
# 18148                     56                     46                53
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 12                     91                73                90             79
# 17                     92                91                89             81
# 19                     92                79                88             69
# 20                     90                82                87             84
# 34                     91                59                88             88
# ...                   ...               ...               ...            ...
# 17060                  49                51                54             65
# 17184                  47                59                52             59
# 17296                  46                68                51             62
# 17993                  50                55                44             60
# 18148                  52                72                45             61
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 12                87              84                86                    78
# 17                79              74                84                    65
# 19                82              86                86                    87
# 20                78              84                84                    81
# 34                91              79                79                    84
# ...              ...             ...               ...                   ...
# 17060             52              77                53                    31
# 17184             53              59                50                    48
# 17296             64              62                52                    50
# 17993             62              50                41                    32
# 18148             37              53                47                    32
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 12                          35                     93                81
# 17                          24                     93                83
# 19                          41                     92                82
# 20                          39                     91                77
# 34                          54                     93                77
# ...                        ...                    ...               ...
# 17060                       13                     54                47
# 17184                       19                     55                50
# 17296                       18                     47                43
# 17993                       13                     48                44
# 18148                       10                     50                47
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 12                      90                   91                 56
# 17                      83                   90                 30
# 19                      83                   85                 57
# 20                      86                   86                 34
# 34                      85                   80                 57
# ...                    ...                  ...                ...
# 17060                   56                   46                 15
# 17184                   58                   49                 14
# 17296                   57                   48                 20
# 17993                   58                   43                 11
# 18148                   62                   47                 27
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 12                            36                        38
# 17                            29                        24
# 19                            45                        38
# 20                            42                        19
# 34                            48                        39
# ...                          ...                       ...
# 17060                         17                        12
# 17184                         14                        12
# 17296                         24                        23
# 17993                         19                        11
# 18148                         15                        17
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 12                      8                    10                   11
# 17                     13                    15                    6
# 19                     27                    25                   31
# 20                     15                     6                   12
# 34                     12                     5                   13
# ...                   ...                   ...                  ...
# 17060                   6                    12                    5
# 17184                  11                    10                   10
# 17296                  10                     5                    9
# 17993                  14                     5                    9
# 18148                   7                    14                    6
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 12                          14                    11  86+3  86+3  86+3  82+3
# 17                          11                    14  87+3  87+3  87+3  85+3
# 19                          33                    37  86+5  86+5  86+5  83+5
# 20                           8                    10  86+3  86+3  86+3  82+3
# 34                          13                    10  85+3  85+3  85+3  80+3
# ...                        ...                   ...   ...   ...   ...   ...
# 17060                       13                     7  55+2  55+2  55+2  50+2
# 17184                       10                    12  54+2  54+2  54+2  54+2
# 17296                       11                    10  53+2  53+2  53+2  47+2
# 17993                        7                     6  50+2  50+2  50+2  49+2
# 18148                        8                     9  49+2  49+2  49+2  46+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 12     84+3  84+3  84+3  82+3  83+3  83+3  83+3  82+3  79+3  79+3  79+3  82+3
# 17     87+3  87+3  87+3  85+3  85+3  85+3  85+3  83+3  77+3  77+3  77+3  83+3
# 19     85+5  85+5  85+5  83+5  84+5  84+5  84+5  82+5  79+5  79+5  79+5  82+5
# 20     85+3  85+3  85+3  82+3  83+3  83+3  83+3  80+3  77+3  77+3  77+3  80+3
# 34     83+3  83+3  83+3  80+3  80+3  80+3  80+3  79+3  75+3  75+3  75+3  79+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 17060  52+2  52+2  52+2  50+2  49+2  49+2  49+2  48+2  42+2  42+2  42+2  48+2
# 17184  54+2  54+2  54+2  54+2  52+2  52+2  52+2  52+2  45+2  45+2  45+2  52+2
# 17296  49+2  49+2  49+2  47+2  47+2  47+2  47+2  46+2  42+2  42+2  42+2  46+2
# 17993  49+2  49+2  49+2  49+2  48+2  48+2  48+2  48+2  42+2  42+2  42+2  48+2
# 18148  47+2  47+2  47+2  46+2  46+2  46+2  46+2  43+2  39+2  39+2  39+2  43+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 12     65+3  66+3  66+3  66+3  65+3  62+3  60+3  60+3  60+3  62+3
# 17     60+3  58+3  58+3  58+3  60+3  56+3  50+3  50+3  50+3  56+3
# 19     67+5  67+5  67+5  67+5  67+5  64+5  63+5  63+5  63+5  64+5
# 20     61+3  62+3  62+3  62+3  61+3  58+3  57+3  57+3  57+3  58+3
# 34     68+3  66+3  66+3  66+3  68+3  66+3  65+3  65+3  65+3  66+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 17060  34+2  32+2  32+2  32+2  34+2  33+2  33+2  33+2  33+2  33+2
# 17184  37+2  35+2  35+2  35+2  37+2  35+2  32+2  32+2  32+2  35+2
# 17296  37+2  35+2  35+2  35+2  37+2  37+2  38+2  38+2  38+2  37+2
# 17993  35+2  31+2  31+2  31+2  35+2  34+2  29+2  29+2  29+2  34+2
# 18148  31+2  30+2  30+2  30+2  31+2  31+2  31+2  31+2  31+2  31+2
#
# [458 rows x 104 columns]

# %%
df.shape, df2.shape
# Out:
# ((18278, 104), (458, 104))

# %%
# Filtrar columnas numéricas y de no-porteros
from pandas.api.types import is_numeric_dtype

sel = ['short_name']

for col in df2.columns:
    if is_numeric_dtype(df2[col]) and not col.startswith('goalk') and not col.startswith('gk'):
        sel.append(col)

sel.remove('team_jersey_number')
sel.remove('sofifa_id')
sel.remove('nation_jersey_number')
sel.remove('contract_valid_until')

# %%
df3 = df2[sel]
df3
# Out:
#            short_name  age  height_cm  weight_kg  overall  potential  \
# 12            H. Kane   25        188         89       89         91
# 17          S. Agüero   31        173         70       89         89
# 19          L. Suárez   32        182         86       89         89
# 20     R. Lewandowski   30        184         80       89         89
# 34          E. Cavani   32        185         77       88         88
# ...               ...  ...        ...        ...      ...        ...
# 17060         J. Mary   26        185         87       56         58
# 17184        Y. Mahdy   21        178         73       55         69
# 17296        L. Dykes   23        188         75       55         63
# 17993        E. Brown   18        188         84       51         68
# 18148        D. Walsh   22        175         75       50         59
#
#        value_eur  wage_eur  international_reputation  weak_foot  skill_moves  \
# 12      83000000    220000                         3          4            3
# 17      60000000    300000                         4          4            4
# 19      53000000    355000                         5          4            3
# 20      64500000    235000                         4          4            4
# 34      47000000    195000                         4          4            3
# ...          ...       ...                       ...        ...          ...
# 17060     110000      3000                         1          3            2
# 17184     180000      1000                         1          2            3
# 17296     120000      1000                         1          3            2
# 17993      80000      1000                         1          2            2
# 18148      50000      1000                         1          3            2
#
#        release_clause_eur  pace  shooting  passing  dribbling  defending  \
# 12            159800000.0  70.0      91.0     79.0       81.0       47.0
# 17            111000000.0  80.0      90.0     77.0       88.0       33.0
# 19            108700000.0  73.0      89.0     80.0       84.0       51.0
# 20            106400000.0  77.0      87.0     74.0       85.0       41.0
# 34             87000000.0  75.0      86.0     72.0       79.0       55.0
# ...                   ...   ...       ...      ...        ...        ...
# 17060            179000.0  61.0      55.0     38.0       52.0       20.0
# 17184            392000.0  67.0      53.0     44.0       57.0       19.0
# 17296            234000.0  55.0      54.0     36.0       50.0       27.0
# 17993            190000.0  65.0      46.0     37.0       54.0       18.0
# 18148             88000.0  51.0      51.0     38.0       46.0       21.0
#
#        physic  attacking_crossing  attacking_finishing  \
# 12       83.0                  75                   94
# 17       74.0                  70                   93
# 19       84.0                  78                   91
# 20       82.0                  62                   88
# 34       83.0                  70                   88
# ...       ...                 ...                  ...
# 17060    61.0                  29                   57
# 17184    55.0                  41                   54
# 17296    60.0                  28                   56
# 17993    50.0                  32                   48
# 18148    45.0                  28                   56
#
#        attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 12                             86                       81                 85
# 17                             78                       83                 85
# 19                             83                       82                 90
# 20                             85                       82                 88
# 34                             89                       78                 90
# ...                           ...                      ...                ...
# 17060                          64                       42                 42
# 17184                          51                       47                 53
# 17296                          75                       44                 53
# 17993                          55                       39                 39
# 18148                          50                       44                 37
#
#        skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 12                  80           78                 68                  83
# 17                  88           83                 73                  64
# 19                  85           86                 82                  72
# 20                  85           77                 85                  65
# 34                  79           77                 76                  52
# ...                ...          ...                ...                 ...
# 17060               53           36                 28                  30
# 17184               58           42                 33                  35
# 17296               49           28                 22                  27
# 17993               55           34                 28                  31
# 18148               44           38                 29                  25
#
#        skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 12                     84                     68                     72
# 17                     89                     82                     78
# 19                     84                     76                     70
# 20                     88                     77                     77
# 34                     81                     74                     76
# ...                   ...                    ...                    ...
# 17060                  49                     64                     58
# 17184                  55                     65                     69
# 17296                  49                     54                     55
# 17993                  52                     64                     65
# 18148                  43                     56                     46
#
#        movement_agility  movement_reactions  movement_balance  \
# 12                   71                  91                73
# 17                   84                  92                91
# 19                   79                  92                79
# 20                   78                  90                82
# 34                   74                  91                59
# ...                 ...                 ...               ...
# 17060                59                  49                51
# 17184                59                  47                59
# 17296                54                  46                68
# 17993                56                  50                55
# 18148                53                  52                72
#
#        power_shot_power  power_jumping  power_stamina  power_strength  \
# 12                   90             79             87              84
# 17                   89             81             79              74
# 19                   88             69             82              86
# 20                   87             84             78              84
# 34                   88             88             91              79
# ...                 ...            ...            ...             ...
# 17060                54             65             52              77
# 17184                52             59             53              59
# 17296                51             62             64              62
# 17993                44             60             62              50
# 18148                45             61             37              53
#
#        power_long_shots  mentality_aggression  mentality_interceptions  \
# 12                   86                    78                       35
# 17                   84                    65                       24
# 19                   86                    87                       41
# 20                   84                    81                       39
# 34                   79                    84                       54
# ...                 ...                   ...                      ...
# 17060                53                    31                       13
# 17184                50                    48                       19
# 17296                52                    50                       18
# 17993                41                    32                       13
# 18148                47                    32                       10
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# 12                        93                81                   90
# 17                        93                83                   83
# 19                        92                82                   83
# 20                        91                77                   86
# 34                        93                77                   85
# ...                      ...               ...                  ...
# 17060                     54                47                   56
# 17184                     55                50                   58
# 17296                     47                43                   57
# 17993                     48                44                   58
# 18148                     50                47                   62
#
#        mentality_composure  defending_marking  defending_standing_tackle  \
# 12                      91                 56                         36
# 17                      90                 30                         29
# 19                      85                 57                         45
# 20                      86                 34                         42
# 34                      80                 57                         48
# ...                    ...                ...                        ...
# 17060                   46                 15                         17
# 17184                   49                 14                         14
# 17296                   48                 20                         24
# 17993                   43                 11                         19
# 18148                   47                 27                         15
#
#        defending_sliding_tackle
# 12                           38
# 17                           24
# 19                           38
# 20                           19
# 34                           39
# ...                         ...
# 17060                        12
# 17184                        12
# 17296                        23
# 17993                        11
# 18148                        17
#
# [458 rows x 47 columns]

# %%
null_columns = df3.columns[df3.isnull().any()]
df3[null_columns].isnull().sum()
# Out:
# release_clause_eur    37
# dtype: int64

# %%
df3 = df3.fillna(df3.release_clause_eur.median())

# %%
null_columns = df3.columns[df3.isnull().any()]
df3[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df4 = df3.drop(['short_name'],axis=1)
scaler.fit(df4)
X_scaled = scaler.transform(df4)

# %%
from sklearn.cluster import KMeans
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X_scaled) for k in range(2,10)]
inertias = [model.inertia_ for model in kmeans_per_k]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(8, 3.5))
plt.plot(range(2, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)

plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_scores = [silhouette_score(X_scaled, model.labels_)
                     for model in kmeans_per_k]


#[model.labels_ for model in kmeans_per_k]

# %%
silhouette_scores
# Out:
# [0.22207771772255458,
#  0.14064187582520257,
#  0.13139171751199732,
#  0.11955059828726286,
#  0.11016249896495042,
#  0.1078141026536958,
#  0.09542071186570211,
#  0.09818097135451996]

# %%
plt.figure(figsize=(8, 3))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)

plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X_scaled)
labels = kmeans.predict(X_scaled)
centroid = kmeans.cluster_centers_

pd.DataFrame(centroid,columns=df4.columns)
# Out:
#         age  height_cm  weight_kg   overall  potential  value_eur  wage_eur  \
# 0 -0.195564   0.065722   0.000370 -0.488454  -0.387214  -0.362031 -0.304234
# 1  0.426438  -0.143311  -0.000806  1.065102   0.844341   0.789428  0.663400
#
#    international_reputation  weak_foot  skill_moves  release_clause_eur  \
# 0                 -0.323663  -0.204961    -0.338789           -0.354290
# 1                  0.705764   0.446928     0.738748            0.772549
#
#        pace  shooting   passing  dribbling  defending    physic  \
# 0 -0.077066 -0.467316 -0.481544  -0.441148  -0.326965 -0.176844
# 1  0.168048  1.019008  1.050033   0.961947   0.712966  0.385619
#
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0           -0.359978            -0.426113                   -0.280494
# 1            0.784952             0.929163                    0.611632
#
#    attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 0                -0.457380          -0.402721        -0.428318    -0.385330
# 1                 0.997342           0.878155         0.933971     0.840233
#
#    skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0          -0.317146           -0.384969           -0.462802
# 1           0.691555            0.839446            1.009165
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 0              -0.088308              -0.062969         -0.132211
# 1               0.192560               0.137308          0.288294
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0           -0.460667         -0.095294         -0.405737      -0.148312
# 1            1.004510          0.207794          0.884733       0.323402
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0      -0.135779       -0.056229         -0.436676             -0.205737
# 1       0.296073        0.122609          0.952197              0.448620
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                -0.297069              -0.435033         -0.445872
# 1                 0.647776               0.948613          0.972249
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0            -0.342212            -0.435491          -0.227025
# 1             0.746213             0.949613           0.495040
#
#    defending_standing_tackle  defending_sliding_tackle
# 0                  -0.247407                 -0.185077
# 1                   0.539484                  0.403571

# %%
df3['cluster'] = labels
df3.groupby('cluster').mean()
# Out:
#                age   height_cm  weight_kg    overall  potential     value_eur  \
# cluster
# 0        26.563694  183.984076  78.834395  67.455414  70.722930  1.637134e+06
# 1        29.250000  182.756944  78.826389  76.826389  77.972222  1.164722e+07
#
#              wage_eur  international_reputation  weak_foot  skill_moves  \
# cluster
# 0         6162.420382                  1.035032   3.117834     2.563694
# 1        38888.888889                  1.652778   3.527778     3.180556
#
#          release_clause_eur       pace   shooting    passing  dribbling  \
# cluster
# 0              2.877271e+06  67.955414  66.101911  52.277070  63.923567
# 1              2.121339e+07  70.840278  76.194444  65.666667  73.298611
#
#          defending     physic  attacking_crossing  attacking_finishing  \
# cluster
# 0        30.060510  68.968153           45.974522            68.251592
# 1        38.430556  73.145833           60.444444            77.791667
#
#          attacking_heading_accuracy  attacking_short_passing  \
# cluster
# 0                         66.398089                58.792994
# 1                         74.222222                70.847222
#
#          attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# cluster
# 0                59.958599        63.156051    51.541401          44.958599
# 1                72.701389        73.347222    66.277778          59.229167
#
#          skill_long_passing  skill_ball_control  movement_acceleration  \
# cluster
# 0                 44.219745           65.273885              66.678344
# 1                 58.250000           75.354167              70.215278
#
#          movement_sprint_speed  movement_agility  movement_reactions  \
# cluster
# 0                    68.929936         65.101911           63.378981
# 1                    71.291667         69.798611           75.465278
#
#          movement_balance  power_shot_power  power_jumping  power_stamina  \
# cluster
# 0               61.636943         68.710191      68.595541      66.694268
# 1               65.388889         78.368056      74.000000      71.090278
#
#          power_strength  power_long_shots  mentality_aggression  \
# cluster
# 0             75.156051         60.095541             56.273885
# 1             76.875000         71.333333             66.055556
#
#          mentality_interceptions  mentality_positioning  mentality_vision  \
# cluster
# 0                      25.159236              67.503185         55.127389
# 1                      35.430556              78.680556         68.625000
#
#          mentality_penalties  mentality_composure  defending_marking  \
# cluster
# 0                  64.773885            62.015924          28.633758
# 1                  73.201389            75.013889          36.729167
#
#          defending_standing_tackle  defending_sliding_tackle
# cluster
# 0                        25.070064                 22.350318
# 1                        33.645833                 27.868056

# %%
clusterGerard = df3.loc[df3.short_name=='Gerard Moreno'].cluster.values[0]
clusterGerard
# Out:
# 1

# %%
df_final = df3.loc[(df3.cluster==clusterGerard) & (df.short_name!="Gerard Moreno")][['short_name','value_eur']].sort_values('value_eur',ascending=False)
df_final.to_csv('Delanteros_substitutos.csv',index=False)
df_final
# Out:
#           short_name  value_eur
# 12           H. Kane   83000000
# 20    R. Lewandowski   64500000
# 17         S. Agüero   60000000
# 19         L. Suárez   53000000
# 34         E. Cavani   47000000
# ...              ...        ...
# 2969    Rubén Castro    1400000
# 6516       M. Urruti    1100000
# 4429        S. Silva     850000
# 5240            Nino     525000
# 5249  D. Moscardelli     525000
#
# [143 rows x 2 columns]

# %% [markdown]
# ## 2. Segmentación de clientes
# ![The-Key-to-Successful-Segmentations.jpg](attachment:The-Key-to-Successful-Segmentations.jpg)

# %% [markdown]
# El siguiente dataset contiene información acerca del gasto de clientes en diferentes productos (frescos, leche, comestibles, congelados, detergentes y delicatessen). Se quieren diseñar diversas campañas publicitarias en función de los grupos homogéneos que se encuentren. ¡Encuéntralos!
#
# * Utiliza k-means y cluster jerárquico.
#
# * ¿Cuál es la proporción de clientes en cada cluster?
#
# * Utiliza PCA con dos componentes para visualizar los clusters en un gráfico de 2 dimensiones e interpreta los resultados

# %%
data = pd.read_csv('data/customers.csv')
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
from sklearn.preprocessing import normalize
data_scaled = normalize(data.drop(columns=['Channel','Region']))
data_scaled = pd.DataFrame(data_scaled,columns=data.drop(columns=['Channel','Region']).columns)
data_scaled
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# 0    0.708333  0.539874  0.422741  0.011965          0.149505    0.074809
# 1    0.442198  0.614704  0.599540  0.110409          0.206342    0.111286
# 2    0.396552  0.549792  0.479632  0.150119          0.219467    0.489619
# 3    0.856837  0.077254  0.272650  0.413659          0.032749    0.115494
# 4    0.895416  0.214203  0.284997  0.155010          0.070358    0.205294
# ..        ...       ...       ...       ...               ...         ...
# 435  0.776890  0.315197  0.419191  0.343549          0.004760    0.057646
# 436  0.990872  0.036146  0.019298  0.113919          0.002349    0.059258
# 437  0.364462  0.388465  0.758545  0.010961          0.372237    0.046827
# 438  0.937737  0.180530  0.203404  0.094594          0.015310    0.193653
# 439  0.672296  0.409601  0.605477  0.015680          0.115065    0.012544
#
# [440 rows x 6 columns]

# %%
# Kmeans
from sklearn.cluster import KMeans
kmeans_per_k = [KMeans(n_clusters=k, random_state = 42).fit(data_scaled) for k in range(2, 10)]
silhouette_scores = [silhouette_score(data_scaled, model.labels_)
                     for model in kmeans_per_k]

# %%
plt.figure(figsize=(8, 3))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)

plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data_scaled)
labels = kmeans.predict(data_scaled)

# %%
data['cluster'] = labels
data
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen  cluster
# 0          1338        0
# 1          1776        1
# 2          7844        1
# 3          1788        0
# 4          5185        0
# ..          ...      ...
# 435        2204        0
# 436        2346        0
# 437        1867        1
# 438        2125        0
# 439          52        1
#
# [440 rows x 9 columns]

# %%
data.groupby('cluster').mean()
# Out:
#           Channel    Region         Fresh         Milk       Grocery  \
# cluster
# 0        1.128000  2.536000  17446.696000  3119.504000   3929.972000
# 1        1.578947  2.552632   4833.984211  9318.321053  13242.468421
#
#               Frozen  Detergents_Paper   Delicassen
# cluster
# 0        3925.072000        839.472000  1301.976000
# 1        1949.378947       5568.363158  1818.152632

# %%
data.cluster.value_counts(normalize=True)
# Out:
# 0    0.568182
# 1    0.431818
# Name: cluster, dtype: float64

# %%
# Jerárquico
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
reduced = pd.DataFrame(pca.fit_transform(data_scaled))

# %%
data_scaled
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# 0    0.708333  0.539874  0.422741  0.011965          0.149505    0.074809
# 1    0.442198  0.614704  0.599540  0.110409          0.206342    0.111286
# 2    0.396552  0.549792  0.479632  0.150119          0.219467    0.489619
# 3    0.856837  0.077254  0.272650  0.413659          0.032749    0.115494
# 4    0.895416  0.214203  0.284997  0.155010          0.070358    0.205294
# ..        ...       ...       ...       ...               ...         ...
# 435  0.776890  0.315197  0.419191  0.343549          0.004760    0.057646
# 436  0.990872  0.036146  0.019298  0.113919          0.002349    0.059258
# 437  0.364462  0.388465  0.758545  0.010961          0.372237    0.046827
# 438  0.937737  0.180530  0.203404  0.094594          0.015310    0.193653
# 439  0.672296  0.409601  0.605477  0.015680          0.115065    0.012544
#
# [440 rows x 6 columns]

# %%
reduced
# Out:
#             0         1
# 0    0.034037 -0.180421
# 1    0.351057 -0.046644
# 2    0.305375  0.055551
# 3   -0.383677  0.161789
# 4   -0.318591 -0.076970
# ..        ...       ...
# 435 -0.166266  0.106042
# 436 -0.607490 -0.097158
# 437  0.464837 -0.191884
# 438 -0.412001 -0.120676
# 439  0.102969 -0.212446
#
# [440 rows x 2 columns]

# %%
km = KMeans(n_clusters=2,random_state=42).fit(data_scaled)

# %%
reduced['cluster']=km.labels_
reduced
# Out:
#             0         1  cluster
# 0    0.034037 -0.180421        1
# 1    0.351057 -0.046644        0
# 2    0.305375  0.055551        0
# 3   -0.383677  0.161789        1
# 4   -0.318591 -0.076970        1
# ..        ...       ...      ...
# 435 -0.166266  0.106042        1
# 436 -0.607490 -0.097158        1
# 437  0.464837 -0.191884        0
# 438 -0.412001 -0.120676        1
# 439  0.102969 -0.212446        0
#
# [440 rows x 3 columns]

# %%
data2 = data.drop(columns=['Channel','Region','cluster'])
pd.DataFrame(
data = pca.components_,
    columns=data2.columns,
    index = ['PC1','PC2']
)
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# PC1 -0.720606  0.344109  0.537571 -0.106800          0.247658    0.024347
# PC2 -0.325226  0.057227 -0.220449  0.898543         -0.167915    0.082343

# %%
plt.scatter(reduced[0],reduced[1],c=reduced['cluster'])
