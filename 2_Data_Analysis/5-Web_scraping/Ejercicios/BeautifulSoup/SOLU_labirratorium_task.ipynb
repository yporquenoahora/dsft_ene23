# %% [markdown]
# ###  Pasos a seguir en el proceso de 'scraping':
#
# 1. Encuentra la URL que quieres 'escrapear'.
# 2. Inspecciona la página (código fuente).
# 3. Localiza los datos que necesitas obtener.
# 4. Desarrolla tu código en Python.
#     1. Crea tu sopa
#     2. Busca los elementos que cotienen los datos y extráelos
# 5. Ejecuta tu código y obten los datos.
# 6. Alamacena los datos en el formato requerido.

# %%
# Importamos librerías
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import html
import numpy as np

# %% [markdown]
# ## Caso 1: Scraping de un catálogo: Labirratorium

# %%
URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page='

# %% [markdown]
# Queremos obtener un dataFrame con todas las cervezas del catálogo y sus características descritas. Analizamos la página para ver qué tenemos que hacer para conseguirlo

# %%
# La web tiene 80 páginas con 12 cervezas listadas en cada página.

# %% [markdown]
# Hacemos la consulta (request) y creamos la SOPA inicial:

# %%
r = requests.get(URL)
soup = bs(r.text, 'lxml')

# %%
# Guardamos lista de cervezas
cervezas_grid = soup.find_all(class_='product-image')
cervezas_grid[0]
# Out:
# <div class="product-image">
# <!-- @file modules\appagebuilder\views\templates\front\products\file_tpl -->
# <ul class="product-flags">
# </ul>
# <a class="thumbnail product-thumbnail" href="https://www.labirratorium.com/es/inicio/831-arriaca-boris-brew-vikingathor-.html">
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.labirratorium.com/27941-large_default/arriaca-boris-brew-vikingathor-.jpg" src="https://www.labirratorium.com/27941-home_default/arriaca-boris-brew-vikingathor-.jpg"/>
# <span class="product-additional" data-idproduct="831"></span>
# </a>
# </div>

# %%
# necesitamos acceder a cada una de las cervezas del grid:
lista_URLs = []
for cerveza in cervezas_grid:
    URL_cerveza = cerveza.find('a')['href']
    lista_URLs.append(URL_cerveza)

lista_URLs
# Out:
# ['https://www.labirratorium.com/es/inicio/831-arriaca-boris-brew-vikingathor-.html',
#  'https://www.labirratorium.com/es/cerveza-lambic/284-boon-kriek-2013.html',
#  'https://www.labirratorium.com/es/cervezas-alemanas/225-stortebeker-schwarz-bier.html',
#  'https://www.labirratorium.com/es/cervezas-alemanas/184-augustiner-lagerbier-hell.html',
#  'https://www.labirratorium.com/es/inicio/183-schneider-eisbock.html',
#  'https://www.labirratorium.com/es/inicio/181-schlenkerla-rauchbier-weizen.html',
#  'https://www.labirratorium.com/es/inicio/173-samuel-adams-boston-lager.html',
#  'https://www.labirratorium.com/es/inicio/82-westmalle-dubbel.html',
#  'https://www.labirratorium.com/es/inicio/75-duchesse-de-bourgogne.html',
#  'https://www.labirratorium.com/es/inicio/61-tripel-karmeliet33.html',
#  'https://www.labirratorium.com/es/inicio/21-weihenstephaner-vitus.html',
#  'https://www.labirratorium.com/es/cervezas-americanas-estadounidenses/19-anchor-porter.html']

# %%
# Hacemos un nuevo request para la primera cerveza: 
r = requests.get(lista_URLs[0])

# Creamos una sopa específica con la info de cada cerveza
soup_cerveza = bs(r.text, 'lxml')

# %%
# Nombre
name = soup_cerveza.find(class_='h1 product-detail-name')
name
# Out:
# <h1 class="h1 product-detail-name" itemprop="name">SanFrutos Vikingathor Boris Brew</h1>

# %%
# Precio
price = float(soup_cerveza.find(class_='current-price').find('span')['content'])
price
# Out:
# 3.35

# %%
# Descripcion corta
descr_short = soup_cerveza.find(class_='description-short').find('p').text
descr_short
# Out:
# 'Indian Dunkel'

# %%
# Descripción larga
descr_full_list = []

descr_full_p = soup_cerveza.find(class_='product-description').find_all()
for sentence in descr_full_p:
    descr_full_list.append(sentence.text)

descr_full = '\n'.join(descr_full_list)

print(descr_full)
# Out:
# Cerveza de 8.2% ABV intensa, oscura y muy lupulada. Con aroma intenso a maltas tostadas, caramelo, fruta madura, resina e hierbas aromáticas. Delicioso armargor, dulzor equilibrado y sensación de calidez. Refrescante y lupulada.
# Una receta de Boris de Mesones.
# Vikingathor ya ha sido galardonada con anterioridad con las Medallas de Plata cosechadas en el European Beer Star de 2011 y 2012 y la Medalla de Plata en el Asia Beer Cup 2013.
# Medallas de Plata
# European Beer Star
# Medalla de Plata
# Asia Beer Cup

# %%
# Imagen
image = soup_cerveza.find(class_='js-qv-product-cover img-fluid')['src']
image
# Out:
# 'https://www.labirratorium.com/27941-large_default/arriaca-boris-brew-vikingathor-.jpg'

# %%
 # Brand
 brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
 brand
# Out:
# 'Cerveza Sanfrutos'

# %%
# Código de barras
try:
    barcode = soup_cerveza.find(class_='product-reference').find('span').text
except:
    barcode = None
print(barcode)
# Out:
# 831

# %%
# Features
features_dict = {}

try:
    features_dt = soup_cerveza.find_all('dt')
    features_dd = soup_cerveza.find_all('dd')
    for feature, value in zip(features_dt, features_dd):
        features_dict[feature.text] = value.text
except:
    features_dict = {}

features_dict
# Out:
# {'Estilo': 'DUNKEL',
#  'Origen': 'Segovia',
#  '% Alc.': 'ALTO (6-9%)',
#  '% Alc. Exacto': '8.2',
#  'Volumen (cl)': '33 Cl',
#  'Tipo Fermentación': 'Lager (Baja Fermentación)',
#  'IBU': '50-75 Amargor alto',
#  'IBU Exacto': '75',
#  'Color': 'Marrón',
#  'Envase': 'Botella'}

# %%
# Creamos un Id único que os permita diferenciar cada entrada en la BBDD
counter = 1
id_cerv = 'lbt_' + str(counter)

id_cerv
# Out:
# 'lbt_1'

# %% [markdown]
# Ya tenemos todos los datos que queremos de la cerveza: Agrupamos todo en una lista:

# %%
# Agregamos a una lista
lista_cervezas = []

lista_cervezas.append([
    ("id", id_cerv),
    ("name", name),
    ('price', price),
    ('descr_short', descr_short),
    ('descr_full', descr_full),
    ('image', image),
    ('brand', brand),
    ('barcode', barcode),
    ('features', features_dict)
])

lista_cervezas
# Out:
# [[('id', 'lbt_1'),
#   ('name',
#    <h1 class="h1 product-detail-name" itemprop="name">SanFrutos Vikingathor Boris Brew</h1>),
#   ('price', 3.35),
#   ('descr_short', 'Indian Dunkel'),
#   ('descr_full',
#    'Cerveza de 8.2% ABV intensa, oscura y muy lupulada. Con aroma intenso a maltas tostadas, caramelo, fruta madura, resina e hierbas aromáticas. Delicioso armargor, dulzor equilibrado y sensación de calidez. Refrescante y lupulada.\xa0\nUna receta de Boris de Mesones.\nVikingathor ya ha sido galardonada con anterioridad con las\xa0Medallas de Plata\xa0cosechadas en el\xa0European Beer Star\xa0de 2011 y 2012 y la\xa0Medalla de Plata\xa0en el\xa0Asia Beer Cup\xa02013.\nMedallas de Plata\nEuropean Beer Star\nMedalla de Plata\nAsia Beer Cup\n\n'),
#   ('image',
#    'https://www.labirratorium.com/27941-large_default/arriaca-boris-brew-vikingathor-.jpg'),
#   ('brand', 'Cerveza Sanfrutos'),
#   ('barcode', '831'),
#   ('features',
#    {'Estilo': 'DUNKEL',
#     'Origen': 'Segovia',
#     '% Alc.': 'ALTO (6-9%)',
#     '% Alc. Exacto': '8.2',
#     'Volumen (cl)': '33 Cl',
#     'Tipo Fermentación': 'Lager (Baja Fermentación)',
#     'IBU': '50-75 Amargor alto',
#     'IBU Exacto': '75',
#     'Color': 'Marrón',
#     'Envase': 'Botella'})]]

# %% [markdown]
# ### Ya sabemos obtener todos los datos que nos interesan de una cerveza, ahora tenemos que aplicar esta lógica para obtener todas las demás

# %% [markdown]
# Construir un DataFrame

# %%
pages = np.arange(1,5)
count = 1
lista_cervezas = []

for page in pages:
    URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page=' + str(page)
    r = requests.get(URL)
    soup = bs(r.text, 'lxml')
    cervezas_grid = soup.find_all(class_='product-image')
    count_beer = 1

    for cerveza in cervezas_grid:
        print('Cerveza {} de {}, pag {}/{}'.format(count_beer, len(cervezas_grid), page, len(pages)))

        URL_cerveza = cerveza.find('a')['href']
        r = requests.get(URL_cerveza)
        soup_cerveza = bs(r.text, 'lxml')

        name = soup_cerveza.find(class_='h1 product-detail-name').text   

        price = soup_cerveza.find(class_='current-price').find('span')['content']

        try:
            descr_short = soup_cerveza.find(class_='description-short').find('p').text
        except:
            descr_short = None

        descr_full_list = []
        descr_full_p = soup_cerveza.find(class_='product-description').find_all('p')
        for sentence in descr_full_p:
            descr_full_list.append(sentence.text)
            
        descr_full = "\n".join(descr_full_list)

        image = soup_cerveza.find(class_='js-qv-product-cover img-fluid')['src']

        try:
            brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
        except:
            brand = None

        try:
            barcode = soup_cerveza.find(class_='product-reference').find('span').text
        except:
            barcode = None
        
        features_dicc = {}
        features = soup_cerveza.find(class_ = 'data-sheet')
        
        try:
            features_dt = features.find_all('dt')
            features_dd = features.find_all('dd')
            for feature, value in zip(features_dt, features_dd):
                #print(feature.text, value.text)
                features_dicc[feature.text] = value.text
        except:
            features_dicc = {}

        data = {"id_libro": count_beer,
                "name": name,
                "price": price,
                "descr_short": descr_short,
                "descr_full": descr_full,
                "brand": brand,
                "barcode": barcode,
                "image": image,
                'features': features_dicc}

        lista_cervezas.append(data)
        count_beer += 1
        count = +1
# Out:
# Cerveza 1 de 12, pag 1/4
# Cerveza 2 de 12, pag 1/4
# Cerveza 3 de 12, pag 1/4
# Cerveza 4 de 12, pag 1/4
# Cerveza 5 de 12, pag 1/4
# Cerveza 6 de 12, pag 1/4
# Cerveza 7 de 12, pag 1/4
# Cerveza 8 de 12, pag 1/4
# Cerveza 9 de 12, pag 1/4
# Cerveza 10 de 12, pag 1/4
# Cerveza 11 de 12, pag 1/4
# Cerveza 12 de 12, pag 1/4
# Cerveza 1 de 12, pag 2/4
# Cerveza 2 de 12, pag 2/4
# Cerveza 3 de 12, pag 2/4
# Cerveza 4 de 12, pag 2/4
# Cerveza 5 de 12, pag 2/4
# Cerveza 6 de 12, pag 2/4
# Cerveza 7 de 12, pag 2/4
# Cerveza 8 de 12, pag 2/4
# Cerveza 9 de 12, pag 2/4
# Cerveza 10 de 12, pag 2/4
# Cerveza 11 de 12, pag 2/4
# Cerveza 12 de 12, pag 2/4
# Cerveza 1 de 12, pag 3/4
# Cerveza 2 de 12, pag 3/4
# Cerveza 3 de 12, pag 3/4
# Cerveza 4 de 12, pag 3/4
# Cerveza 5 de 12, pag 3/4
# Cerveza 6 de 12, pag 3/4
# Cerveza 7 de 12, pag 3/4
# Cerveza 8 de 12, pag 3/4
# Cerveza 9 de 12, pag 3/4
# Cerveza 10 de 12, pag 3/4
# Cerveza 11 de 12, pag 3/4
# Cerveza 12 de 12, pag 3/4
# Cerveza 1 de 12, pag 4/4
# Cerveza 2 de 12, pag 4/4
# Cerveza 3 de 12, pag 4/4
# Cerveza 4 de 12, pag 4/4
# Cerveza 5 de 12, pag 4/4
# Cerveza 6 de 12, pag 4/4
# Cerveza 7 de 12, pag 4/4
# Cerveza 8 de 12, pag 4/4
# Cerveza 9 de 12, pag 4/4
# Cerveza 10 de 12, pag 4/4
# Cerveza 11 de 12, pag 4/4
# Cerveza 12 de 12, pag 4/4

# %%
df = pd.DataFrame(lista_cervezas)
df
# Out:
#     id_libro                                    name  price  \
# 0          1        SanFrutos Vikingathor Boris Brew   3.35
# 1          2                  Boon Oude Kriek 37,5cl   7.15
# 2          3                Störtebeker Schwarz-Bier    2.5
# 3          4               Augustiner Lagerbier Hell   2.75
# 4          5      Schneider Aventinus Weizen-Eisbock   2.85
# 5          6      Aecht Schlenkerla Rauchbier Weizen   2.75
# 6          7               Samuel Adams Boston Lager   2.45
# 7          8                        Westmalle Dubbel    2.5
# 8          9                   Duchesse De Bourgogne   2.45
# 9         10                 Tripel Karmeliet 33 cl.   2.95
# 10        11                   Weihenstephaner Vitus      3
# 11        12                           Anchor Porter   3.05
# 12         1   Oud Beersel Oude Kriek Vieille 75 cl.  15.25
# 13         2               Weihenstephaner Korbinian    3.2
# 14         3      Aecht Schlenkerla Rauchbier Märzen    2.7
# 15         4             Samuel Smith Imperial Stout    3.7
# 16         5                        Westmalle Tripel   2.95
# 17         6         Chimay Azul Grande Réserve 75cl    7.4
# 18         7                             Achel Brune   2.95
# 19         8                 Anchor California Lager   2.95
# 20         9                      Ayinger Celebrator    2.5
# 21        10                         Pilsner Urquell   1.75
# 22        11  Aecht Schlenkerla Rauchbier Doppelbock   3.35
# 23        12                  Lindemans Kriek 25 cl.    2.4
# 24         1                  Straffe Hendrik Tripel    3.4
# 25         2                       Chimay Azul 33 cl    3.1
# 26         3                       La Chouffe 33 cl.    2.7
# 27         4                  Anchor Old Foghorn Ale   4.75
# 28         5                            Achel Blonde   2.95
# 29         6      Aecht Schlenkerla Rauchbier Urbock    2.9
# 30         7                       DouGall's Raquera   2.45
# 31         8                  Trappistes Rochefort 8   3.15
# 32         9                   Tripel Karmeliet 75cl    6.8
# 33        10                    St. Bernardus Abt 12   3.05
# 34        11                           Caleya Goma 2   2.97
# 35        12                            Gulden Draak   2.95
# 36         1  St. Louis Gueuze Fond Tradition 37.5cl    4.6
# 37         2               Straffe Hendrik Quadrupel    3.6
# 38         3               Schneider Tap 6 Aventinus    2.4
# 39         4           Kloster Andechs Bergbock Hell    2.7
# 40         5              St Feuillien Cuvée de Noel   3.42
# 41         6                   Blanche de Namur 75cl   5.55
# 42         7                 Trappistes Rochefort 10      4
# 43         8                    DouGall's Tres Mares   2.45
# 44         9                           Saison Dupont   2.32
# 45        10                       Gulden Draak 9000   2.95
# 46        11                             Chimay Roja    2.8
# 47        12         Brunehaut Tripel Bio Sin Gluten   3.95
#
#                                           descr_short  \
# 0                                       Indian Dunkel
# 1                                      Lambic / Kriek
# 2                 Cerveza negra de baja fermentación
# 3                                      Lager / Helles
# 4   Cerveza de color medio oscuro, aromas alcohóli...
# 5
# 6   Cerveza de baja fermentación (Lager) de color ...
# 7                                              Dubbel
# 8                         Oud Bruin/ Flanders Red Ale
# 9                                              Tripel
# 10                                         Weizenbock
# 11                                             Porter
# 12                                     Lambik / Kriek
# 13                                         Doppelbock
# 14                                  Rauchbier / Mazen
# 15                                     Imperial Stout
# 16                                             Tripel
# 17                                 Belgian Strong Ale
# 18                                     Belgian Dubbel
# 19                                              Lager
# 20                                         Doppelbock
# 21                                            Pilsner
# 22                             Rauchbier / Doppelbock
# 23                                     Lambic / Kriek
# 24              Cerveza rubia estilo Tripel de abadía
# 25                            Belgian Strong Dark Ale
# 26                          Belgian Strong Golden Ale
# 27  Cerveza estilo Barleywine. De color oscuro, ar...
# 28                          Belgian Strong Golden Ale
# 29                                  Rauchbier / Lager
# 30                                             Pilsen
# 31                            Belgian Strong Dark Ale
# 32                                             Tripel
# 33                                          Quadrupel
# 34                                                IPA
# 35                            Belgian Strong Dark Ale
# 36                                    Lambic / Gueuze
# 37                                          Quadrupel
# 38                                   Weizendoppelbock
# 39                              Helles Bock / Maibock
# 40     Belgian Strong Dark Ale. Color marrón rojizo.
# 41                                            Witbier
# 42                            Belgian Strong Dark Ale
# 43                             Amber Ale / Sin Gluten
# 44                             Saison / Farmhouse Ale
# 45                                          Quadrupel
# 46                                     Belgian Dubbel
# 47                       Sin Gluten / Belgian Triple
#
#                                            descr_full  \
# 0   Cerveza de 8.2% ABV intensa, oscura y muy lupu...
# 1   Cerveza de fermentación espontánea (Lambic) de...
# 2   Cerveza negra de baja fermentación de estilo S...
# 3   Cerveza de baja fermentación de estilo Munich ...
# 4   Cerveza de color medio oscuro, aromas alcohóli...
# 5   Rauchbier (cerveza ahumada) de trigo con 5.2% ...
# 6   Apariencia: color ambarino cobrizo y espuma pe...
# 7   Cerveza Trapista belga con 7% ABV de color mar...
# 8   Cerveza belga de estilo Ale Roja de 6.2% ABV d...
# 9   Cerveza de estilo Belgian Tripel con 8.4% ABV....
# 10  Cerveza refrescante de trigo fuerte y aromátic...
# 11  Cerveza negra, cremosa, con aromas a chocolate...
# 12  Oud Beersel Oude Kriek es una cerveza artesana...
# 13  Cerveza alemanda de estilo Doppelbock de 7.4% ...
# 14  Rauchbier (cerveza ahumada) de estilo Marzen d...
# 15  Cerveza de color marrón muy oscuro, muy cremos...
# 16  Cerveza Trapista belga con 9% ABV de color oro...
# 17  Cerveza fuerte de abadía, de color oscuro, Afr...
# 18  Ale Trapense.De un color caoba muy bello y una...
# 19  COMMERCIAL DESCRIPTIONOur California Lager is ...
# 20  Cerveza Lager tostada de 6.7% ABV. De color ca...
# 21                Cerveza Pilsner Checa, la original.
# 22  Rauchbier (cerveza ahumada). Lager fuerte de 8...
# 23  Cerveza de fermentación espontánea (Lambic) de...
# 24  Cerveza de color amarillo dorado, con aromas e...
# 25  Cerveza de color tostada oscura, con un aroma ...
# 26  Cerveza rubia belga de 8% ABV, con aromas herb...
# 27  Cerveza estilo Barleywine. De color oscuro, ar...
# 28  Densa, ligeramente amarga. Dulce y amarga a lú...
# 29  Rauchbier (cerveza ahumada). Lager fuerte de 6...
# 30  Cerveza rubia ligera estilo Pilsen de 5% ABV\n...
# 31  Cerveza color marrón rojizo, aroma complejo af...
# 32  Cerveza de estilo Belgian Tripel con 8.4% ABV....
# 33  Cerveza belga fuerte elaborada al estilo del c...
# 34  IPA de 6.3% ABV elaborada con lúpulos Citra y ...
# 35  Cerveza belga fuerte en la que se ha utilizado...
# 36  Cerveza de fermentación espontánea (Lambic) si...
# 37  Cerveza de color marrón oscuro, aroma alcohóli...
# 38  Cerveza fuerte y oscura de trigo alemán de 8.2...
# 39  Helles Bock 6.9% ABV.\nCerveza de color dorado...
# 40  Belgian Strong Dark Ale Color marrón rojizo\n\...
# 41  Cerveza de trigo belga (estilo Witbier o Blanc...
# 42  Cerveza de color oscuro, con aromas a pasas, a...
# 43  Amber Ale de 5.2% ABV elaborada con lúpulos Ce...
# 44  Saison de 6.5% ABV. \nElaborada desde 1844 en ...
# 45  Cerveza belga de estilo Quadrupel extremadamen...
# 46  Cerveza trapense posee un hermoso color cobriz...
# 47  Cerveza sin gluten de estilo Belgian Triple de...
#
#                                                 brand barcode  \
# 0                                   Cerveza Sanfrutos     831
# 1                                   Brouwerij F. Boon     284
# 2                                         Störtebeker     225
# 3                                          Augustiner     184
# 4                                           Schneider     183
# 5                                         Schlenkerla     181
# 6                                        Samuel Adams     173
# 7                                       Van Westmalle      82
# 8                                           Verhaeghe      75
# 9                       Brouwerij Bosteels (AB InBev)      61
# 10                                      Weihenstephan      21
# 11                   Anchor Brewing Company (Sapporo)      19
# 12                                        Oud Beersel     287
# 13                                      Weihenstephan     182
# 14                                    Brauerei Heller     180
# 15                                       Samuel Smith     109
# 16                                      Van Westmalle      83
# 17                                             Chimay      44
# 18  Brouwerij der Trappistenabdij De Achelse Kluis...      13
# 19                   Anchor Brewing Company (Sapporo)     966
# 20                                            Ayinger     584
# 21     Pilsner Urquell- Plzensky Prazdroj (SABMiller)     558
# 22                                        Schlenkerla     367
# 23                                          Lindemans     352
# 24                      De Halve Maan-Straffe Hendrik      69
# 25                                             Chimay      67
# 26              Brasserie d'Achouffe (Duvel-Moortgat)      60
# 27                   Anchor Brewing Company (Sapporo)      18
# 28  Brouwerij der Trappistenabdij De Achelse Kluis...      12
# 29                                        Schlenkerla     671
# 30                                  Cerveza Dougall's     158
# 31                                          Rochefort      73
# 32                      Brouwerij Bosteels (AB InBev)      72
# 33                                     St. Bernardus       63
# 34                                     Cerveza Caleya    2313
# 35                                     Van Steenberge      66
# 36                                    Van Honsebrouck    2273
# 37                      De Halve Maan-Straffe Hendrik      68
# 38                                          Schneider      22
# 39                            Klosterbrauerei Andechs    2361
# 40                              St-Feuillien / Friart    1263
# 41                                  Brasserie Du Bocq     208
# 42                                          Rochefort      74
# 43                                  Cerveza Dougall's     339
# 44                                   Brasserie Dupont     930
# 45                                     Van Steenberge     605
# 46                                             Chimay    4295
# 47                                          Brunehaut     712
#
#                                                 image  \
# 0   https://www.labirratorium.com/27941-large_defa...
# 1   https://www.labirratorium.com/19351-large_defa...
# 2   https://www.labirratorium.com/488-large_defaul...
# 3   https://www.labirratorium.com/367-large_defaul...
# 4   https://www.labirratorium.com/366-large_defaul...
# 5   https://www.labirratorium.com/364-large_defaul...
# 6   https://www.labirratorium.com/343-large_defaul...
# 7   https://www.labirratorium.com/102-large_defaul...
# 8   https://www.labirratorium.com/12300-large_defa...
# 9   https://www.labirratorium.com/81-large_default...
# 10  https://www.labirratorium.com/43-large_default...
# 11  https://www.labirratorium.com/33361-large_defa...
# 12  https://www.labirratorium.com/620-large_defaul...
# 13  https://www.labirratorium.com/365-large_defaul...
# 14  https://www.labirratorium.com/12653-large_defa...
# 15  https://www.labirratorium.com/131-large_defaul...
# 16  https://www.labirratorium.com/103-large_defaul...
# 17  https://www.labirratorium.com/67-large_default...
# 18  https://www.labirratorium.com/12481-large_defa...
# 19  https://www.labirratorium.com/33947-large_defa...
# 20  https://www.labirratorium.com/899-large_defaul...
# 21  https://www.labirratorium.com/848-large_defaul...
# 22  https://www.labirratorium.com/777-large_defaul...
# 23  https://www.labirratorium.com/30322-large_defa...
# 24  https://www.labirratorium.com/89-large_default...
# 25  https://www.labirratorium.com/87-large_default...
# 26  https://www.labirratorium.com/30126-large_defa...
# 27  https://www.labirratorium.com/40-large_default...
# 28  https://www.labirratorium.com/29924-large_defa...
# 29  https://www.labirratorium.com/1133-large_defau...
# 30  https://www.labirratorium.com/9072-large_defau...
# 31  https://www.labirratorium.com/93-large_default...
# 32  https://www.labirratorium.com/92-large_default...
# 33  https://www.labirratorium.com/83-large_default...
# 34  https://www.labirratorium.com/2759-large_defau...
# 35  https://www.labirratorium.com/29959-large_defa...
# 36  https://www.labirratorium.com/29017-large_defa...
# 37  https://www.labirratorium.com/88-large_default...
# 38  https://www.labirratorium.com/11199-large_defa...
# 39  https://www.labirratorium.com/19388-large_defa...
# 40  https://www.labirratorium.com/1821-large_defau...
# 41  https://www.labirratorium.com/12375-large_defa...
# 42  https://www.labirratorium.com/94-large_default...
# 43  https://www.labirratorium.com/804-large_defaul...
# 44  https://www.labirratorium.com/29511-large_defa...
# 45  https://www.labirratorium.com/29961-large_defa...
# 46  https://www.labirratorium.com/5160-large_defau...
# 47  https://www.labirratorium.com/1207-large_defau...
#
#                                              features
# 0   {'Estilo': 'DUNKEL', 'Origen': 'Segovia', '% A...
# 1   {'Estilo': 'KRIEK', 'Origen': 'Bélgica', '% Al...
# 2   {'Estilo': 'SCHWARZBIER', 'Origen': 'Alemania'...
# 3   {'Estilo': 'MUNICH HELLES', 'Origen': 'Alemani...
# 4   {'Origen': 'Alemania', '% Alc. Exacto': '12', ...
# 5   {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 6   {'Estilo': 'AMERICAN LAGER', 'Origen': 'EEUU',...
# 7   {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 8   {'Estilo': 'FLANDERS RED ALE
# OUD BRUIN
# Oud Bru...
# 9   {'Origen': 'Bélgica', '% Alc.': 'ALTO (6-9%)',...
# 10  {'Estilo': 'TRIGO ALEMÁN (WEIZENDOPPELBOCK)', ...
# 11  {'Estilo': 'AMERICAN PORTER', 'Origen': 'Estad...
# 12  {'Estilo': 'KRIEK', 'Origen': 'Belgica', '% Al...
# 13  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 14  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 15  {'Estilo': 'IMPERIAL STOUT', 'Origen': 'Inglat...
# 16  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 17  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 18  {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 19  {'Origen': 'California, Estados Unidos', '% Al...
# 20  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 21  {'Estilo': 'PILSNER ', 'Origen': 'República Ch...
# 22  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 23  {'Estilo': 'KRIEK', 'Origen': 'Belgica', '% Al...
# 24  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 25  {'Origen': 'Bélgica', '% Alc.': 'ALTO (6-9%)',...
# 26  {'Estilo': 'BELGIAN GOLDEN STRONG', 'Origen': ...
# 27  {'Estilo': 'AMERICAN BARLEYWINE', 'Origen': 'E...
# 28  {'Estilo': 'BELGIAN GOLDEN STRONG', 'Origen': ...
# 29  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 30  {'Estilo': 'PILSNER ', 'Origen': 'Cantabria', ...
# 31  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 32  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 33  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 34  {'Estilo': 'IPA (INDIA PALE ALE)', 'Origen': '...
# 35  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 36  {'Estilo': 'GUEUZE', 'Origen': 'Bélgica', '% A...
# 37  {'Estilo': 'QUADRUPEL / DARK STRONG ALE', 'Ori...
# 38  {'Estilo': 'TRIGO ALEMÁN (WEIZENDOPPELBOCK)', ...
# 39  {'Estilo': 'MAIBOCK', 'Origen': 'Alemania', '%...
# 40  {'Origen': 'Bélgica', '% Alc. Exacto': '9', 'O...
# 41  {'Estilo': 'TRIGO BELGA (WITBIER)', 'Origen': ...
# 42  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 43  {'Estilo': 'AMBER ALE / RED ALE
# SIN GLUTEN', '...
# 44  {'Estilo': 'SAISON / FARMHOUSE ALE', 'Origen':...
# 45  {'Estilo': 'QUADRUPEL / DARK STRONG ALE', 'Ori...
# 46  {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 47  {'Estilo': 'SIN GLUTEN
# TRIPEL', 'Origen': 'Bél...
