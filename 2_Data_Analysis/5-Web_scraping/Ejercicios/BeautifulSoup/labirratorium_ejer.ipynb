# %% [markdown]
# ###  Pasos a seguir en el proceso de 'scraping':
#
# 1. Encuentra la URL que quieres 'escrapear'.
# 2. Inspecciona la página (código fuente).
# 3. Localiza los datos que necesitas obtener.
# 4. Desarrolla tu código en Python.
#     1. Crea tu sopa
#     2. Busca los elementos que cotienen los datos y extráelos
# 5. Ejecuta tu código y obten los datos.
# 6. Alamacena los datos en el formato requerido.

# %%
# Importamos librerías
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import html
import numpy as np

# %% [markdown]
# ## Caso 1: Scraping de un catálogo: Labirratorium

# %%
URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page='

# %% [markdown]
# Queremos obtener un dataFrame con todas las cervezas del catálogo y sus características descritas. Analizamos la página para ver qué tenemos que hacer para conseguirlo

# %%
# La web tiene 80 páginas con 12 cervezas listadas en cada página.

# %% [markdown]
# Hacemos la consulta (request) y creamos la SOPA inicial:

# %%
r = requests.get(URL)
soup = bs(r.text, 'lxml')

# %%
# Guardamos lista de cervezas
cervezas_grid = soup.find_all(class_='product-image')
cervezas_grid[0]
# Out:
# <div class="product-image">
# <!-- @file modules\appagebuilder\views\templates\front\products\file_tpl -->
# <ul class="product-flags">
# </ul>
# <a class="thumbnail product-thumbnail" href="https://www.labirratorium.com/es/inicio/831-arriaca-boris-brew-vikingathor-.html">
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.labirratorium.com/27941-large_default/arriaca-boris-brew-vikingathor-.jpg" src="https://www.labirratorium.com/27941-home_default/arriaca-boris-brew-vikingathor-.jpg"/>
# <span class="product-additional" data-idproduct="831"></span>
# </a>
# </div>

# %%
# necesitamos acceder a cada una de las cervezas del grid:
lista_URLs = []
for cerveza in cervezas_grid:
    URL_cerveza = cerveza.find('a')['href']
    lista_URLs.append(URL_cerveza)

lista_URLs
# Out:
# ['https://www.labirratorium.com/es/inicio/831-arriaca-boris-brew-vikingathor-.html',
#  'https://www.labirratorium.com/es/cerveza-lambic/284-boon-kriek-2013.html',
#  'https://www.labirratorium.com/es/cervezas-alemanas/225-stortebeker-schwarz-bier.html',
#  'https://www.labirratorium.com/es/botella-33cl/199-orval.html',
#  'https://www.labirratorium.com/es/cervezas-alemanas/184-augustiner-lagerbier-hell.html',
#  'https://www.labirratorium.com/es/inicio/183-schneider-eisbock.html',
#  'https://www.labirratorium.com/es/inicio/181-schlenkerla-rauchbier-weizen.html',
#  'https://www.labirratorium.com/es/inicio/173-samuel-adams-boston-lager.html',
#  'https://www.labirratorium.com/es/inicio/165-laugar-epa.html',
#  'https://www.labirratorium.com/es/inicio/82-westmalle-dubbel.html',
#  'https://www.labirratorium.com/es/inicio/75-duchesse-de-bourgogne.html',
#  'https://www.labirratorium.com/es/inicio/61-tripel-karmeliet33.html']

# %%
# Hacemos un nuevo request para la primera cerveza: 
r = requests.get(lista_URLs[0])

# Creamos una sopa específica con la info de cada cerveza
soup_cerveza = bs(r.text, 'lxml')

# %%
# Nombre
name = soup_cerveza.find(class_='h1 product-detail-name')
name
# Out:
# <h1 class="h1 product-detail-name" itemprop="name">SanFrutos Vikingathor Boris Brew</h1>

# %%
# Precio
price = float(soup_cerveza.find(class_='current-price').find('span')['content'])
price
# Out:
# 3.35

# %%
# Descripcion corta
descr_short = soup_cerveza.find(class_='description-short').find('p').text
descr_short
# Out:
# 'Indian Dunkel'

# %%
# Descripción larga
descr_full_list = []

descr_full_p = soup_cerveza.find(class_='product-description').find_all()
for sentence in descr_full_p:
    descr_full_list.append(sentence.text)

descr_full = '\n'.join(descr_full_list)

print(descr_full)
# Out:
# Cerveza de 8.2% ABV intensa, oscura y muy lupulada. Con aroma intenso a maltas tostadas, caramelo, fruta madura, resina e hierbas aromáticas. Delicioso armargor, dulzor equilibrado y sensación de calidez. Refrescante y lupulada.
# Una receta de Boris de Mesones.
# Vikingathor ya ha sido galardonada con anterioridad con las Medallas de Plata cosechadas en el European Beer Star de 2011 y 2012 y la Medalla de Plata en el Asia Beer Cup 2013.
# Medallas de Plata
# European Beer Star
# Medalla de Plata
# Asia Beer Cup

# %%
# Imagen
image = soup_cerveza.find(class_='js-qv-product-cover img-fluid')['src']
image
# Out:
# 'https://www.labirratorium.com/27941-large_default/arriaca-boris-brew-vikingathor-.jpg'

# %%
 # Brand
brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
brand
# Out:
# 'Cerveza Sanfrutos'

# %%
# Código de barras
try:
    barcode = soup_cerveza.find(class_='product-reference').find('span').text
except:
    barcode = None
print(barcode)
# Out:
# 831

# %%
# Features
features_dict = {}

try:
    features_dt = soup_cerveza.find_all('dt')
    features_dd = soup_cerveza.find_all('dd')
    for feature, value in zip(features_dt, features_dd):
        features_dict[feature.text] = value.text
except:
    features_dict = {}

features_dict
# Out:
# {'Estilo': 'DUNKEL',
#  'Origen': 'Segovia',
#  '% Alc.': 'ALTO (6-9%)',
#  '% Alc. Exacto': '8.2',
#  'Volumen (cl)': '33 Cl',
#  'Tipo Fermentación': 'Lager (Baja Fermentación)',
#  'IBU': '50-75 Amargor alto',
#  'IBU Exacto': '75',
#  'Color': 'Marrón',
#  'Envase': 'Botella'}

# %%
# Creamos un Id único que os permita diferenciar cada entrada en la BBDD
counter = 1
id_cerv = 'lbt_' + str(counter)

id_cerv
# Out:
# 'lbt_1'

# %% [markdown]
# Ya tenemos todos los datos que queremos de la cerveza: Agrupamos todo en una lista:

# %%
# Agregamos a una lista
lista_cervezas = []

lista_cervezas.append([
    ("id", id_cerv),
    ("name", name),
    ('price', price),
    ('descr_short', descr_short),
    ('descr_full', descr_full),
    ('image', image),
    ('brand', brand),
    ('barcode', barcode),
    ('features', features_dict)
])

lista_cervezas

# %% [markdown]
# ### Ya sabemos obtener todos los datos que nos interesan de una cerveza, ahora tenemos que aplicar esta lógica para obtener todas las demás

# %% [markdown]
# Construir un DataFrame

# %%
# Out:
# Cerveza 1 de 12, pag 1/4
# Cerveza 2 de 12, pag 1/4
# Cerveza 3 de 12, pag 1/4
# Cerveza 4 de 12, pag 1/4
# Cerveza 5 de 12, pag 1/4
# Cerveza 6 de 12, pag 1/4
# Cerveza 7 de 12, pag 1/4
# Cerveza 8 de 12, pag 1/4
# Cerveza 9 de 12, pag 1/4
# Cerveza 10 de 12, pag 1/4
# Cerveza 11 de 12, pag 1/4
# Cerveza 12 de 12, pag 1/4
# Cerveza 1 de 12, pag 2/4
# Cerveza 2 de 12, pag 2/4
# Cerveza 3 de 12, pag 2/4
# Cerveza 4 de 12, pag 2/4
# Cerveza 5 de 12, pag 2/4
# Cerveza 6 de 12, pag 2/4
# Cerveza 7 de 12, pag 2/4
# Cerveza 8 de 12, pag 2/4
# Cerveza 9 de 12, pag 2/4
# Cerveza 10 de 12, pag 2/4
# Cerveza 11 de 12, pag 2/4
# Cerveza 12 de 12, pag 2/4
# Cerveza 1 de 12, pag 3/4
# Cerveza 2 de 12, pag 3/4
# Cerveza 3 de 12, pag 3/4
# Cerveza 4 de 12, pag 3/4
# Cerveza 5 de 12, pag 3/4
# Cerveza 6 de 12, pag 3/4
# Cerveza 7 de 12, pag 3/4
# Cerveza 8 de 12, pag 3/4
# Cerveza 9 de 12, pag 3/4
# Cerveza 10 de 12, pag 3/4
# Cerveza 11 de 12, pag 3/4
# Cerveza 12 de 12, pag 3/4
# Cerveza 1 de 12, pag 4/4
# Cerveza 2 de 12, pag 4/4
# Cerveza 3 de 12, pag 4/4
# Cerveza 4 de 12, pag 4/4
# Cerveza 5 de 12, pag 4/4
# Cerveza 6 de 12, pag 4/4
# Cerveza 7 de 12, pag 4/4
# Cerveza 8 de 12, pag 4/4
# Cerveza 9 de 12, pag 4/4
# Cerveza 10 de 12, pag 4/4
# Cerveza 11 de 12, pag 4/4
# Cerveza 12 de 12, pag 4/4

# %%
# Out:
#    id_libro                                     name  price  \
# 0     lbt_1         SanFrutos Vikingathor Boris Brew   3.35
# 1     lbt_1                   Boon Oude Kriek 37,5cl   7.15
# 2     lbt_1                 Störtebeker Schwarz-Bier    2.5
# 3     lbt_1                                    Orval   2.95
# 4     lbt_1                Augustiner Lagerbier Hell   2.75
# 5     lbt_1       Schneider Aventinus Weizen-Eisbock   2.85
# 6     lbt_1       Aecht Schlenkerla Rauchbier Weizen    2.7
# 7     lbt_1                Samuel Adams Boston Lager   2.45
# 8     lbt_1           Laugar EPA! Euskadiko Pale Ale    2.7
# 9     lbt_1                         Westmalle Dubbel    2.5
# 10    lbt_1                    Duchesse De Bourgogne   2.95
# 11    lbt_1                  Tripel Karmeliet 33 cl.    2.7
# 12    lbt_1                    Weihenstephaner Vitus   2.95
# 13    lbt_1                            Anchor Porter   3.05
# 14    lbt_1    Oud Beersel Oude Kriek Vieille 75 cl.  15.25
# 15    lbt_1            Boon Oude Geuze Boon 37,5 cl.   5.15
# 16    lbt_1                Weihenstephaner Korbinian    3.2
# 17    lbt_1       Aecht Schlenkerla Rauchbier Märzen   2.65
# 18    lbt_1              Samuel Smith Imperial Stout    3.6
# 19    lbt_1                         Westmalle Tripel   2.95
# 20    lbt_1          Chimay Azul Grande Réserve 75cl    7.4
# 21    lbt_1               Lindemans Framboise 25 cl.    2.7
# 22    lbt_1                              Achel Brune   2.95
# 23    lbt_1                       Ayinger Celebrator    2.4
# 24    lbt_1                          Pilsner Urquell   1.75
# 25    lbt_1   Aecht Schlenkerla Rauchbier Doppelbock    3.3
# 26    lbt_1                   Lindemans Kriek 25 cl.    2.4
# 27    lbt_1                   Straffe Hendrik Tripel    3.4
# 28    lbt_1                        Chimay Azul 33 cl    3.1
# 29    lbt_1                        La Chouffe 33 cl.    2.7
# 30    lbt_1               Weihenstephaner HefeWeizen    2.7
# 31    lbt_1                   Anchor Old Foghorn Ale   4.75
# 32    lbt_1                             Achel Blonde   2.95
# 33    lbt_1               Ayinger Frühlingsbier 2022    2.8
# 34    lbt_1  Cantillon Gueuze 100% Lambic Bio 75 cl.  18.95
# 35    lbt_1       Aecht Schlenkerla Rauchbier Urbock   2.85
# 36    lbt_1                        DouGall's Raquera   2.45
# 37    lbt_1                   Trappistes Rochefort 8   3.15
# 38    lbt_1                    Tripel Karmeliet 75cl    6.8
# 39    lbt_1                     St. Bernardus Abt 12      3
# 40    lbt_1                            Caleya Goma 2    3.3
# 41    lbt_1             Hanssens Oude Kriek 37,5 cl.   9.65
# 42    lbt_1               Kloster Andechs Doppelbock    2.7
# 43    lbt_1  Les Trois Mousquetaires Porter Baltique   15.1
# 44    lbt_1                         Brewdog Punk IPA   3.05
# 45    lbt_1                           Bishops Finger    4.2
# 46    lbt_1                             Gulden Draak   2.95
# 47    lbt_1                Straffe Hendrik Quadrupel    3.6
#
#                                           descr_short  \
# 0                                       Indian Dunkel
# 1                                      Lambic / Kriek
# 2                 Cerveza negra de baja fermentación
# 3                                    Belgian Pale Ale
# 4                                      Lager / Helles
# 5   Cerveza de color medio oscuro, aromas alcohóli...
# 6
# 7   Cerveza de baja fermentación (Lager) de color ...
# 8                                   American Pale Ale
# 9                                              Dubbel
# 10                        Oud Bruin/ Flanders Red Ale
# 11                                             Tripel
# 12                                         Weizenbock
# 13                                             Porter
# 14                                     Lambik / Kriek
# 15                                    Lambic / Gueuze
# 16                                         Doppelbock
# 17                                  Rauchbier / Mazen
# 18                                     Imperial Stout
# 19                                             Tripel
# 20                                 Belgian Strong Ale
# 21                                 Lambic / Framboise
# 22                                     Belgian Dubbel
# 23                                         Doppelbock
# 24                                            Pilsner
# 25                             Rauchbier / Doppelbock
# 26                                     Lambic / Kriek
# 27              Cerveza rubia estilo Tripel de abadía
# 28                            Belgian Strong Dark Ale
# 29                          Belgian Strong Golden Ale
# 30                                         Hefeweizen
# 31  Cerveza estilo Barleywine. De color oscuro, ar...
# 32                          Belgian Strong Golden Ale
# 33                              Kellerbier / Landbier
# 34                                   Lambic / Gueuze
# 35                                  Rauchbier / Lager
# 36                                             Pilsen
# 37                            Belgian Strong Dark Ale
# 38                                             Tripel
# 39                                          Quadrupel
# 40                                                IPA
# 41                                     Lambic / Kriek
# 42                                  Doppelbock Dunkel
# 43                                      Baltic Porter
# 44                                     India Pale Ale
# 45                                         Strong Ale
# 46                            Belgian Strong Dark Ale
# 47                                          Quadrupel
#
#                                            descr_full  \
# 0   Cerveza de 8.2% ABV intensa, oscura y muy lupu...
# 1   Cerveza de fermentación espontánea (Lambic) de...
# 2   Cerveza negra de baja fermentación de estilo S...
# 3   Orval es una cerveza tipo ale y es la que prin...
# 4   Cerveza de baja fermentación de estilo Munich ...
# 5   Cerveza de color medio oscuro, aromas alcohóli...
# 6   Rauchbier (cerveza ahumada) de trigo con 5.2% ...
# 7   Apariencia: color ambarino cobrizo y espuma pe...
# 8   American Pale Ale de 5.2% ABV elaborada con lú...
# 9   Cerveza Trapista belga con 7% ABV de color mar...
# 10  Cerveza belga de estilo Ale Roja de 6.2% ABV d...
# 11  Cerveza de estilo Belgian Tripel con 8.4% ABV....
# 12  Cerveza refrescante de trigo fuerte y aromátic...
# 13  Cerveza negra, cremosa, con aromas a chocolate...
# 14  Oud Beersel Oude Kriek es una cerveza artesana...
# 15  Cerveza de fermentación espontánea de estilo G...
# 16  Cerveza alemanda de estilo Doppelbock de 7.4% ...
# 17  Rauchbier (cerveza ahumada) de estilo Marzen d...
# 18  Cerveza de color marrón muy oscuro, muy cremos...
# 19  Cerveza Trapista belga con 9% ABV de color oro...
# 20  Cerveza fuerte de abadía, de color oscuro, Afr...
# 21  Cerveza de fermentación espontánea y con framb...
# 22  Ale Trapense.De un color caoba muy bello y una...
# 23  Cerveza Lager tostada de 6.7% ABV. De color ca...
# 24                Cerveza Pilsner Checa, la original.
# 25  Rauchbier (cerveza ahumada). Lager fuerte de 8...
# 26  Cerveza de fermentación espontánea (Lambic) de...
# 27  Cerveza de color amarillo dorado, con aromas e...
# 28  Cerveza de color tostada oscura, con un aroma ...
# 29  Cerveza rubia belga de 8% ABV, con aromas herb...
# 30  Cerveza de trigo estilo Hefeweizen de 5.4% ABV...
# 31  Cerveza estilo Barleywine. De color oscuro, ar...
# 32  Densa, ligeramente amarga. Dulce y amarga a lú...
# 33  Kellerbier alemana de 5.5% ABV naturalmente tu...
# 34  COMMERCIAL DESCRIPTIONThe world's classic Gueu...
# 35  Rauchbier (cerveza ahumada). Lager fuerte de 6...
# 36  Cerveza rubia ligera estilo Pilsen de 5% ABV\n...
# 37  Cerveza color marrón rojizo, aroma complejo af...
# 38  Cerveza de estilo Belgian Tripel con 8.4% ABV....
# 39  Cerveza belga fuerte elaborada al estilo del c...
# 40  IPA de 6.3% ABV elaborada con lúpulos Citra y ...
# 41  Mezcla de varias Kriek de diferentes añadas qu...
# 42  Cerveza alemana de baja fermentación de estilo...
# 43  Cerveza lager negra fuerte de 10% ABV, inspira...
# 44  Cerveza Estilo IPA de 5.6% ABV elaborada en es...
# 45  Cerveza inglesa de estilo Strong Ale de 5.4% A...
# 46  Cerveza belga fuerte en la que se ha utilizado...
# 47  Cerveza de color marrón oscuro, aroma alcohóli...
#
#                                                 brand barcode  \
# 0                                   Cerveza Sanfrutos     831
# 1                                   Brouwerij F. Boon     284
# 2                                         Störtebeker     225
# 3                                               Orval     199
# 4                                          Augustiner     184
# 5                                           Schneider     183
# 6                                         Schlenkerla     181
# 7                                        Samuel Adams     173
# 8                                              Laugar     165
# 9                                       Van Westmalle      82
# 10                                          Verhaeghe      75
# 11                      Brouwerij Bosteels (AB InBev)      61
# 12                                      Weihenstephan      21
# 13                   Anchor Brewing Company (Sapporo)      19
# 14                                        Oud Beersel     287
# 15                                  Brouwerij F. Boon     285
# 16                                      Weihenstephan     182
# 17                                    Brauerei Heller     180
# 18                                       Samuel Smith     109
# 19                                      Van Westmalle      83
# 20                                             Chimay      44
# 21                                          Lindemans      39
# 22  Brouwerij der Trappistenabdij De Achelse Kluis...      13
# 23                                            Ayinger     584
# 24     Pilsner Urquell- Plzensky Prazdroj (SABMiller)     558
# 25                                        Schlenkerla     367
# 26                                          Lindemans     352
# 27                      De Halve Maan-Straffe Hendrik      69
# 28                                             Chimay      67
# 29              Brasserie d'Achouffe (Duvel-Moortgat)      60
# 30                                      Weihenstephan      20
# 31                   Anchor Brewing Company (Sapporo)      18
# 32  Brouwerij der Trappistenabdij De Achelse Kluis...      12
# 33                                            Ayinger    3302
# 34                                          Cantillon    1046
# 35                                        Schlenkerla     671
# 36                                  Cerveza Dougall's     158
# 37                                          Rochefort      73
# 38                      Brouwerij Bosteels (AB InBev)      72
# 39                                     St. Bernardus       63
# 40                                     Cerveza Caleya    2313
# 41                                           Hanssens    1301
# 42                            Klosterbrauerei Andechs     889
# 43                            Les Trois Mousquetaires     341
# 44                                            Brewdog     211
# 45                                     Shepherd Neame     111
# 46                                     Van Steenberge      66
# 47                      De Halve Maan-Straffe Hendrik      68
#
#                                                 image  \
# 0   https://www.labirratorium.com/27941-large_defa...
# 1   https://www.labirratorium.com/19351-large_defa...
# 2   https://www.labirratorium.com/488-large_defaul...
# 3   https://www.labirratorium.com/385-large_defaul...
# 4   https://www.labirratorium.com/367-large_defaul...
# 5   https://www.labirratorium.com/366-large_defaul...
# 6   https://www.labirratorium.com/364-large_defaul...
# 7   https://www.labirratorium.com/343-large_defaul...
# 8   https://www.labirratorium.com/30978-large_defa...
# 9   https://www.labirratorium.com/102-large_defaul...
# 10  https://www.labirratorium.com/12300-large_defa...
# 11  https://www.labirratorium.com/81-large_default...
# 12  https://www.labirratorium.com/43-large_default...
# 13  https://www.labirratorium.com/29925-large_defa...
# 14  https://www.labirratorium.com/620-large_defaul...
# 15  https://www.labirratorium.com/618-large_defaul...
# 16  https://www.labirratorium.com/365-large_defaul...
# 17  https://www.labirratorium.com/12653-large_defa...
# 18  https://www.labirratorium.com/131-large_defaul...
# 19  https://www.labirratorium.com/103-large_defaul...
# 20  https://www.labirratorium.com/67-large_default...
# 21  https://www.labirratorium.com/62-large_default...
# 22  https://www.labirratorium.com/12481-large_defa...
# 23  https://www.labirratorium.com/899-large_defaul...
# 24  https://www.labirratorium.com/848-large_defaul...
# 25  https://www.labirratorium.com/777-large_defaul...
# 26  https://www.labirratorium.com/30322-large_defa...
# 27  https://www.labirratorium.com/89-large_default...
# 28  https://www.labirratorium.com/87-large_default...
# 29  https://www.labirratorium.com/30126-large_defa...
# 30  https://www.labirratorium.com/12700-large_defa...
# 31  https://www.labirratorium.com/40-large_default...
# 32  https://www.labirratorium.com/29924-large_defa...
# 33  https://www.labirratorium.com/3980-large_defau...
# 34  https://www.labirratorium.com/1750-large_defau...
# 35  https://www.labirratorium.com/1133-large_defau...
# 36  https://www.labirratorium.com/9072-large_defau...
# 37  https://www.labirratorium.com/93-large_default...
# 38  https://www.labirratorium.com/92-large_default...
# 39  https://www.labirratorium.com/83-large_default...
# 40  https://www.labirratorium.com/2759-large_defau...
# 41  https://www.labirratorium.com/1800-large_defau...
# 42  https://www.labirratorium.com/2552-large_defau...
# 43  https://www.labirratorium.com/30801-large_defa...
# 44  https://www.labirratorium.com/14452-large_defa...
# 45  https://www.labirratorium.com/133-large_defaul...
# 46  https://www.labirratorium.com/29959-large_defa...
# 47  https://www.labirratorium.com/88-large_default...
#
#                                              features
# 0   {'Estilo': 'DUNKEL', 'Origen': 'Segovia', '% A...
# 1   {'Estilo': 'KRIEK', 'Origen': 'Bélgica', '% Al...
# 2   {'Estilo': 'SCHWARZBIER', 'Origen': 'Alemania'...
# 3   {'Estilo': 'BELGIAN PALE ALE', 'Origen': 'Bélg...
# 4   {'Estilo': 'MUNICH HELLES', 'Origen': 'Alemani...
# 5   {'Origen': 'Alemania', '% Alc. Exacto': '12', ...
# 6   {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 7   {'Estilo': 'AMERICAN LAGER', 'Origen': 'EEUU',...
# 8   {'Estilo': 'APA (AMERICAN PALE ALE)', 'Origen'...
# 9   {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 10  {'Estilo': 'FLANDERS RED ALE
# OUD BRUIN
# Oud Bru...
# 11  {'Origen': 'Bélgica', '% Alc.': 'ALTO (6-9%)',...
# 12  {'Estilo': 'TRIGO ALEMÁN (WEIZENDOPPELBOCK)', ...
# 13  {'Estilo': 'AMERICAN PORTER', 'Origen': 'Estad...
# 14  {'Estilo': 'KRIEK', 'Origen': 'Belgica', '% Al...
# 15  {'Estilo': 'GUEUZE', 'Origen': 'Bélgica', '% A...
# 16  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 17  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 18  {'Estilo': 'IMPERIAL STOUT', 'Origen': 'Inglat...
# 19  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 20  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 21  {'Estilo': 'FRAMBOISE', 'Origen': 'Bélgica', '...
# 22  {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 23  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 24  {'Estilo': 'PILSNER ', 'Origen': 'República Ch...
# 25  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 26  {'Estilo': 'KRIEK', 'Origen': 'Belgica', '% Al...
# 27  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 28  {'Origen': 'Bélgica', '% Alc.': 'ALTO (6-9%)',...
# 29  {'Estilo': 'BELGIAN GOLDEN STRONG', 'Origen': ...
# 30  {'Estilo': 'TRIGO ALEMÁN (WEISSBIER / HEFEWEIZ...
# 31  {'Estilo': 'AMERICAN BARLEYWINE', 'Origen': 'E...
# 32  {'Estilo': 'BELGIAN GOLDEN STRONG', 'Origen': ...
# 33  {'Estilo': 'KELLERBIER', 'Origen': 'Alemania',...
# 34  {'Estilo': 'GUEUZE', 'Origen': 'Bélgica', '% A...
# 35  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 36  {'Estilo': 'PILSNER ', 'Origen': 'Cantabria', ...
# 37  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 38  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 39  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 40  {'Estilo': 'IPA (INDIA PALE ALE)', 'Origen': '...
# 41  {'Estilo': 'KRIEK', 'Origen': 'Bélgica', '% Al...
# 42  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 43  {'Estilo': 'BALTIC PORTER', 'Origen': 'Canadá'...
# 44  {'Estilo': 'IPA (INDIA PALE ALE)', 'Origen': '...
# 45  {'Estilo': 'ENGLISH STRONG ALE', 'Origen': 'In...
# 46  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 47  {'Estilo': 'QUADRUPEL / DARK STRONG ALE', 'Ori...
