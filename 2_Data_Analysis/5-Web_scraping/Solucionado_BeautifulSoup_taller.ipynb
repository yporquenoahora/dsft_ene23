# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página de libros más vendidos de Book Depository, y para lograr esto, también tendrá que hacer uso de un poco de pandas principalmente..

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (from beautifulsoup4) (2.4)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parser, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (4.9.2)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (2.28.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (from requests) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yporq\ds-2023\dsft_ene23\.venv\lib\site-packages (from requests) (1.26.14)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Ahora asi manos a la obra..

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.bookdepository.com/es/bestsellers"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <link rel="preconnect" href="https://d3ogvdx946i4sr.cloudfront.net"/>\n<link rel="dns-prefetch" href="https://d3ogvdx946i4sr.cloudfront.net"/>\n<script type="text/javascript">\n        function csmWidgetStart(widgetName) {\n            if (typeof uet == \'function\') {\n                uet(\'bb\', widgetName, {wb: 1});\n            }\n        }\n        function csmWidgetEnd(widgetName) {\n            if (typeof uet == \'function\') {\n                uex(\'ld\', widgetName, {wb: 1});\n            }\n        }\n    </script>\n    <noscript>\n        <style>\n            .hide-when-no-js {\n                display: none !important;\n            }\n\n            .show-when-no-js {\n                display: block !important;\n            }\n        </style>\n    </noscript>\n\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n<meta name="copyright" content="&copy;2020 Book Depository Ltd." />\n<meta name="author" content="Book Depository" />\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n<meta name="google-site-verification" content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" />\n<meta name="msvalidate.01" content="D45E907CC9A963F78BD3129AAAAFE4F0" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge; charset=UTF-8"> <meta name="description" content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." />\n    <meta name="keywords" content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" />\n\t<meta name="Revisit-After" content="30 days" />\n\t<link rel="canonical" href="https://www.bookdepository.com/es/bestsellers" />\n<link rel="alternate" hreflang="x-default" href="https://www.bookdepository.com/bestsellers" />\n\t<link rel="alternate" hreflang="en" href="https://www.bookdepository.com/bestsellers" />\n\t<link rel="alternate" hreflang="es" href="https://www.bookdepository.com/es/bestsellers" />\n\t<link rel="next" href="/es/bestsellers?page=2" />\n\t<title>\n\tBestselling books online with free delivery at Book Depository</title>\n\n<!-- Styles -->\n<link rel="shortcut icon" type="image/ico" href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" />\n<link rel="apple-touch-icon-precomposed" href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" />\n<link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/common.css" onload="csmWidgetEnd(\'css-download\');">\n<!--[if lte IE 9]>\n<link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/ie/common.css">\n<![endif]-->\n\n<script type="text/javascript">\n    csmWidgetStart(\'icons-download\');\n</script>\n<link rel="preload" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/fonts/bdicons.woff" as="font" type="font/woff2" crossorigin onload="csmWidgetEnd(\'icons-download\');">\n\n<script type="text/javascript">\n    csmWidgetStart(\'font-download\');\n</script>\n\n<script type="text/javascript">\n    csmWidgetStart(\'css-download\');\n</script>\n<script type="text/javascript">\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n        (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n        m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    \n    window.ga(\'create\', \'UA-41807899-1\', \'www.bookdepository.com\', {\n        \'allowLinker\': true,\n        \'storage\': \'none\'\n    });\n    \n\n    function registerPageView() {\n        window.ga(\'send\', \'pageview\');\n    }\n    document.addEventListener("DOMContentLoaded", function() {\n        registerPageView();\n    });\n</script>\n\n<script src="https://assets.adobedtm.com/4dfb8f1b14f8/eb478f5c633f/launc ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." name="description"/>
# <meta content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <link href="https://www.bookdepository.com/es/bestsellers" rel="canonical"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/bestsellers" hreflang="es" rel="alternate"/>
# <link href="/es/bestsellers?page=2" rel="next"/>
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# <script async="" src="https://assets.adobedtm.com/4dfb8f1b14f8/eb478f5c633f/launch-8ffac2b531d7.min.js">
# </script>
# </head>
# <body class="">
# <div aria-live="polite" class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>Usamos cookies para mejorar este sitio</h2>
# <p>Las cookies se utilizan para brindar, analizar y mejorar nuestros servicios; proporcionar herramientas de chat; y<br/>mostrarte contenido relevante de publicidad. Para más información sobre nuestro uso de cookies, lee nuestra sección de <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Ayuda sobre Cookies</a></p><h2>¿Aceptas las cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <button class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Aceptar cookies</button>
# <button class="btn btn-sm btn-secondary btn-manage" href="#" rel="nofollow">
#                 Administrar cookies</button>
# </div>
# </div>
# <div aria-live="polite" class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Preferencias de cookies</h2>
# <p>Usamos cookies y herramientas similares que son necesarias para permitirte realizar compras, incluidas las que utilizan terceros autorizados (colectivamente denominadas “cookies”) para los fines que se describen a continuación.
#      <br/>Para obtener más información acerca de cómo nosotros y los terceros autorizados usamos las cookies y cómo cambiar tu configuración, consulta el <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>. Las elecciones que realices aquí se aplicarán a tu interacción con este servicio en este dispositivo.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Indispensable</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>Usamos cookies para brindar nuestros servicios, </span>
# <div>
# <div class="additionalInfo wrapping-space">por ejemplo, para realizar un seguimiento de los artículos almacenados en tu canasta de compras, prevenir actividades fraudulentas, mejorar la seguridad de nuestros servicios, realizar un seguimiento de tus preferencias específicas (como preferencias de moneda o idioma) y mostrar características, productos y servicios que puedan ser de tu interés. Debido a que usamos cookies para brindarte nuestros servicios, estas no se pueden desactivar cuando se usan con este fin.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <label for="performanceCheckBox"><h2>Desempeño y analítica</h2></label>
# </div>
# <div class="cookie-management-category-check">
# <span aria-hidden="true" class="is-enabled">ACTIVADO</span>
# <span aria-hidden="true" class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="performanceCheckBox" role="switch" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si estás de acuerdo, utilizaremos cookies para comprender cómo los clientes utilizan nuestros servicios</span>
# <div>
# <div class="additionalInfo wrapping-space">(por ejemplo, midiendo visitas al sitio) para que podamos hacer mejoras. Usamos cookies para realizar investigaciones y diagnósticos a fin de mejorar el contenido, los productos y los servicios, y para evaluar y analizar el desempeño de nuestros servicios.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <label for="advertisingCheckBox"><h2>Publicidad</h2></label>
# </div>
# <div class="cookie-management-category-check">
# <span aria-hidden="true" class="is-enabled">ACTIVADO</span>
# <span aria-hidden="true" class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" role="switch" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si estás de acuerdo, utilizaremos cookies para complementar tu experiencia de compra, tal como se describe en nuestro <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de Cookies</a></span>
# <div>
# <div class="additionalInfo wrapping-space">y ofrecerte ciertos tipos de anuncios relevantes a tus intereses en Book Depository. Esto incluye el uso de cookies de terceros con el propósito de mostrar y medir anuncios (consulta el aviso de <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Anuncios basados en intereses</a> para conocer cómo usamos las cookies para publicar anuncios basados en intereses), medir la efectividad de los anuncios y, según sea necesario, para que el tercero realice servicios en nombre de Book Depository.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <button class="btn btn-sm btn-secondary btn-cancel" href="#" rel="nofollow">
#                 Cancelar</button>
# <button class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Guardar configuración</button>
# </div>
# </div>
# <div hidden="" id="main-data-container">
# <div class="metrics_data_events" data-metric-event="PAGE_LOADED" hidden=""></div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a></li>
# <li class="mob-nav-account"><a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a></li>
# <li class="mob-nav-account"><a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/es/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/es/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/es/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Buscar libros por palabra clave / título / autor / ISBN" class="text-input" name="searchTerm" placeholder="Buscar libros por palabra clave / título / autor / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Buscar</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 Todas las categorías</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Menú principal</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/es/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/es/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/es/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/es/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/es/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Libros infantiles por edades</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/es/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/es/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/es/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/es/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/es/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Top Authors">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Bestselling Series">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Books By Language">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/es/bestsellers">Los más vendidos</a></li>
# <li class="mob-nav-shop"><a href="/es/comingsoon">Próximamente </a></li>
# <li class="mob-nav-shop"><a href="/es/top-new-releases">Nuevos lanzamientos</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         Español</a>
# <div class="metrics_data_container" data-datalayer-reader="locale" data-page-locale="es_ES" hidden=""></div>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Idiomas</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             Inglés (English)</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Español</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="Español">
# <select id="selectLanguage" name="selectLanguage">
# <option value="en_US">
#                     English</option>
# <option selected="selected" value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/es/bestsellers" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/es/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="metrics_data_container" data-datalayer-reader="loginStatus" data-val="guest" hidden=""></div>
# <div class="content-wrap">
# <div class="sidebar">
# <div class="sidebar-section search-filter">
# <h2>Filtrar tu búsqueda</h2>
# <div class="sidebar-section-content search-filter-sidebar">
# <form action="/es/bestsellers" class="filter-menu" method="get">
# <div class="form-group">
# <label for="searchTerm">Palabra clave</label>
# <input class="form-control" name="searchTerm" spellcheck="false" type="text" value=""/>
# </div>
# <input name="searchSortBy" type="hidden" value=""/>
# <input name="category" type="hidden" value=""/>
# <div class="form-group">
# <label for="filter_price">Precio</label>
# <select class="form-control" id="filterPrice" name="price">
# <option label="All" value="">
# 							All</option>
# <option label="Under €15" value="low">
# 							Under €15</option>
# <option label="€15 to €30" value="med">
# 							€15 to €30</option>
# <option label="€30 +" value="high">
# 							€30 +</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_availability">Disponibilidad</label>
# <select class="form-control" id="filterAvailability" name="availability">
# <option label="All" value="">
# 							All</option>
# <option label="In stock (62422)" value="1">
# 							In stock (62422)</option>
# <option label="Pre-order (2071)" value="2">
# 							Pre-order (2071)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_search_lang">Idioma</label>
# <select class="form-control" id="filterLang" name="searchLang">
# <option label="All" value="">
# 							All</option>
# <option label="English (61209)" value="123">
# 							English (61209)</option>
# <option label="French (356)" value="137">
# 							French (356)</option>
# <option label="Spanish (1245)" value="404">
# 							Spanish (1245)</option>
# <option label="German (927)" value="150">
# 							German (927)</option>
# <option label="Latin (15)" value="246">
# 							Latin (15)</option>
# <option label="Italian (138)" value="202">
# 							Italian (138)</option>
# <option label="Chinese (191)" value="79">
# 							Chinese (191)</option>
# <option label="Russian (21)" value="365">
# 							Russian (21)</option>
# <option label="Japanese (47)" value="205">
# 							Japanese (47)</option>
# <option label="Dutch; Flemish (13)" value="116">
# 							Dutch; Flemish (13)</option>
# <option label="Afar (1)" value="1">
# 							Afar (1)</option>
# <option label="Afrikaans (5)" value="9">
# 							Afrikaans (5)</option>
# <option label="Albanian (1)" value="13">
# 							Albanian (1)</option>
# <option label="Arabic (23)" value="21">
# 							Arabic (23)</option>
# <option label="Basque (1)" value="44">
# 							Basque (1)</option>
# <option label="Catalan (4)" value="71">
# 							Catalan (4)</option>
# <option label="Classical Syriac (1)" value="416">
# 							Classical Syriac (1)</option>
# <option label="Croatian (3)" value="181">
# 							Croatian (3)</option>
# <option label="Czech (5)" value="101">
# 							Czech (5)</option>
# <option label="Danish (2)" value="103">
# 							Danish (2)</option>
# <option label="English, Middle (1100-1500) (1)" value="124">
# 							English, Middle (1100-1500) (1)</option>
# <option label="English, Old (ca. 450-1100) (1)" value="18">
# 							English, Old (ca. 450-1100) (1)</option>
# <option label="Esperanto (2)" value="125">
# 							Esperanto (2)</option>
# <option label="Filipino; Pilipino (1)" value="133">
# 							Filipino; Pilipino (1)</option>
# <option label="Finnish (25)" value="134">
# 							Finnish (25)</option>
# <option label="German, Middle High (ca. 1050-1500) (1)" value="157">
# 							German, Middle High (ca. 1050-1500) (1)</option>
# <option label="Greek, Ancient (to 1453) (15)" value="163">
# 							Greek, Ancient (to 1453) (15)</option>
# <option label="Greek, Modern (1453-) (8)" value="164">
# 							Greek, Modern (1453-) (8)</option>
# <option label="Hebrew (12)" value="173">
# 							Hebrew (12)</option>
# <option label="Hindi (1)" value="177">
# 							Hindi (1)</option>
# <option label="Hungarian (5)" value="183">
# 							Hungarian (5)</option>
# <option label="Icelandic (1)" value="187">
# 							Icelandic (1)</option>
# <option label="Irish (10)" value="154">
# 							Irish (10)</option>
# <option label="Korean (54)" value="231">
# 							Korean (54)</option>
# <option label="Lithuanian (1)" value="251">
# 							Lithuanian (1)</option>
# <option label="Malay (1)" value="274">
# 							Malay (1)</option>
# <option label="Multiple languages (13)" value="292">
# 							Multiple languages (13)</option>
# <option label="Nepali (1)" value="308">
# 							Nepali (1)</option>
# <option label="No linguistic content (2)" value="486">
# 							No linguistic content (2)</option>
# <option label="Norwegian (5)" value="317">
# 							Norwegian (5)</option>
# <option label="Official Aramaic; Imperial Aramaic (700-300 BCE) (1)" value="22">
# 							Official Aramaic; Imperial Aramaic (700-300 BCE) (1)</option>
# <option label="Persian (1)" value="343">
# 							Persian (1)</option>
# <option label="Polish (189)" value="347">
# 							Polish (189)</option>
# <option label="Portuguese (33)" value="349">
# 							Portuguese (33)</option>
# <option label="Romance languages (1)" value="359">
# 							Romance languages (1)</option>
# <option label="Romanian (5)" value="362">
# 							Romanian (5)</option>
# <option label="Romansh (1)" value="360">
# 							Romansh (1)</option>
# <option label="Sanskrit (1)" value="372">
# 							Sanskrit (1)</option>
# <option label="Scots (7)" value="377">
# 							Scots (7)</option>
# <option label="Scottish Gaelic (4)" value="153">
# 							Scottish Gaelic (4)</option>
# <option label="Slovak (1)" value="388">
# 							Slovak (1)</option>
# <option label="Slovenian (1)" value="389">
# 							Slovenian (1)</option>
# <option label="Swedish (89)" value="415">
# 							Swedish (89)</option>
# <option label="Tahitian (1)" value="418">
# 							Tahitian (1)</option>
# <option label="Tamil (2)" value="420">
# 							Tamil (2)</option>
# <option label="Tetum (1)" value="425">
# 							Tetum (1)</option>
# <option label="Thai (1)" value="428">
# 							Thai (1)</option>
# <option label="Tibetan (1)" value="429">
# 							Tibetan (1)</option>
# <option label="Turkish (6)" value="446">
# 							Turkish (6)</option>
# <option label="Ukrainian (6)" value="454">
# 							Ukrainian (6)</option>
# <option label="Undetermined (5)" value="456">
# 							Undetermined (5)</option>
# <option label="Urdu (1)" value="457">
# 							Urdu (1)</option>
# <option label="Welsh (3)" value="468">
# 							Welsh (3)</option>
# <option label="Western Frisian (1)" value="142">
# 							Western Frisian (1)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="">Formato</label>
# <select class="form-control" id="filterFormat" name="format">
# <option label="All" value="">
# 							All</option>
# <option label="Paperback" value="1">
# 							Paperback</option>
# <option label="Hardback" value="2">
# 							Hardback</option>
# <option label="Audio" value="3">
# 							Audio</option>
# <option label="Baby Books" value="4">
# 							Baby Books</option>
# <option label="Digital" value="5">
# 							Digital</option>
# <option label="Maps" value="6">
# 							Maps</option>
# <option label="Stationery" value="7">
# 							Stationery</option>
# <option label="Toys" value="8">
# 							Toys</option>
# </select>
# </div>
# <div class="form-group padded-btn-wrap">
# <button class="btn btn-primary" type="submit">
# 					Buscar</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="main-content bestseller-page">
# <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filtrar tu búsqueda">Filtrar tu búsqueda</a>
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>
# <div class="head-block">
# <div class="search-info left-content" id="search-info">
#                 Mostrando 1 a 30 de <span class="search-count">1.000</span> resultados</div>
# <div class="right-content">
# <ul class="pagination pagination-sm responsive-pagination">
# <li class="active"><a>1</a></li>
# <li><a href="/es/bestsellers?page=2">2</a></li>
# <li><a href="/es/bestsellers?page=3">3</a></li>
# <li><a href="/es/bestsellers?page=4">4</a></li>
# <li><a href="/es/bestsellers?page=5">5</a></li>
# <li class="next" id="next-top"><a href="/es/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# <div class="content-block">
# <div class="block-wrap search no-heading">
# <div class="block">
# <div class="tab-wrap module type-book grid tab--2 tab-active">
# <div class="tab">
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959" itemprop="url">
# <img alt="How to Paint Without a Brush" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4197/9781419761959.jpg"/>
# </a>
# </div>
# <meta content="9781419761959" itemprop="isbn"/>
# <meta content="How to Paint Without a Brush" itemprop="name"/>
# <meta content="Red Hong Yi" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959">
#                     How to Paint Without a Brush<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Red-Hong-Yi" itemprop="author">Red Hong Yi</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">11 May 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">31,00 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781419761959" data-price="31.00" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781419761959" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
# <img alt="Atomic Habits" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
# </a>
# </div>
# <meta content="9781847941831" itemprop="isbn"/>
# <meta content="Atomic Habits" itemprop="name"/>
# <meta content="James Clear" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831">
#                     Atomic Habits<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/James-Clear" itemprop="author">James Clear</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Atomic Habits" href="/es/Atomic-Habits-James-Clear/9781847941831">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Nov 2018</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">21,40 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">22,00 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                         Más bajo</a>:
#                                     <span class="price-save">
#                                         20,87 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781847941831" data-price="21.40" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Young-Forever-Mark-Hyman/9781399716307" itemprop="url">
# <img alt="Young Forever" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399716307.jpg"/>
# </a>
# </div>
# <meta content="9781399716307" itemprop="isbn"/>
# <meta content="Young Forever" itemprop="name"/>
# <meta content="Mark Hyman" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Young-Forever-Mark-Hyman/9781399716307">
#                     Young Forever<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Mark-Hyman" itemprop="author">Mark Hyman</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">16 Feb 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">21,91 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399716307" data-price="21.91" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399716307" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771" itemprop="url">
# <img alt="Things We Hide From The Light" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399713771.jpg"/>
# </a>
# </div>
# <meta content="9781399713771" itemprop="isbn"/>
# <meta content="Things We Hide From The Light" itemprop="name"/>
# <meta content="Lucy Score" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
#                     Things We Hide From The Light<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Lucy-Score" itemprop="author">Lucy Score</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Things We Hide From The Light" href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Feb 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">14,32 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399713771" data-price="14.32" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399713771" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
# <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
# </a>
# </div>
# <meta content="9781471156267" itemprop="isbn"/>
# <meta content="It Ends With Us: The most heartbreaking novel you'll ever read" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                     It Ends With Us: The most heartbreaking novel you'll ever read<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Aug 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">12,58 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781471156267" data-price="12.58" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061" itemprop="url">
# <img alt="The Letters I Will Never Send" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5299/9781529901061.jpg"/>
# </a>
# </div>
# <meta content="9781529901061" itemprop="isbn"/>
# <meta content="The Letters I Will Never Send" itemprop="name"/>
# <meta content="Isabella Dorta" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061">
#                     The Letters I Will Never Send<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Isabella-Dorta" itemprop="author">Isabella Dorta</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Letters I Will Never Send" href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star"></span>
# <span class="star"></span>
# <span class="star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">16 Mar 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">18,50 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781529901061" data-price="18.50" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529901061" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Parenting-Map-Shefali-Tsabary/9780063267954" itemprop="url">
# <img alt="The Parenting Map" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/0632/9780063267954.jpg"/>
# </a>
# </div>
# <meta content="9780063267954" itemprop="isbn"/>
# <meta content="The Parenting Map" itemprop="name"/>
# <meta content="Shefali Tsabary" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Parenting-Map-Shefali-Tsabary/9780063267954">
#                     The Parenting Map<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Shefali-Tsabary" itemprop="author">Shefali Tsabary</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Parenting Map" href="/es/Parenting-Map-Shefali-Tsabary/9780063267954">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Apr 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">31,55 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780063267954" data-price="31.55" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780063267954" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/UPROAR-Alice-Loxton/9781785789540" itemprop="url">
# <img alt="UPROAR!" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7857/9781785789540.jpg"/>
# <div class="savings-splat">
#                         Ahorra<br/>6%</div>
# </a>
# </div>
# <meta content="9781785789540" itemprop="isbn"/>
# <meta content="UPROAR!" itemprop="name"/>
# <meta content="Alice Loxton" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/UPROAR-Alice-Loxton/9781785789540">
#                     UPROAR!<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Alice-Loxton" itemprop="author">Alice Loxton</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for UPROAR!" href="/es/UPROAR-Alice-Loxton/9781785789540">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Mar 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">28,51 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">30,50 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
# ...
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782" itemprop="url">
# <img alt="The Adventure Zone: The Eleventh Hour" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/2507/9781250793782.jpg"/>
# </a>
# </div>
# <meta content="9781250793782" itemprop="isbn"/>
# <meta content="The Adventure Zone: The Eleventh Hour" itemprop="name"/>
# <meta content="Clint McElroy" itemprop="contributor"/>
# <meta content="Griffin McElroy" itemprop="contributor"/>
# <meta content="Travis McElroy" itemprop="contributor"/>
# <meta content="Justin McElroy" itemprop="contributor"/>
# <meta content="Carey Pietsch" itemprop="contributor"/>
# <meta content="Carey Pietsch" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782">
#                     The Adventure Zone: The Eleventh Hour<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Clint-McElroy" itemprop="author">Clint McElroy</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Adventure Zone: The Eleventh Hour" href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Feb 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">19,77 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781250793782" data-price="19.77" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781250793782" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script></div>
# <div class="foot-block">
# <div class="right-content">
# <ul class="pagination pagination-sm">
# <li class="active"><a>1</a></li>
# <li><a href="/es/bestsellers?page=2">2</a></li>
# <li><a href="/es/bestsellers?page=3">3</a></li>
# <li><a href="/es/bestsellers?page=4">4</a></li>
# <li><a href="/es/bestsellers?page=5">5</a></li>
# <li class="next" id="next-bottom"><a href="/es/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# </div></div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/es/newsletter/add">
# <div class="form-group">
# <input aria-label="Dirección de correo electrónico para suscribirte a nuestro Newsletter" class="form-control" name="newsletterEmailAddress" placeholder="Correo electrónico" spellcheck="false" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                 Sign up now</button>
# </div>
# </form>
# </div>
# </div>
# </div></div>
# <div class="footer-social-wrap">
# <h4>
#             Síguenos</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Descubre</h4>
# <ul>
# <li><a href="/es/about-us" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/sitemap">
#                             Mapa del sitio</a></li>
# <li><a href="/es/bookmarks">
#                             Marcapáginas</a></li>
# <li><a href="/es/blog">
#                             Book Blog</a></li>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                     Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>¿En qué podemos ayudarte?</h4>
# <ul>
# <li>
# <a href="/es/help" rel="nofollow">
#                                 Ayuda</a>
# </li>
# <li>
# <a href="/es/contactus">
#                                 Contáctanos</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 ¿Dónde está mi pedido? </a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 Envíos internacionales</a>
# </li>
# <li>
# <a href="/es/cancelorder" rel="nofollow">
#                                 Cancelar mi pedido</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                 Devolver mi pedido</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Trabaja con nosotros</h4>
# <ul>
# <li><a href="/es/affiliate">
#                             Afiliados</a></li>
# <li><a href="/es/jobs">
#                             Trabajar en Book Depository</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Información importante</h4>
# <ul>
# <li>
# <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Reclamaciones</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Política de privacidad</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Términos y Condiciones </a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                     Iniciar sesión/Crear cuenta</a></li>
# <li><a href="/es/track">
#                             Mis pedidos</a></li>
# <li><a href="/es/contactus">
#                             Contáctanos</a></li>
# <li><a href="/es/help">
#                             Ayuda</a></li>
# <li><a href="/es/about-us" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Términos y Condiciones </a></li>
# <li><a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Política de privacidad</a></li>
# <li><a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>Aceptamos los siguientes métodos de pago </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2022-8', requestTime='0.04 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='90.75.129.53', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Tue Feb 28 08:16:34 UTC 2023, cacheEnabled=true}}">
#                         © 2023
#                         The Book Depository Ltd.UK<br/>Número de registro de la empresa: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Comprar","bd_js_too_long_for_shipping_label":"Eso es demasiado largo para nuestras etiquetas de envío","bd_js_why_are_you_leaving":"¿Por qué te vas?","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Eso es demasiado largo","bd_js_could_not_find_address_try_again":"No pudimos encontrar la dirección. Inténtalo de nuevo","bd_js_lack_of_reviews":"Falta de opiniones","bd_saving_percent_off":"Ahorra&lt;br&gt;{0}%","bd_js_missing_book_information":"Falta la información del libro o la portada","bd_js_total_basket_count":"{0, plural, one {Tienes &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;producto&lt;/span&gt;&lt;/b&gt; en el carrito} other {Tienes &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;productos&lt;/span&gt;&lt;/b&gt; en el carrito}}","bd_js_total_cost":"Costo total: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"mostrar menos","bd_try_abe_books":"Prueba AbeBooks","bd_js_item_added_to_your_basket":"Se agregó el producto en el carrito","bd_js_quick_view":"Vista rápida","bd_js_lack_of_inside_images":"Falta de imágenes internas","bd_rrp":"PVPR","bd_link_prefix":"/es","bd_js_wrong_book_information":"Información o portada incorrecta del libro","bd_js_unable_get_address_enter_manually":"No podemos obtener la dirección. Ingrésala manualmente:","bd_js_keep_typing_to_refine_search_results":"Sigue escribiendo para ajustar los resultados de búsqueda","bd_pre_order":"Comprar en preventa","bd_js_top_categories":"Categorías principales","bd_price_save":"Ahorra {0}","bd_notify_me":"Notificarme","bd_js_name_only_letters":"El nombre completo solo puede contener letras","bd_js_show_more":"mostrar más","bd_js_enter_valid_email_address":"Ingresa una dirección de correo electrónico válida","bd_js_delivery_time":"Hora de entrega","bd_js_enter_address_manually":"Ingresar la dirección manualmente","bd_js_more_categories":"Más categorías","bd_30_day_low_price_carousel":"Más bajo","bd_js_continue_shopping":"Seguir comprando","bd_js_account_and_help":"Cuenta y ayuda","bd_js_price":"Precio","bd_js_basket_checkout":"Carrito/proceder al pago","bd_add_to_basket":"Añadir a la cesta","bd_js_enter_first_last_name":"Ingresa un nombre y apellido","bd_js_please_enter_your":"Ingresa tu"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los libros más vendidos)
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." name="description"/>
# <meta content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <link href="https://www.bookdepository.com/es/bestsellers" rel="canonical"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/bestsellers" hreflang="es" rel="alternate"/>
# <link href="/es/bestsellers?page=2" rel="next"/>
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# <script async="" src="https://assets.adobedtm.com/4dfb8f1b14f8/eb478f5c633f/launch-8ffac2b531d7.min.js">
# </script>
# </head>
# <body class="">
# <div aria-live="polite" class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>Usamos cookies para mejorar este sitio</h2>
# <p>Las cookies se utilizan para brindar, analizar y mejorar nuestros servicios; proporcionar herramientas de chat; y<br/>mostrarte contenido relevante de publicidad. Para más información sobre nuestro uso de cookies, lee nuestra sección de <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Ayuda sobre Cookies</a></p><h2>¿Aceptas las cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <button class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Aceptar cookies</button>
# <button class="btn btn-sm btn-secondary btn-manage" href="#" rel="nofollow">
#                 Administrar cookies</button>
# </div>
# </div>
# <div aria-live="polite" class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Preferencias de cookies</h2>
# <p>Usamos cookies y herramientas similares que son necesarias para permitirte realizar compras, incluidas las que utilizan terceros autorizados (colectivamente denominadas “cookies”) para los fines que se describen a continuación.
#      <br/>Para obtener más información acerca de cómo nosotros y los terceros autorizados usamos las cookies y cómo cambiar tu configuración, consulta el <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>. Las elecciones que realices aquí se aplicarán a tu interacción con este servicio en este dispositivo.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Indispensable</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>Usamos cookies para brindar nuestros servicios, </span>
# <div>
# <div class="additionalInfo wrapping-space">por ejemplo, para realizar un seguimiento de los artículos almacenados en tu canasta de compras, prevenir actividades fraudulentas, mejorar la seguridad de nuestros servicios, realizar un seguimiento de tus preferencias específicas (como preferencias de moneda o idioma) y mostrar características, productos y servicios que puedan ser de tu interés. Debido a que usamos cookies para brindarte nuestros servicios, estas no se pueden desactivar cuando se usan con este fin.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <label for="performanceCheckBox"><h2>Desempeño y analítica</h2></label>
# </div>
# <div class="cookie-management-category-check">
# <span aria-hidden="true" class="is-enabled">ACTIVADO</span>
# <span aria-hidden="true" class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="performanceCheckBox" role="switch" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si estás de acuerdo, utilizaremos cookies para comprender cómo los clientes utilizan nuestros servicios</span>
# <div>
# <div class="additionalInfo wrapping-space">(por ejemplo, midiendo visitas al sitio) para que podamos hacer mejoras. Usamos cookies para realizar investigaciones y diagnósticos a fin de mejorar el contenido, los productos y los servicios, y para evaluar y analizar el desempeño de nuestros servicios.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <label for="advertisingCheckBox"><h2>Publicidad</h2></label>
# </div>
# <div class="cookie-management-category-check">
# <span aria-hidden="true" class="is-enabled">ACTIVADO</span>
# <span aria-hidden="true" class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" role="switch" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si estás de acuerdo, utilizaremos cookies para complementar tu experiencia de compra, tal como se describe en nuestro <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de Cookies</a></span>
# <div>
# <div class="additionalInfo wrapping-space">y ofrecerte ciertos tipos de anuncios relevantes a tus intereses en Book Depository. Esto incluye el uso de cookies de terceros con el propósito de mostrar y medir anuncios (consulta el aviso de <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Anuncios basados en intereses</a> para conocer cómo usamos las cookies para publicar anuncios basados en intereses), medir la efectividad de los anuncios y, según sea necesario, para que el tercero realice servicios en nombre de Book Depository.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <button class="btn btn-sm btn-secondary btn-cancel" href="#" rel="nofollow">
#                 Cancelar</button>
# <button class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Guardar configuración</button>
# </div>
# </div>
# <div hidden="" id="main-data-container">
# <div class="metrics_data_events" data-metric-event="PAGE_LOADED" hidden=""></div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a></li>
# <li class="mob-nav-account"><a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a></li>
# <li class="mob-nav-account"><a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/es/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/es/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/es/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Buscar libros por palabra clave / título / autor / ISBN" class="text-input" name="searchTerm" placeholder="Buscar libros por palabra clave / título / autor / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Buscar</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 Todas las categorías</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Menú principal</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/es/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/es/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/es/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/es/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/es/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Libros infantiles por edades</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/es/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/es/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/es/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/es/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/es/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Top Authors">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Bestselling Series">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Books By Language">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/es/bestsellers">Los más vendidos</a></li>
# <li class="mob-nav-shop"><a href="/es/comingsoon">Próximamente </a></li>
# <li class="mob-nav-shop"><a href="/es/top-new-releases">Nuevos lanzamientos</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         Español</a>
# <div class="metrics_data_container" data-datalayer-reader="locale" data-page-locale="es_ES" hidden=""></div>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Idiomas</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             Inglés (English)</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Español</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="Español">
# <select id="selectLanguage" name="selectLanguage">
# <option value="en_US">
#                     English</option>
# <option selected="selected" value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/es/bestsellers" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/es/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="metrics_data_container" data-datalayer-reader="loginStatus" data-val="guest" hidden=""></div>
# <div class="content-wrap">
# <div class="sidebar">
# <div class="sidebar-section search-filter">
# <h2>Filtrar tu búsqueda</h2>
# <div class="sidebar-section-content search-filter-sidebar">
# <form action="/es/bestsellers" class="filter-menu" method="get">
# <div class="form-group">
# <label for="searchTerm">Palabra clave</label>
# <input class="form-control" name="searchTerm" spellcheck="false" type="text" value=""/>
# </div>
# <input name="searchSortBy" type="hidden" value=""/>
# <input name="category" type="hidden" value=""/>
# <div class="form-group">
# <label for="filter_price">Precio</label>
# <select class="form-control" id="filterPrice" name="price">
# <option label="All" value="">
# 							All</option>
# <option label="Under €15" value="low">
# 							Under €15</option>
# <option label="€15 to €30" value="med">
# 							€15 to €30</option>
# <option label="€30 +" value="high">
# 							€30 +</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_availability">Disponibilidad</label>
# <select class="form-control" id="filterAvailability" name="availability">
# <option label="All" value="">
# 							All</option>
# <option label="In stock (62634)" value="1">
# 							In stock (62634)</option>
# <option label="Pre-order (2051)" value="2">
# 							Pre-order (2051)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_search_lang">Idioma</label>
# <select class="form-control" id="filterLang" name="searchLang">
# <option label="All" value="">
# 							All</option>
# <option label="English (61340)" value="123">
# 							English (61340)</option>
# <option label="French (333)" value="137">
# 							French (333)</option>
# <option label="Spanish (1248)" value="404">
# 							Spanish (1248)</option>
# <option label="German (939)" value="150">
# 							German (939)</option>
# <option label="Latin (15)" value="246">
# 							Latin (15)</option>
# <option label="Italian (135)" value="202">
# 							Italian (135)</option>
# <option label="Chinese (187)" value="79">
# 							Chinese (187)</option>
# <option label="Russian (16)" value="365">
# 							Russian (16)</option>
# <option label="Japanese (42)" value="205">
# 							Japanese (42)</option>
# <option label="Dutch; Flemish (13)" value="116">
# 							Dutch; Flemish (13)</option>
# <option label="Afar (1)" value="1">
# 							Afar (1)</option>
# <option label="Afrikaans (5)" value="9">
# 							Afrikaans (5)</option>
# <option label="Arabic (25)" value="21">
# 							Arabic (25)</option>
# <option label="Basque (1)" value="44">
# 							Basque (1)</option>
# <option label="Bulgarian (1)" value="65">
# 							Bulgarian (1)</option>
# <option label="Catalan (3)" value="71">
# 							Catalan (3)</option>
# <option label="Classical Syriac (1)" value="416">
# 							Classical Syriac (1)</option>
# <option label="Croatian (3)" value="181">
# 							Croatian (3)</option>
# <option label="Czech (5)" value="101">
# 							Czech (5)</option>
# <option label="Danish (1)" value="103">
# 							Danish (1)</option>
# <option label="English, Middle (1100-1500) (1)" value="124">
# 							English, Middle (1100-1500) (1)</option>
# <option label="English, Old (ca. 450-1100) (1)" value="18">
# 							English, Old (ca. 450-1100) (1)</option>
# <option label="Esperanto (2)" value="125">
# 							Esperanto (2)</option>
# <option label="Filipino; Pilipino (1)" value="133">
# 							Filipino; Pilipino (1)</option>
# <option label="Finnish (20)" value="134">
# 							Finnish (20)</option>
# <option label="German, Middle High (ca. 1050-1500) (1)" value="157">
# 							German, Middle High (ca. 1050-1500) (1)</option>
# <option label="Greek, Ancient (to 1453) (9)" value="163">
# 							Greek, Ancient (to 1453) (9)</option>
# <option label="Greek, Modern (1453-) (7)" value="164">
# 							Greek, Modern (1453-) (7)</option>
# <option label="Hebrew (9)" value="173">
# 							Hebrew (9)</option>
# <option label="Hindi (1)" value="177">
# 							Hindi (1)</option>
# <option label="Hungarian (4)" value="183">
# 							Hungarian (4)</option>
# <option label="Irish (10)" value="154">
# 							Irish (10)</option>
# <option label="Korean (49)" value="231">
# 							Korean (49)</option>
# <option label="Lithuanian (1)" value="251">
# 							Lithuanian (1)</option>
# <option label="Malay (1)" value="274">
# 							Malay (1)</option>
# <option label="Malayalam (1)" value="268">
# 							Malayalam (1)</option>
# <option label="Maori (2)" value="270">
# 							Maori (2)</option>
# <option label="Multiple languages (13)" value="292">
# 							Multiple languages (13)</option>
# <option label="Nepali (1)" value="308">
# 							Nepali (1)</option>
# <option label="No linguistic content (1)" value="486">
# 							No linguistic content (1)</option>
# <option label="Norwegian (9)" value="317">
# 							Norwegian (9)</option>
# <option label="Official Aramaic; Imperial Aramaic (700-300 BCE) (1)" value="22">
# 							Official Aramaic; Imperial Aramaic (700-300 BCE) (1)</option>
# <option label="Persian (1)" value="343">
# 							Persian (1)</option>
# <option label="Polish (171)" value="347">
# 							Polish (171)</option>
# <option label="Portuguese (36)" value="349">
# 							Portuguese (36)</option>
# <option label="Romance languages (1)" value="359">
# 							Romance languages (1)</option>
# <option label="Romanian (10)" value="362">
# 							Romanian (10)</option>
# <option label="Romansh (1)" value="360">
# 							Romansh (1)</option>
# <option label="Sanskrit (1)" value="372">
# 							Sanskrit (1)</option>
# <option label="Scots (7)" value="377">
# 							Scots (7)</option>
# <option label="Scottish Gaelic (5)" value="153">
# 							Scottish Gaelic (5)</option>
# <option label="Slovak (2)" value="388">
# 							Slovak (2)</option>
# <option label="Slovenian (1)" value="389">
# 							Slovenian (1)</option>
# <option label="Swedish (89)" value="415">
# 							Swedish (89)</option>
# <option label="Tahitian (1)" value="418">
# 							Tahitian (1)</option>
# <option label="Tamil (2)" value="420">
# 							Tamil (2)</option>
# <option label="Tetum (1)" value="425">
# 							Tetum (1)</option>
# <option label="Thai (1)" value="428">
# 							Thai (1)</option>
# <option label="Tibetan (1)" value="429">
# 							Tibetan (1)</option>
# <option label="Turkish (6)" value="446">
# 							Turkish (6)</option>
# <option label="Ukrainian (6)" value="454">
# 							Ukrainian (6)</option>
# <option label="Undetermined (5)" value="456">
# 							Undetermined (5)</option>
# <option label="Urdu (1)" value="457">
# 							Urdu (1)</option>
# <option label="Welsh (2)" value="468">
# 							Welsh (2)</option>
# <option label="Western Frisian (1)" value="142">
# 							Western Frisian (1)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="">Formato</label>
# <select class="form-control" id="filterFormat" name="format">
# <option label="All" value="">
# 							All</option>
# <option label="Paperback" value="1">
# 							Paperback</option>
# <option label="Hardback" value="2">
# 							Hardback</option>
# <option label="Audio" value="3">
# 							Audio</option>
# <option label="Baby Books" value="4">
# 							Baby Books</option>
# <option label="Digital" value="5">
# 							Digital</option>
# <option label="Maps" value="6">
# 							Maps</option>
# <option label="Stationery" value="7">
# 							Stationery</option>
# <option label="Toys" value="8">
# 							Toys</option>
# </select>
# </div>
# <div class="form-group padded-btn-wrap">
# <button class="btn btn-primary" type="submit">
# 					Buscar</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="main-content bestseller-page">
# <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filtrar tu búsqueda">Filtrar tu búsqueda</a>
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>
# <div class="head-block">
# <div class="search-info left-content" id="search-info">
#                 Mostrando 1 a 30 de <span class="search-count">1.000</span> resultados</div>
# <div class="right-content">
# <ul class="pagination pagination-sm responsive-pagination">
# <li class="active"><a>1</a></li>
# <li><a href="/es/bestsellers?page=2">2</a></li>
# <li><a href="/es/bestsellers?page=3">3</a></li>
# <li><a href="/es/bestsellers?page=4">4</a></li>
# <li><a href="/es/bestsellers?page=5">5</a></li>
# <li class="next" id="next-top"><a href="/es/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# <div class="content-block">
# <div class="block-wrap search no-heading">
# <div class="block">
# <div class="tab-wrap module type-book grid tab--2 tab-active">
# <div class="tab">
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959" itemprop="url">
# <img alt="How to Paint Without a Brush" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4197/9781419761959.jpg"/>
# </a>
# </div>
# <meta content="9781419761959" itemprop="isbn"/>
# <meta content="How to Paint Without a Brush" itemprop="name"/>
# <meta content="Red Hong Yi" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959">
#                     How to Paint Without a Brush<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Red-Hong-Yi" itemprop="author">Red Hong Yi</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">11 May 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">31,00 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781419761959" data-price="31.00" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781419761959" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
# <img alt="Atomic Habits" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
# </a>
# </div>
# <meta content="9781847941831" itemprop="isbn"/>
# <meta content="Atomic Habits" itemprop="name"/>
# <meta content="James Clear" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831">
#                     Atomic Habits<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/James-Clear" itemprop="author">James Clear</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Atomic Habits" href="/es/Atomic-Habits-James-Clear/9781847941831">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Nov 2018</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">20,93 €</span>
# <span class="rrp-label">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                         PVPR</a>:
#                                 </span>
#
#                              <span class="rrp omnibus">22,00 €</span>
# </p>
# <p class="price-save">
# <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                         Más bajo</a>:
#                                     <span class="price-save">
#                                         20,93 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781847941831" data-price="20.93" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Young-Forever-Mark-Hyman/9781399716307" itemprop="url">
# <img alt="Young Forever" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399716307.jpg"/>
# </a>
# </div>
# <meta content="9781399716307" itemprop="isbn"/>
# <meta content="Young Forever" itemprop="name"/>
# <meta content="Mark Hyman" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Young-Forever-Mark-Hyman/9781399716307">
#                     Young Forever<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Mark-Hyman" itemprop="author">Mark Hyman</a>
# </p>
# <div class="rating-wrap">
# </div>
# <p class="published" itemprop="datePublished">16 Feb 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">21,40 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399716307" data-price="21.40" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399716307" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061" itemprop="url">
# <img alt="The Letters I Will Never Send" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5299/9781529901061.jpg"/>
# </a>
# </div>
# <meta content="9781529901061" itemprop="isbn"/>
# <meta content="The Letters I Will Never Send" itemprop="name"/>
# <meta content="Isabella Dorta" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061">
#                     The Letters I Will Never Send<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Isabella-Dorta" itemprop="author">Isabella Dorta</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Letters I Will Never Send" href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star"></span>
# <span class="star"></span>
# <span class="star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">16 Mar 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">23,43 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781529901061" data-price="23.43" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529901061" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771" itemprop="url">
# <img alt="Things We Hide From The Light" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399713771.jpg"/>
# </a>
# </div>
# <meta content="9781399713771" itemprop="isbn"/>
# <meta content="Things We Hide From The Light" itemprop="name"/>
# <meta content="Lucy Score" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
#                     Things We Hide From The Light<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Lucy-Score" itemprop="author">Lucy Score</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Things We Hide From The Light" href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Feb 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">13,03 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399713771" data-price="13.03" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399713771" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Parenting-Map-Shefali-Tsabary/9780063267954" itemprop="url">
# <img alt="The Parenting Map" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/0632/9780063267954.jpg"/>
# </a>
# </div>
# <meta content="9780063267954" itemprop="isbn"/>
# <meta content="The Parenting Map" itemprop="name"/>
# <meta content="Shefali Tsabary" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Parenting-Map-Shefali-Tsabary/9780063267954">
#                     The Parenting Map<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Shefali-Tsabary" itemprop="author">Shefali Tsabary</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Parenting Map" href="/es/Parenting-Map-Shefali-Tsabary/9780063267954">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Apr 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">31,51 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780063267954" data-price="31.51" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780063267954" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
# <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
# </a>
# </div>
# <meta content="9781471156267" itemprop="isbn"/>
# <meta content="It Ends With Us: The most heartbreaking novel you'll ever read" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                     It Ends With Us: The most heartbreaking novel you'll ever read<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Aug 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">12,58 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781471156267" data-price="12.58" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/UPROAR-Alice-Loxton/9781785789540" itemprop="url">
# <img alt="UPROAR!" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7857/9781785789540.jpg"/>
# </a>
# </div>
# <meta content="9781785789540" itemprop="isbn"/>
# <meta content="UPROAR!" itemprop="name"/>
# <meta content="Alice Loxton" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/UPROAR-Alice-Loxton/9781785789540">
#                     UPROAR!<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Alice-Loxton" itemprop="author">Alice Loxton</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for UPROAR!" href="/es/UPROAR-Alice-Loxton/9781785789540">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Mar 2023</p>
# <p class="format">Hardback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">30,50 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781785789540" data-price="30.50" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785789540" rel="nofollow">
#                         Comprar en preventa</a>
# </div>
# </div>
# </div>
# ...
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782" itemprop="url">
# <img alt="The Adventure Zone: The Eleventh Hour" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/2507/9781250793782.jpg"/>
# </a>
# </div>
# <meta content="9781250793782" itemprop="isbn"/>
# <meta content="The Adventure Zone: The Eleventh Hour" itemprop="name"/>
# <meta content="Clint McElroy" itemprop="contributor"/>
# <meta content="Griffin McElroy" itemprop="contributor"/>
# <meta content="Travis McElroy" itemprop="contributor"/>
# <meta content="Justin McElroy" itemprop="contributor"/>
# <meta content="Carey Pietsch" itemprop="contributor"/>
# <meta content="Carey Pietsch" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782">
#                     The Adventure Zone: The Eleventh Hour<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/es/author/Clint-McElroy" itemprop="author">Clint McElroy</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Adventure Zone: The Eleventh Hour" href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Feb 2023</p>
# <p class="format">Paperback</p>
# <div class="price-wrap omnibus">
# <p class="price">
# <span class="sale-price">20,11 €</span>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781250793782" data-price="20.11" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781250793782" rel="nofollow">
#                         Añadir a la cesta</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script></div>
# <div class="foot-block">
# <div class="right-content">
# <ul class="pagination pagination-sm">
# <li class="active"><a>1</a></li>
# <li><a href="/es/bestsellers?page=2">2</a></li>
# <li><a href="/es/bestsellers?page=3">3</a></li>
# <li><a href="/es/bestsellers?page=4">4</a></li>
# <li><a href="/es/bestsellers?page=5">5</a></li>
# <li class="next" id="next-bottom"><a href="/es/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# </div></div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/es/newsletter/add">
# <div class="form-group">
# <input aria-label="Dirección de correo electrónico para suscribirte a nuestro Newsletter" class="form-control" name="newsletterEmailAddress" placeholder="Correo electrónico" spellcheck="false" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                 Sign up now</button>
# </div>
# </form>
# </div>
# </div>
# </div></div>
# <div class="footer-social-wrap">
# <h4>
#             Síguenos</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Descubre</h4>
# <ul>
# <li><a href="/es/about-us" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/sitemap">
#                             Mapa del sitio</a></li>
# <li><a href="/es/bookmarks">
#                             Marcapáginas</a></li>
# <li><a href="/es/blog">
#                             Book Blog</a></li>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                     Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>¿En qué podemos ayudarte?</h4>
# <ul>
# <li>
# <a href="/es/help" rel="nofollow">
#                                 Ayuda</a>
# </li>
# <li>
# <a href="/es/contactus">
#                                 Contáctanos</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 ¿Dónde está mi pedido? </a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 Envíos internacionales</a>
# </li>
# <li>
# <a href="/es/cancelorder" rel="nofollow">
#                                 Cancelar mi pedido</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                 Devolver mi pedido</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Trabaja con nosotros</h4>
# <ul>
# <li><a href="/es/affiliate">
#                             Afiliados</a></li>
# <li><a href="/es/jobs">
#                             Trabajar en Book Depository</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Información importante</h4>
# <ul>
# <li>
# <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Reclamaciones</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Política de privacidad</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Términos y Condiciones </a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                     Iniciar sesión/Crear cuenta</a></li>
# <li><a href="/es/track">
#                             Mis pedidos</a></li>
# <li><a href="/es/contactus">
#                             Contáctanos</a></li>
# <li><a href="/es/help">
#                             Ayuda</a></li>
# <li><a href="/es/about-us" rel="nofollow">
#                             Conócenos</a></li>
# <li><a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Términos y Condiciones </a></li>
# <li><a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Política de privacidad</a></li>
# <li><a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>Aceptamos los siguientes métodos de pago </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2022-8', requestTime='0.05 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='2.139.130.195', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Mon Feb 27 08:25:54 UTC 2023, cacheEnabled=true}}">
#                         © 2023
#                         The Book Depository Ltd.UK<br/>Número de registro de la empresa: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Comprar","bd_js_too_long_for_shipping_label":"Eso es demasiado largo para nuestras etiquetas de envío","bd_js_why_are_you_leaving":"¿Por qué te vas?","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Eso es demasiado largo","bd_js_could_not_find_address_try_again":"No pudimos encontrar la dirección. Inténtalo de nuevo","bd_js_lack_of_reviews":"Falta de opiniones","bd_saving_percent_off":"Ahorra&lt;br&gt;{0}%","bd_js_missing_book_information":"Falta la información del libro o la portada","bd_js_total_basket_count":"{0, plural, one {Tienes &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;producto&lt;/span&gt;&lt;/b&gt; en el carrito} other {Tienes &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;productos&lt;/span&gt;&lt;/b&gt; en el carrito}}","bd_js_total_cost":"Costo total: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"mostrar menos","bd_try_abe_books":"Prueba AbeBooks","bd_js_item_added_to_your_basket":"Se agregó el producto en el carrito","bd_js_quick_view":"Vista rápida","bd_js_lack_of_inside_images":"Falta de imágenes internas","bd_rrp":"PVPR","bd_link_prefix":"/es","bd_js_wrong_book_information":"Información o portada incorrecta del libro","bd_js_unable_get_address_enter_manually":"No podemos obtener la dirección. Ingrésala manualmente:","bd_js_keep_typing_to_refine_search_results":"Sigue escribiendo para ajustar los resultados de búsqueda","bd_pre_order":"Comprar en preventa","bd_js_top_categories":"Categorías principales","bd_price_save":"Ahorra {0}","bd_notify_me":"Notificarme","bd_js_name_only_letters":"El nombre completo solo puede contener letras","bd_js_show_more":"mostrar más","bd_js_enter_valid_email_address":"Ingresa una dirección de correo electrónico válida","bd_js_delivery_time":"Hora de entrega","bd_js_enter_address_manually":"Ingresar la dirección manualmente","bd_js_more_categories":"Más categorías","bd_30_day_low_price_carousel":"Más bajo","bd_js_continue_shopping":"Seguir comprando","bd_js_account_and_help":"Cuenta y ayuda","bd_js_price":"Precio","bd_js_basket_checkout":"Carrito/proceder al pago","bd_add_to_basket":"Añadir a la cesta","bd_js_enter_first_last_name":"Ingresa un nombre y apellido","bd_js_please_enter_your":"Ingresa tu"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# ![image](img\html-content-web-scraping.png)

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# ![image](img\attribute-example-for-web-scraping-1536x386.png)

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>

# %%
soup.h1
# Out:
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>

# %% [markdown]
# Eliminamos las etiquetas

# %%
soup.h1.get_text()
# Out:
# 'Los más vendidos — nuestros artículos más populares, actualizados diariamente.'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
soup.a['href']
soup.a.get('href')
# Out:
# '/help/topic/HelpId/53/How-we-use-cookies#helpContent'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
print(soup.h1)
print("")
print("Utilizando método .find()")
print(soup.find('h1'))
# Out:
# Sin utilizar método .find()
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>
#
# Utilizando método .find()
# <h1>Los más vendidos — nuestros artículos más populares, actualizados diariamente.</h1>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all('a')
# Out:
# [<a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Ayuda sobre Cookies</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>,
#  <a class="showLess" role="button">Mostrar menos</a>,
#  <a class="showMore" role="button">Mostrar más</a>,
#  <a class="showLess" role="button">Mostrar menos</a>,
#  <a class="showMore" role="button">Mostrar más</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de Cookies</a>,
#  <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Anuncios basados en intereses</a>,
#  <a class="showLess" role="button">Mostrar menos</a>,
#  <a class="showMore" role="button">Mostrar más</a>,
#  <a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a>,
#  <a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a>,
#  <a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a>,
#  <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
#  <i class="icon-rocket"></i> Envío gratis</a>,
#  <a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>,
#  <a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>,
#  <a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a>,
#  <a class="brand-link" href="/es/">
#  <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/logo.svg"/>
#  </a>,
#  <a class="mobile-basket-btn basket-wrap" href="/es/basket">
#  <span class="item-count" data-item-count="0">0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>,
#  <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
#  <i class="icon-rocket"></i> Envío gratis</a>,
#  <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
#  <i class="icon-rocket"></i> Envío gratis</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>,
#  <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>,
#  <a>Menú principal</a>,
#  <a href="/es/category/2/Art-Photography">
#                                          Art &amp; Photography</a>,
#  <a href="/es/category/3389/Audio-Books">
#                                          Audio Books</a>,
#  <a href="/es/category/213/Biography">
#                                          Biography</a>,
#  <a href="/es/category/928/Business-Finance-Law">
#                                          Business, Finance &amp; Law</a>,
#  <a href="/es/category/2455/Childrens-Books">
#                                          Children's Books</a>,
#  <a href="/es/category/1897/Computing">
#                                          Computing</a>,
#  <a href="/es/category/2942/Crafts-Hobbies">
#                                          Crafts &amp; Hobbies</a>,
#  <a href="/es/category/2616/Crime-Thriller">
#                                          Crime &amp; Thriller</a>,
#  <a href="/es/category/240/Dictionaries-Languages">
#                                          Dictionaries &amp; Languages</a>,
#  <a href="/es/category/3245/Entertainment">
#                                          Entertainment</a>,
#  <a href="/es/category/333/Fiction">
#                                          Fiction</a>,
#  <a href="/es/category/2858/Food-Drink">
#                                          Food &amp; Drink</a>,
#  <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                          Graphic Novels, Anime &amp; Manga</a>,
#  <a href="/es/category/2770/Health">
#                                          Health</a>,
#  <a href="/es/category/2638/History-Archaeology">
#                                          History &amp; Archaeology</a>,
#  <a href="/es/category/2892/Home-Garden">
#                                          Home &amp; Garden</a>,
#  <a href="/es/category/2978/Humour">
#                                          Humour</a>,
#  <a href="/es/category/1279/Medical">
#                                          Medical</a>,
#  <a href="/es/category/2819/Mind-Body-Spirit">
#                                          Mind, Body &amp; Spirit</a>,
#  <a href="/es/category/2985/Natural-History">
#                                          Natural History</a>,
#  <a href="/es/category/2802/Personal-Development">
#                                          Personal Development</a>,
#  <a href="/es/category/283/Poetry-Drama">
#                                          Poetry &amp; Drama</a>,
#  <a href="/es/category/375/Reference">
#                                          Reference</a>,
#  <a href="/es/category/3120/Religion">
#                                          Religion</a>,
#  <a href="/es/category/2630/Romance">
#                                          Romance</a>,
#  <a href="/es/category/1476/Science-Geography">
#                                          Science &amp; Geography</a>,
#  <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                          Science Fiction, Fantasy &amp; Horror</a>,
#  <a href="/es/category/632/Society-Social-Sciences">
#                                          Society &amp; Social Sciences</a>,
#  <a href="/es/category/3013/Sport">
#                                          Sport</a>,
#  <a href="/es/category/3385/Stationery">
#                                          Stationery</a>,
#  <a href="/es/category/3328/Teaching-Resources-Education">
#                                          Teaching Resources &amp; Education</a>,
#  <a href="/es/category/1708/Technology-Engineering">
#                                          Technology &amp; Engineering</a>,
#  <a href="/es/category/3391/Teen-Young-Adult">
#                                          Teen &amp; Young Adult</a>,
#  <a href="/es/category/2967/Transport">
#                                          Transport</a>,
#  <a href="/es/category/3098/Travel-Holiday-Guides">
#                                          Travel &amp; Holiday Guides</a>,
#  <a href="/es/category/3392/Books-for-Ages-0-2">
#                                  Ages 0-2</a>,
#  <a href="/es/category/3393/Books-for-Ages-3-5">
#                                  Ages 3-5</a>,
#  <a href="/es/category/3394/Books-for-Ages-6-8">
#                                  Ages 6-8</a>,
#  <a href="/es/category/3395/Books-for-Ages-9-11">
#                                  Ages 9-11</a>,
#  <a href="/es/category/3391/Teen-Young-Adult">
#                                  Teen &amp; Young Adult</a>,
#  <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
#  <div class="link-text">J. K. Rowling</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/roald-dahl">
#  <div class="link-text">Roald Dahl</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/julia-donaldson">
#  <div class="link-text">Julia Donaldson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/stephen-king">
#  <div class="link-text">Stephen King</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/david-walliams">
#  <div class="link-text">David Walliams</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
#  <div class="link-text">Dr. Seuss</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/andy-griffiths">
#  <div class="link-text">Andy Griffiths</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
#  <div class="link-text">James Patterson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
#  <div class="link-text">Sarah J. Maas</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/enid-blyton">
#  <div class="link-text">Enid Blyton</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/john-green">
#  <div class="link-text">John Green</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
#  <div class="link-text">Brandon Sanderson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/popular-authors">
#  <div class="link-text">See all</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/harry-potter">
#  <div class="link-text">Harry Potter</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/game-of-thrones">
#  <div class="link-text">Game Of Thrones</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/lego">
#  <div class="link-text">Lego</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
#  <div class="link-text">Divergent</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
#  <div class="link-text">Throne Of Glass</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/star-wars">
#  <div class="link-text">Star Wars</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/spanish">
#  <div class="link-text">Books in Spanish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/polish-books">
#  <div class="link-text">Books in Polish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/german-books">
#  <div class="link-text">Books in German</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/french-books">
#  <div class="link-text">Books in French</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/es/languages">
#  <div class="link-text">Languages Bookshop</div>
#  </a>,
#  <a href="/es/bestsellers">Los más vendidos</a>,
#  <a href="/es/comingsoon">Próximamente </a>,
#  <a href="/es/top-new-releases">Nuevos lanzamientos</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">
#          Español</a>,
#  <a class="global-nav-close" href="#"><i class="icon-close"></i></a>,
#  <a class="language-option" data-value="en_US" href="#">
#                              Inglés (English)</a>,
#  <a class="language-option" data-value="es_ES" href="#">
#                              Español</a>,
#  <a class="basket-btn" href="/es/basket" rel="nofollow">
#  <span class="item-count">
#                          0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filtrar tu búsqueda">Filtrar tu búsqueda</a>,
#  <a>1</a>,
#  <a href="/es/bestsellers?page=2">2</a>,
#  <a href="/es/bestsellers?page=3">3</a>,
#  <a href="/es/bestsellers?page=4">4</a>,
#  <a href="/es/bestsellers?page=5">5</a>,
#  <a href="/es/bestsellers?page=2">»</a>,
#  <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959" itemprop="url">
#  <img alt="How to Paint Without a Brush" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4197/9781419761959.jpg"/>
#  </a>,
#  <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959">
#                      How to Paint Without a Brush<br/>
#  </a>,
#  <a href="/es/author/Red-Hong-Yi" itemprop="author">Red Hong Yi</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781419761959" data-price="31.00" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781419761959" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
#  <img alt="Atomic Habits" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
#  </a>,
#  <a href="/es/Atomic-Habits-James-Clear/9781847941831">
#                      Atomic Habits<br/>
#  </a>,
#  <a href="/es/author/James-Clear" itemprop="author">James Clear</a>,
#  <a aria-label="Ratings for Atomic Habits" href="/es/Atomic-Habits-James-Clear/9781847941831">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781847941831" data-price="21.40" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Young-Forever-Mark-Hyman/9781399716307" itemprop="url">
#  <img alt="Young Forever" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399716307.jpg"/>
#  </a>,
#  <a href="/es/Young-Forever-Mark-Hyman/9781399716307">
#                      Young Forever<br/>
#  </a>,
#  <a href="/es/author/Mark-Hyman" itemprop="author">Mark Hyman</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399716307" data-price="21.91" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399716307" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771" itemprop="url">
#  <img alt="Things We Hide From The Light" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399713771.jpg"/>
#  </a>,
#  <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
#                      Things We Hide From The Light<br/>
#  </a>,
#  <a href="/es/author/Lucy-Score" itemprop="author">Lucy Score</a>,
#  <a aria-label="Ratings for Things We Hide From The Light" href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399713771" data-price="14.32" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399713771" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
#  <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
#  </a>,
#  <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                      It Ends With Us: The most heartbreaking novel you'll ever read<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781471156267" data-price="12.58" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061" itemprop="url">
#  <img alt="The Letters I Will Never Send" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5299/9781529901061.jpg"/>
#  </a>,
#  <a href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061">
#                      The Letters I Will Never Send<br/>
#  </a>,
#  <a href="/es/author/Isabella-Dorta" itemprop="author">Isabella Dorta</a>,
#  <a aria-label="Ratings for The Letters I Will Never Send" href="/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  <span class="star"></span>
#  <span class="star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781529901061" data-price="18.50" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529901061" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Parenting-Map-Shefali-Tsabary/9780063267954" itemprop="url">
#  <img alt="The Parenting Map" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/0632/9780063267954.jpg"/>
#  </a>,
#  <a href="/es/Parenting-Map-Shefali-Tsabary/9780063267954">
#                      The Parenting Map<br/>
#  </a>,
#  <a href="/es/author/Shefali-Tsabary" itemprop="author">Shefali Tsabary</a>,
#  <a aria-label="Ratings for The Parenting Map" href="/es/Parenting-Map-Shefali-Tsabary/9780063267954">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780063267954" data-price="31.55" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780063267954" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/UPROAR-Alice-Loxton/9781785789540" itemprop="url">
#  <img alt="UPROAR!" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7857/9781785789540.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>6%</div>
#  </a>,
#  <a href="/es/UPROAR-Alice-Loxton/9781785789540">
#                      UPROAR!<br/>
#  </a>,
#  <a href="/es/author/Alice-Loxton" itemprop="author">Alice Loxton</a>,
#  <a aria-label="Ratings for UPROAR!" href="/es/UPROAR-Alice-Loxton/9781785789540">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781785789540" data-price="28.51" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781785789540" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Parenting-Map-Dr-Shefali-Tsabary/9781399719087" itemprop="url">
#  <img alt="The Parenting Map" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399719087.jpg"/>
#  </a>,
#  <a href="/es/Parenting-Map-Dr-Shefali-Tsabary/9781399719087">
#                      The Parenting Map<br/>
#  </a>,
#  <a href="/es/author/Dr-Shefali-Tsabary" itemprop="author">Dr Shefali Tsabary</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781399719087" data-price="21.00" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399719087" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/I-Dont-Need-Therapy-Toni-Lodge/9781761067693" itemprop="url">
#  <img alt="I Don't Need Therapy" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7610/9781761067693.jpg"/>
#  </a>,
#  <a href="/es/I-Dont-Need-Therapy-Toni-Lodge/9781761067693">
#                      I Don't Need Therapy<br/>
#  </a>,
#  <a href="/es/author/Toni-Lodge" itemprop="author">Toni Lodge</a>,
#  <a aria-label="Ratings for I Don't Need Therapy" href="/es/I-Dont-Need-Therapy-Toni-Lodge/9781761067693">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781761067693" data-price="35.16" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781761067693" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697" itemprop="url">
#  <img alt="Seven Husbands of Evelyn Hugo" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515697.jpg"/>
#  </a>,
#  <a href="/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#                      Seven Husbands of Evelyn Hugo<br/>
#  </a>,
#  <a href="/es/author/Taylor-Jenkins-Reid" itemprop="author">Taylor Jenkins Reid</a>,
#  <a aria-label="Ratings for Seven Husbands of Evelyn Hugo" href="/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781398515697" data-price="13.14" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781398515697" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581" itemprop="url">
#  <img alt="Before the Coffee Gets Cold" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5290/9781529029581.jpg"/>
#  </a>,
#  <a href="/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#                      Before the Coffee Gets Cold<br/>
#  </a>,
#  <a href="/es/author/Toshikazu-Kawaguchi" itemprop="author">Toshikazu Kawaguchi</a>,
#  <a aria-label="Ratings for Before the Coffee Gets Cold" href="/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781529029581" data-price="13.74" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529029581" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Final-Offer-Lauren-Asher/9780349433479" itemprop="url">
#  <img alt="Final Offer" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349433479.jpg"/>
#  </a>,
#  <a href="/es/Final-Offer-Lauren-Asher/9780349433479">
#                      Final Offer<br/>
#  </a>,
#  <a href="/es/author/Lauren-Asher" itemprop="author">Lauren Asher</a>,
#  <a aria-label="Ratings for Final Offer" href="/es/Final-Offer-Lauren-Asher/9780349433479">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780349433479" data-price="13.39" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780349433479" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611" itemprop="url">
#  <img alt="The Body Keeps the Score" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1419/9780141978611.jpg"/>
#  </a>,
#  <a href="/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#                      The Body Keeps the Score<br/>
#  </a>,
#  <a href="/es/author/Bessel-van-der-Kolk" itemprop="author">Bessel van der Kolk</a>,
#  <a aria-label="Ratings for The Body Keeps the Score" href="/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780141978611" data-price="17.05" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780141978611" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Twisted-Love-Ana-Huang/9780349434278" itemprop="url">
#  <img alt="Twisted Love" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349434278.jpg"/>
#  </a>,
#  <a href="/es/Twisted-Love-Ana-Huang/9780349434278">
#                      Twisted Love<br/>
#  </a>,
#  <a href="/es/author/Ana-Huang" itemprop="author">Ana Huang</a>,
#  <a aria-label="Ratings for Twisted Love" href="/es/Twisted-Love-Ana-Huang/9780349434278">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780349434278" data-price="12.89" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780349434278" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Verity-Colleen-Hoover/9781408726600" itemprop="url">
#  <img alt="Verity" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
#  </a>,
#  <a href="/es/Verity-Colleen-Hoover/9781408726600">
#                      Verity<br/>
#  </a>,
#  <a href="/es/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Verity" href="/es/Verity-Colleen-Hoover/9781408726600">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781408726600" data-price="13.11" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Psychology-Money-Morgan-Housel/9780857197689" itemprop="url">
#  <img alt="The Psychology of Money" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/8571/9780857197689.jpg"/>
#  </a>,
#  <a href="/es/Psychology-Money-Morgan-Housel/9780857197689">
#                      The Psychology of Money<br/>
#  </a>,
#  <a href="/es/author/Morgan-Housel" itemprop="author">Morgan Housel</a>,
#  <a aria-label="Ratings for The Psychology of Money" href="/es/Psychology-Money-Morgan-Housel/9780857197689">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780857197689" data-price="18.17" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780857197689" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Small-Things-Like-These-Claire-Keegan/9780571368709" itemprop="url">
#  <img alt="Small Things Like These" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5713/9780571368709.jpg"/>
#  </a>,
#  <a href="/es/Small-Things-Like-These-Claire-Keegan/9780571368709">
#                      Small Things Like These<br/>
#  </a>,
#  <a href="/es/author/Claire-Keegan" itemprop="author">Claire Keegan</a>,
#  <a aria-label="Ratings for Small Things Like These" href="/es/Small-Things-Like-These-Claire-Keegan/9780571368709">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780571368709" data-price="12.92" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780571368709" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740" itemprop="url">
#  <img alt="Things We Never Got Over" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3997/9781399713740.jpg"/>
#  </a>,
#  <a href="/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740">
#                      Things We Never Got Over<br/>
#  </a>,
#  <a href="/es/author/Lucy-Score" itemprop="author">Lucy Score</a>,
#  <a aria-label="Ratings for Things We Never Got Over" href="/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781399713740" data-price="12.53" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781399713740" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Twisted-Games-Ana-Huang/9780349434315" itemprop="url">
#  <img alt="Twisted Games" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349434315.jpg"/>
#  </a>,
#  <a href="/es/Twisted-Games-Ana-Huang/9780349434315">
#                      Twisted Games<br/>
#  </a>,
#  <a href="/es/author/Ana-Huang" itemprop="author">Ana Huang</a>,
#  <a aria-label="Ratings for Twisted Games" href="/es/Twisted-Games-Ana-Huang/9780349434315">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780349434315" data-price="13.00" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780349434315" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Foster-Claire-Keegan/9780571379149" itemprop="url">
#  <img alt="Foster" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5713/9780571379149.jpg"/>
#  </a>,
#  <a href="/es/Foster-Claire-Keegan/9780571379149">
#                      Foster<br/>
#  </a>,
#  <a href="/es/author/Claire-Keegan" itemprop="author">Claire Keegan</a>,
#  <a aria-label="Ratings for Foster" href="/es/Foster-Claire-Keegan/9780571379149">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780571379149" data-price="12.75" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780571379149" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Icebreaker-Hannah-Grace/9781398525689" itemprop="url">
#  <img alt="Icebreaker" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398525689.jpg"/>
#  </a>,
#  <a href="/es/Icebreaker-Hannah-Grace/9781398525689">
#                      Icebreaker<br/>
#  </a>,
#  <a href="/es/author/Hannah-Grace" itemprop="author">Hannah Grace</a>,
#  <a aria-label="Ratings for Icebreaker" href="/es/Icebreaker-Hannah-Grace/9781398525689">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781398525689" data-price="13.56" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781398525689" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Midnight-Library-Matt-Haig/9781786892737" itemprop="url">
#  <img alt="The Midnight Library" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7868/9781786892737.jpg"/>
#  </a>,
#  <a href="/es/Midnight-Library-Matt-Haig/9781786892737">
#                      The Midnight Library<br/>
#  </a>,
#  <a href="/es/author/Matt-Haig" itemprop="author">Matt Haig</a>,
#  <a aria-label="Ratings for The Midnight Library" href="/es/Midnight-Library-Matt-Haig/9781786892737">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781786892737" data-price="12.80" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781786892737" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Rethink-Your-Position-Katy-Bowman/9781943370238" itemprop="url">
#  <img alt="Rethink Your Position" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9433/9781943370238.jpg"/>
#  </a>,
#  <a href="/es/Rethink-Your-Position-Katy-Bowman/9781943370238">
#                      Rethink Your Position<br/>
#  </a>,
#  <a href="/es/author/Katy-Bowman" itemprop="author">Katy Bowman</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781943370238" data-price="21.71" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781943370238" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Fine-Print-Lauren-Asher/9780349433448" itemprop="url">
#  <img alt="The Fine Print" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349433448.jpg"/>
#  </a>,
#  <a href="/es/Fine-Print-Lauren-Asher/9780349433448">
#                      The Fine Print<br/>
#  </a>,
#  <a href="/es/author/Lauren-Asher" itemprop="author">Lauren Asher</a>,
#  <a aria-label="Ratings for The Fine Print" href="/es/Fine-Print-Lauren-Asher/9780349433448">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780349433448" data-price="12.98" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780349433448" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Spare-Prince-Harry-Duke-Sussex/9780857504791" itemprop="url">
#  <img alt="Spare" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/8575/9780857504791.jpg"/>
#  <div class="savings-splat">
#                          Ahorra<br/>20%</div>
#  </a>,
#  <a href="/es/Spare-Prince-Harry-Duke-Sussex/9780857504791">
#                      Spare<br/>
#  </a>,
#  <a href="/es/author/Prince-Harry-the-Duke-of-Sussex" itemprop="author">Prince Harry the Duke of Sussex</a>,
#  <a aria-label="Ratings for Spare" href="/es/Spare-Prince-Harry-Duke-Sussex/9780857504791">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9780857504791" data-price="28.24" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9780857504791" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Heaven-Officials-Blessing-Tian-Guan-Ci-Fu-Novel-Vol-5-Mo-Xiang-Tong-Xiu/9781638585503" itemprop="url">
#  <img alt="Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 5" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/6385/9781638585503.jpg"/>
#  </a>,
#  <a href="/es/Heaven-Officials-Blessing-Tian-Guan-Ci-Fu-Novel-Vol-5-Mo-Xiang-Tong-Xiu/9781638585503">
#                      Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 5<br/>
#  </a>,
#  <a href="/es/author/Mo-Xiang-Tong-Xiu" itemprop="author">Mo Xiang Tong Xiu</a>,
#  <a aria-label="Ratings for Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 5" href="/es/Heaven-Officials-Blessing-Tian-Guan-Ci-Fu-Novel-Vol-5-Mo-Xiang-Tong-Xiu/9781638585503">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781638585503" data-price="20.15" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781638585503" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Boy-Mole-Fox-Horse-Charlie-Mackesy/9781529105100" itemprop="url">
#  <img alt="The Boy, The Mole, The Fox and The Horse" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5291/9781529105100.jpg"/>
#  </a>,
#  <a href="/es/Boy-Mole-Fox-Horse-Charlie-Mackesy/9781529105100">
#                      The Boy, The Mole, The Fox and The Horse<br/>
#  </a>,
#  <a href="/es/author/Charlie-Mackesy" itemprop="author">Charlie Mackesy</a>,
#  <a aria-label="Ratings for The Boy, The Mole, The Fox and The Horse" href="/es/Boy-Mole-Fox-Horse-Charlie-Mackesy/9781529105100">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                          PVPR</a>,
#  <a class="price-save-link" href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                          Más bajo</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781529105100" data-price="20.86" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529105100" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a href="/es/Me-vs-Brain-Hayley-Morris/9781529196047" itemprop="url">
#  <img alt="Me vs Brain" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5291/9781529196047.jpg"/>
#  </a>,
#  <a href="/es/Me-vs-Brain-Hayley-Morris/9781529196047">
#                      Me vs Brain<br/>
#  </a>,
#  <a href="/es/author/Hayley-Morris" itemprop="author">Hayley Morris</a>,
#  <a aria-label="Ratings for Me vs Brain" href="/es/Me-vs-Brain-Hayley-Morris/9781529196047">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="PRE_ORDER" data-currency="EUR" data-isbn="9781529196047" data-price="31.28" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781529196047" rel="nofollow">
#                          Comprar en preventa</a>,
#  <a href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782" itemprop="url">
#  <img alt="The Adventure Zone: The Eleventh Hour" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/2507/9781250793782.jpg"/>
#  </a>,
#  <a href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782">
#                      The Adventure Zone: The Eleventh Hour<br/>
#  </a>,
#  <a href="/es/author/Clint-McElroy" itemprop="author">Clint McElroy</a>,
#  <a aria-label="Ratings for The Adventure Zone: The Eleventh Hour" href="/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-availability="AVAILABLE" data-currency="EUR" data-isbn="9781250793782" data-price="19.77" data-ref="grid-view" data-show-related="false" href="/es/basket/addisbn/isbn13/9781250793782" rel="nofollow">
#                          Añadir a la cesta</a>,
#  <a>1</a>,
#  <a href="/es/bestsellers?page=2">2</a>,
#  <a href="/es/bestsellers?page=3">3</a>,
#  <a href="/es/bestsellers?page=4">4</a>,
#  <a href="/es/bestsellers?page=5">5</a>,
#  <a href="/es/bestsellers?page=2">»</a>,
#  <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-fb"></i>
#  </a>,
#  <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-tw"></i>
#  </a>,
#  <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-pi"></i>
#  </a>,
#  <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-in"></i>
#  </a>,
#  <a href="/es/about-us" rel="nofollow">
#                              Conócenos</a>,
#  <a href="/es/sitemap">
#                              Mapa del sitio</a>,
#  <a href="/es/bookmarks">
#                              Marcapáginas</a>,
#  <a href="/es/blog">
#                              Book Blog</a>,
#  <a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                      Iniciar sesión/Crear cuenta</a>,
#  <a href="/es/help" rel="nofollow">
#                                  Ayuda</a>,
#  <a href="/es/contactus">
#                                  Contáctanos</a>,
#  <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                  ¿Dónde está mi pedido? </a>,
#  <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                  Envíos internacionales</a>,
#  <a href="/es/cancelorder" rel="nofollow">
#                                  Cancelar mi pedido</a>,
#  <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                  Devolver mi pedido</a>,
#  <a href="/es/affiliate">
#                              Afiliados</a>,
#  <a href="/es/jobs">
#                              Trabajar en Book Depository</a>,
#  <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                  Reclamaciones</a>,
#  <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                  Cookies</a>,
#  <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                  Política de privacidad</a>,
#  <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                  Términos y Condiciones </a>,
#  <a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                      Iniciar sesión/Crear cuenta</a>,
#  <a href="/es/track">
#                              Mis pedidos</a>,
#  <a href="/es/contactus">
#                              Contáctanos</a>,
#  <a href="/es/help">
#                              Ayuda</a>,
#  <a href="/es/about-us" rel="nofollow">
#                              Conócenos</a>,
#  <a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                              Términos y Condiciones </a>,
#  <a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                              Política de privacidad</a>,
#  <a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                              Cookies</a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
    print(type(a))
# Out:
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Ayuda sobre Cookies</a>
# <class 'bs4.element.Tag'>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>
# <class 'bs4.element.Tag'>
# <a class="showLess" role="button">Mostrar menos</a>
# <class 'bs4.element.Tag'>
# <a class="showMore" role="button">Mostrar más</a>
# <class 'bs4.element.Tag'>
# <a class="showLess" role="button">Mostrar menos</a>
# <class 'bs4.element.Tag'>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 30 libros con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - book titles
# - formats (paperback or hardback)
# - publication dates
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los titulos de los libros (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un libro y elegimos inspeccionar)

# %%
all_h3 = soup.find_all('h3')
for h3 in all_h3[:5]:
    print(h3)
    print('----')
# Out:
# <h3 class="title">
# <a href="/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959">
#                     How to Paint Without a Brush<br/>
# </a>
# </h3>
# ----
# <h3 class="title">
# <a href="/es/Atomic-Habits-James-Clear/9781847941831">
#                     Atomic Habits<br/>
# </a>
# </h3>
# ----
# <h3 class="title">
# <a href="/es/Young-Forever-Mark-Hyman/9781399716307">
#                     Young Forever<br/>
# </a>
# </h3>
# ----
# <h3 class="title">
# <a href="/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771">
#                     Things We Hide From The Light<br/>
# </a>
# </h3>
# ----
# <h3 class="title">
# <a href="/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                     It Ends With Us: The most heartbreaking novel you'll ever read<br/>
# </a>
# </h3>
# ----

# %% [markdown]
# Si queremos obtener solo los títulos

# %%
all_h3 = soup.find_all('h3', class_='title')
for h3 in all_h3:
    print(h3.get_text(strip = True))
# Out:
# How to Paint Without a Brush
# Atomic Habits
# Young Forever
# Things We Hide From The Light
# It Ends With Us: The most heartbreaking novel you'll ever read
# The Letters I Will Never Send
# The Parenting Map
# UPROAR!
# The Parenting Map
# I Don't Need Therapy
# Seven Husbands of Evelyn Hugo
# Before the Coffee Gets Cold
# Final Offer
# The Body Keeps the Score
# Twisted Love
# Verity
# The Psychology of Money
# Small Things Like These
# Things We Never Got Over
# Twisted Games
# Foster
# Icebreaker
# The Midnight Library
# Rethink Your Position
# The Fine Print
# Spare
# Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 5
# The Boy, The Mole, The Fox and The Horse
# Me vs Brain
# The Adventure Zone: The Eleventh Hour

# %% [markdown]
# ## Tips importantes

# %% [markdown]
# soup.find_all(“h3”) encuentra cada elemento h3 en la página web; con class_=”title” especificamos que buscamos específicamente etiquetas h3 que contengan el atributo class_=”title” (nota importante: el “_” en **class__=”title”** no es un error tipográfico, se requiere en Beautiful Soup cuando seleccionando atributos de clase).

# %% [markdown]
# Guardamos los elementos h3 en all_h3, que se comporta como una lista, por lo que podemos recorrerlos con un bucle for. En cada iteración extraemos solo el texto del elemento h3 con .get_text(), y con el parámetro strip=True nos aseguramos de eliminar cualquier espacio en blanco innecesario.

# %% [markdown]
# ## Obtener los formatos de los libros

# %% [markdown]
# Del paso anterior tenemos todos los títulos de libros de la página de los más vendidos. Pero, ¿qué sabemos acerca de sus formatos? ¿Hay más libros de tapa dura o tapa blanda?
#
# Averigüémoslo inspeccionando el elemento de formato de libro:

# %% [markdown]
# Como siempre inspeccionamos y buscamos el formato..

# %% [markdown]
# Y como queremos saber la cantidad de cada formato lo metemos en dataframe

# %%
all_formats = soup.find_all('p', class_ = 'format')
for i in all_formats:
    print(i)
# Out:
# <p class="format">Hardback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Hardback</p>
# <p class="format">Hardback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Paperback</p>
# <p class="format">Hardback</p>
# <p class="format">Paperback</p>
# <p class="format">Hardback</p>
# <p class="format">Hardback</p>
# <p class="format">Paperback</p>

# %%
all_formats = soup.find_all('p', class_ = 'format')
for i in all_formats:
    print(i.get_text(strip=True))
# Out:
# Hardback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Hardback
# Hardback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Paperback
# Hardback
# Paperback
# Hardback
# Hardback
# Paperback

# %%
formats = soup.select('div.item-info  p.format')
#Esto corresponde al selector CSS
#'body > div.page-slide > div.content-wrap > div.main-content.bestseller-page > div.content-block > div > div > div > div > div:nth-child(3) > div.item-info > p.format'

# %%
formats = soup.select('p.format')
formats
# Out:
# [<p class="format">Hardback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Hardback</p>,
#  <p class="format">Hardback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Hardback</p>,
#  <p class="format">Paperback</p>,
#  <p class="format">Hardback</p>,
#  <p class="format">Hardback</p>,
#  <p class="format">Paperback</p>]

# %%
formats = soup.select('div.item-info  p.format')
formats_series = pd.Series(formats)
formats_series_df = pd.DataFrame(formats)
formats_series.value_counts()
# Out:
# [Paperback]    24
# [Hardback]      6
# dtype: int64

# %% [markdown]
# ## Obtener las fechas de publicación (find_all + get_text)

# %% [markdown]
# Al igual que antes inspeccionamos....

# %% [markdown]
# * type(date) = bs4.element.Tag
# * type(date.get_text()) = str

# %%
#date = soup.find('p', class_='published')
#date = soup.find('p', attrs={'itemprop':'datePublished'})
#date = soup.find('p', attrs = {'class':'published'})
date = soup.find('p', attrs = {'class':'published', 'itemprop':'datePublished'})
print(date)
print(type(date))
print(date.get_text())
print(type(date.get_text(strip=True)))
# Out:
# <p class="published" itemprop="datePublished">11 May 2023</p>
# <class 'bs4.element.Tag'>
# 11 May 2023
# <class 'str'>

# %% [markdown]
# ### Una forma de meter los años dentro de series

# %%
dates = soup.find_all('p', class_='published')
fechas = []
for date in dates:
    fechas.append(date.get_text(strip=True)[-4:])
fechas
# Out:
# ['2023',
#  '2018',
#  '2023',
#  '2023',
#  '2016',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2021',
#  '2019',
#  '2023',
#  '2015',
#  '2022',
#  '2022',
#  '2020',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2019',
#  '2023',
#  '2023']

# %%
fechas_serie = pd.Series(fechas)
fechas_serie
# Out:
# 0     2023
# 1     2018
# 2     2023
# 3     2023
# 4     2016
# 5     2023
# 6     2023
# 7     2023
# 8     2023
# 9     2023
# 10    2021
# 11    2019
# 12    2023
# 13    2015
# 14    2022
# 15    2022
# 16    2020
# 17    2022
# 18    2022
# 19    2022
# 20    2022
# 21    2023
# 22    2021
# 23    2023
# 24    2022
# 25    2023
# 26    2022
# 27    2019
# 28    2023
# 29    2023
# dtype: object

# %% [markdown]
# ### Otra forma de hacerlo

# %%
dates = soup.find_all('p', class_='published')
dates = [date.get_text() for date in dates]
dates_series = pd.Series(dates)
dates_series.value_counts()
# Out:
# 11 May 2023    2
# 21 Feb 2023    2
# 16 Mar 2023    2
# 02 Mar 2023    2
# 05 May 2022    2
# 08 Sep 2020    1
# 20 Dec 2022    1
# 10 Jan 2023    1
# 27 Jan 2022    1
# 18 Feb 2021    1
# 19 Jan 2023    1
# 18 Aug 2022    1
# 14 Jul 2022    1
# 03 Nov 2022    1
# 24 Sep 2015    1
# 20 Jan 2022    1
# 27 Nov 2018    1
# 31 Jan 2023    1
# 19 Sep 2019    1
# 14 Oct 2021    1
# 28 Feb 2023    1
# 27 Apr 2023    1
# 02 Aug 2016    1
# 16 Feb 2023    1
# 04 Nov 2019    1
# dtype: int64

# %%
dates = soup.find_all('p', class_='published')
dates = [date.get_text()[-4:] for date in dates]
dates_series = pd.Series(dates)
dates_series.value_counts()
# Out:
# 2023    14
# 2022     8
# 2021     2
# 2019     2
# 2018     1
# 2016     1
# 2015     1
# 2020     1
# dtype: int64

# %% [markdown]
# ## Obtener los precios (find_all + get_text)

# %% [markdown]
# Inspeccionamos..

# %%
prices = soup.find_all('p', class_='price')
prices
for i in prices:
    print(i.get_text(strip=True))
# Out:
# 31,00 €
# 20,93 €PVPR:22,00 €
# 21,40 €
# 23,43 €
# 13,03 €
# 31,51 €
# 12,58 €
# 30,50 €
# 21,77 €
# 12,56 €
# 13,61 €
# 17,11 €
# 13,78 €
# 21,17 €
# 13,14 €
# 12,76 €PVPR:13,50 €
# 14,22 €
# 13,02 €PVPR:13,50 €
# 12,57 €
# 18,23 €PVPR:18,50 €
# 12,84 €
# 13,04 €PVPR:13,50 €
# 12,34 €
# 28,24 €PVPR:35,50 €
# 20,92 €PVPR:21,50 €
# 13,16 €PVPR:13,50 €
# 20,15 €PVPR:21,00 €
# 12,50 €
# 20,07 €PVPR:21,00 €
# 20,11 €

# %%
prices = soup.find_all('span', class_='sale-price')
prices
# Out:
# [<span class="sale-price">31,00 €</span>,
#  <span class="sale-price">21,40 €</span>,
#  <span class="sale-price">21,91 €</span>,
#  <span class="sale-price">14,32 €</span>,
#  <span class="sale-price">12,58 €</span>,
#  <span class="sale-price">18,50 €</span>,
#  <span class="sale-price">31,55 €</span>,
#  <span class="sale-price">28,51 €</span>,
#  <span class="sale-price">21,00 €</span>,
#  <span class="sale-price">35,16 €</span>,
#  <span class="sale-price">13,14 €</span>,
#  <span class="sale-price">13,74 €</span>,
#  <span class="sale-price">13,39 €</span>,
#  <span class="sale-price">17,05 €</span>,
#  <span class="sale-price">12,89 €</span>,
#  <span class="sale-price">13,11 €</span>,
#  <span class="sale-price">18,17 €</span>,
#  <span class="sale-price">12,92 €</span>,
#  <span class="sale-price">12,53 €</span>,
#  <span class="sale-price">13,00 €</span>,
#  <span class="sale-price">12,75 €</span>,
#  <span class="sale-price">13,56 €</span>,
#  <span class="sale-price">12,80 €</span>,
#  <span class="sale-price">21,71 €</span>,
#  <span class="sale-price">12,98 €</span>,
#  <span class="sale-price">28,24 €</span>,
#  <span class="sale-price">20,15 €</span>,
#  <span class="sale-price">20,86 €</span>,
#  <span class="sale-price">31,28 €</span>,
#  <span class="sale-price">19,77 €</span>]

# %%
for price in prices:
    print(price.get_text(strip=True))
# Out:
# 31,00 €
# 21,40 €
# 21,91 €
# 14,32 €
# 12,58 €
# 18,50 €
# 31,55 €
# 28,51 €
# 21,00 €
# 35,16 €
# 13,14 €
# 13,74 €
# 13,39 €
# 17,05 €
# 12,89 €
# 13,11 €
# 18,17 €
# 12,92 €
# 12,53 €
# 13,00 €
# 12,75 €
# 13,56 €
# 12,80 €
# 21,71 €
# 12,98 €
# 28,24 €
# 20,15 €
# 20,86 €
# 31,28 €
# 19,77 €

# %% [markdown]
# Precio del sexto libro

# %%
prices[5]
# Out:
# <span class="sale-price">18,50 €</span>

# %% [markdown]
# ##### .split()

# %% [markdown]
# Queremos el texto y separado con .split

# %%
prices[5].get_text(strip=True).split()
# Out:
# ['18,50', '€']

# %%
prices[5].get_text(strip=True).split(" ")
# Out:
# ['18,50', '€']

# %% [markdown]
# .split separa los precios por el elemento que quieras

# %%
prices[5].get_text(strip=True).split(',')
# Out:
# ['18', '50 €']

# %%
prices[5].get_text(strip=True).replace(',','.').split()
# Out:
# ['31.51', '€']

# %%
prices[5].get_text(strip=True).replace(',','.').split()[0]
# Out:
# '31.51'

# %%
float(prices[5].get_text(strip=True).replace(',','.').split()[0])
# Out:
# 18.5

# %% [markdown]
# ### Añadirlo a una lista, limpiando los datos

# %%
prices = soup.find_all("p", class_="price")

final_prices = []
for price in prices:
    original_price = price.find("span", class_="sale-price")
    original_price = original_price.get_text()
    original_price = float(original_price.split("€")[0].replace(",", "."))
    final_prices.append(original_price)
print(final_prices)
# Out:
# [31.0, 21.4, 21.91, 14.32, 12.58, 18.5, 31.55, 28.51, 21.0, 35.16, 13.14, 13.74, 13.39, 17.05, 12.89, 13.11, 18.17, 12.92, 12.53, 13.0, 12.75, 13.56, 12.8, 21.71, 12.98, 28.24, 20.15, 20.86, 31.28, 19.77]

# %%
float("31.0 ") #Un espacio al final no afecta en la conversión a float
int("31")
int("31.0") #error

# %% [markdown]
# ### Otra forma de hacerlo

# %%
final_price_compress = [float(price.find("span", class_="sale-price")\
        .get_text().split(" €")[0].replace(",", ".")) for price in prices]
final_price_compress
# Out:
# [31.0,
#  21.4,
#  21.91,
#  14.32,
#  12.58,
#  18.5,
#  31.55,
#  28.51,
#  21.0,
#  35.16,
#  13.14,
#  13.74,
#  13.39,
#  17.05,
#  12.89,
#  13.11,
#  18.17,
#  12.92,
#  12.53,
#  13.0,
#  12.75,
#  13.56,
#  12.8,
#  21.71,
#  12.98,
#  28.24,
#  20.15,
#  20.86,
#  31.28,
#  19.77]

# %% [markdown]
# ### Podéis también meterlo en una serie o en un dataframe

# %%
df = pd.DataFrame(final_prices)
df

df.columns=['Precios']
df[df['Precios']>25]
# Out:
#     Precios
# 0     31.00
# 6     31.55
# 7     28.51
# 9     35.16
# 25    28.24
# 28    31.28

# %% [markdown]
# Aunque se vean diferente, son la misma lista

# %%
print(final_prices == final_price_compress)
# Out:
# True

# %% [markdown]
# ## Recolectar información de un libro

# %% [markdown]
# Primero creamos un soup en la pagína 'principal'

# %%
libros = soup.find_all('div', class_='item-img')

# %% [markdown]
# Guardamos en una variable la url principal

# %%
url_principal = 'https://www.bookdepository.com'

# %% [markdown]
# Creamos una lista con los urls de los libros

# %%
lista_URLs = []
for libro in libros:
    URL_libro= libro.find('a')['href']
    lista_URLs.append(url_principal+URL_libro)
lista_URLs
# Out:
# ['https://www.bookdepository.com/es/How-Paint-Without-Brush-Red-Hong-Yi/9781419761959',
#  'https://www.bookdepository.com/es/Atomic-Habits-James-Clear/9781847941831',
#  'https://www.bookdepository.com/es/Young-Forever-Mark-Hyman/9781399716307',
#  'https://www.bookdepository.com/es/Things-We-Hide-From-Light-Lucy-Score/9781399713771',
#  'https://www.bookdepository.com/es/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267',
#  'https://www.bookdepository.com/es/Letters-I-Will-Never-Send-Isabella-Dorta/9781529901061',
#  'https://www.bookdepository.com/es/Parenting-Map-Shefali-Tsabary/9780063267954',
#  'https://www.bookdepository.com/es/UPROAR-Alice-Loxton/9781785789540',
#  'https://www.bookdepository.com/es/Parenting-Map-Dr-Shefali-Tsabary/9781399719087',
#  'https://www.bookdepository.com/es/I-Dont-Need-Therapy-Toni-Lodge/9781761067693',
#  'https://www.bookdepository.com/es/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697',
#  'https://www.bookdepository.com/es/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581',
#  'https://www.bookdepository.com/es/Final-Offer-Lauren-Asher/9780349433479',
#  'https://www.bookdepository.com/es/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611',
#  'https://www.bookdepository.com/es/Twisted-Love-Ana-Huang/9780349434278',
#  'https://www.bookdepository.com/es/Verity-Colleen-Hoover/9781408726600',
#  'https://www.bookdepository.com/es/Psychology-Money-Morgan-Housel/9780857197689',
#  'https://www.bookdepository.com/es/Small-Things-Like-These-Claire-Keegan/9780571368709',
#  'https://www.bookdepository.com/es/Things-We-Never-Got-Over-Lucy-Score/9781399713740',
#  'https://www.bookdepository.com/es/Twisted-Games-Ana-Huang/9780349434315',
#  'https://www.bookdepository.com/es/Foster-Claire-Keegan/9780571379149',
#  'https://www.bookdepository.com/es/Icebreaker-Hannah-Grace/9781398525689',
#  'https://www.bookdepository.com/es/Midnight-Library-Matt-Haig/9781786892737',
#  'https://www.bookdepository.com/es/Rethink-Your-Position-Katy-Bowman/9781943370238',
#  'https://www.bookdepository.com/es/Fine-Print-Lauren-Asher/9780349433448',
#  'https://www.bookdepository.com/es/Spare-Prince-Harry-Duke-Sussex/9780857504791',
#  'https://www.bookdepository.com/es/Heaven-Officials-Blessing-Tian-Guan-Ci-Fu-Novel-Vol-5-Mo-Xiang-Tong-Xiu/9781638585503',
#  'https://www.bookdepository.com/es/Boy-Mole-Fox-Horse-Charlie-Mackesy/9781529105100',
#  'https://www.bookdepository.com/es/Me-vs-Brain-Hayley-Morris/9781529196047',
#  'https://www.bookdepository.com/es/Adventure-Zone-Eleventh-Hour-Clint-McElroy/9781250793782']

# %% [markdown]
# Vamos a analizar el url de un libro primero

# %%
# Hacemos un nuevo request para un libro (el segundo que aparece en la web): 
r = requests.get(lista_URLs[1])

# Creamos una sopa específica con la info de cada libro
soup_libro = bs(r.content)

# %% [markdown]
# creamos un soup del primer libro

# %%
soup_libro
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="Atomic Habits por James Clear, 9781847941831, disponible en Book Depository con envío gratis. " name="description"/>
# <meta content="James Clear" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <meta content="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg" name="thumbnail"/>
# <link href="https://www.bookdepository.com/es/Atomic-Habits-James-Clear/9781847941831" rel="canonical"/>
# <link href="https://www.bookdepository.com/Atomic-Habits-James-Clear/9781847941831" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/Atomic-Habits-James-Clear/9781847941831" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/Atomic-Habits-James-Clear/9781847941831" hreflang="es" rel="alternate"/>
# <title>
# 	Atomic Habits : James Clear : 9781847941831</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# <script async="" src="https://assets.adobedtm.com/4dfb8f1b14f8/eb478f5c633f/launch-8ffac2b531d7.min.js">
# </script>
# </head>
# <body class="">
# <div aria-live="polite" class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>Usamos cookies para mejorar este sitio</h2>
# <p>Las cookies se utilizan para brindar, analizar y mejorar nuestros servicios; proporcionar herramientas de chat; y<br/>mostrarte contenido relevante de publicidad. Para más información sobre nuestro uso de cookies, lee nuestra sección de <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Ayuda sobre Cookies</a></p><h2>¿Aceptas las cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <button class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Aceptar cookies</button>
# <button class="btn btn-sm btn-secondary btn-manage" href="#" rel="nofollow">
#                 Administrar cookies</button>
# </div>
# </div>
# <div aria-live="polite" class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Preferencias de cookies</h2>
# <p>Usamos cookies y herramientas similares que son necesarias para permitirte realizar compras, incluidas las que utilizan terceros autorizados (colectivamente denominadas “cookies”) para los fines que se describen a continuación.
#      <br/>Para obtener más información acerca de cómo nosotros y los terceros autorizados usamos las cookies y cómo cambiar tu configuración, consulta el <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de cookies</a>. Las elecciones que realices aquí se aplicarán a tu interacción con este servicio en este dispositivo.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Indispensable</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>Usamos cookies para brindar nuestros servicios, </span>
# <div>
# <div class="additionalInfo wrapping-space">por ejemplo, para realizar un seguimiento de los artículos almacenados en tu canasta de compras, prevenir actividades fraudulentas, mejorar la seguridad de nuestros servicios, realizar un seguimiento de tus preferencias específicas (como preferencias de moneda o idioma) y mostrar características, productos y servicios que puedan ser de tu interés. Debido a que usamos cookies para brindarte nuestros servicios, estas no se pueden desactivar cuando se usan con este fin.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <label for="performanceCheckBox"><h2>Desempeño y analítica</h2></label>
# </div>
# <div class="cookie-management-category-check">
# <span aria-hidden="true" class="is-enabled">ACTIVADO</span>
# <span aria-hidden="true" class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="performanceCheckBox" role="switch" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si estás de acuerdo, utilizaremos cookies para comprender cómo los clientes utilizan nuestros servicios</span>
# <div>
# <div class="additionalInfo wrapping-space">(por ejemplo, midiendo visitas al sitio) para que podamos hacer mejoras. Usamos cookies para realizar investigaciones y diagnósticos a fin de mejorar el contenido, los productos y los servicios, y para evaluar y analizar el desempeño de nuestros servicios.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <label for="advertisingCheckBox"><h2>Publicidad</h2></label>
# </div>
# <div class="cookie-management-category-check">
# <span aria-hidden="true" class="is-enabled">ACTIVADO</span>
# <span aria-hidden="true" class="is-disabled shown">DESACTIVADO</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" role="switch" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>Si estás de acuerdo, utilizaremos cookies para complementar tu experiencia de compra, tal como se describe en nuestro <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Aviso de Cookies</a></span>
# <div>
# <div class="additionalInfo wrapping-space">y ofrecerte ciertos tipos de anuncios relevantes a tus intereses en Book Depository. Esto incluye el uso de cookies de terceros con el propósito de mostrar y medir anuncios (consulta el aviso de <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Anuncios basados en intereses</a> para conocer cómo usamos las cookies para publicar anuncios basados en intereses), medir la efectividad de los anuncios y, según sea necesario, para que el tercero realice servicios en nombre de Book Depository.</div>
# <a class="showLess" role="button">Mostrar menos</a>
# </div>
# <a class="showMore" role="button">Mostrar más</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <button class="btn btn-sm btn-secondary btn-cancel" href="#" rel="nofollow">
#                 Cancelar</button>
# <button class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Guardar configuración</button>
# </div>
# </div>
# <div hidden="" id="main-data-container">
# <div class="metrics_data_events" data-metric-event="PAGE_LOADED" hidden=""></div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/es/"><i class="icon-home"></i><span class="show-non-desktop">Inicio</span></a></li>
# <li class="mob-nav-account"><a href="/es/contactus"><i class="icon-em"></i>Contáctanos</a></li>
# <li class="mob-nav-account"><a href="/es/help" rel="nofollow"><i class="icon-info"></i>Ayuda</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/es/track" rel="nofollow"><i class="icon-order-status"></i>Mis pedidos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Lista de deseos</a>
# </li>
# <li class="mob-nav-account"><a href="/es/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/es/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/es/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/es/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Buscar libros por palabra clave / título / autor / ISBN" class="text-input" name="searchTerm" placeholder="Buscar libros por palabra clave / título / autor / ISBN" spellcheck="false" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Buscar</span>
# </button>
# </div>
# </form>
# <a class="advanced-search" href="/es/search/advanced" rel="nofollow">Búsqueda avanzada</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Envío gratis" href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Envío gratis">
# <i class="icon-rocket"></i> Envío gratis</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Comprar por categoría</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categorías</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Libros infantiles por edades</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>
#                 Todas las categorías</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Menú principal</a>
# </li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/es/category/2/Art-Photography">
#                                         Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3389/Audio-Books">
#                                         Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/213/Biography">
#                                         Biography</a>
# </li>
# <li data-order="0">
# <a href="/es/category/928/Business-Finance-Law">
#                                         Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2455/Childrens-Books">
#                                         Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1897/Computing">
#                                         Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2942/Crafts-Hobbies">
#                                         Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2616/Crime-Thriller">
#                                         Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/es/category/240/Dictionaries-Languages">
#                                         Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3245/Entertainment">
#                                         Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/333/Fiction">
#                                         Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2858/Food-Drink">
#                                         Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2633/Graphic-Novels-Anime-Manga">
#                                         Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2770/Health">
#                                         Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2638/History-Archaeology">
#                                         History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2892/Home-Garden">
#                                         Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2978/Humour">
#                                         Humour</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1279/Medical">
#                                         Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2819/Mind-Body-Spirit">
#                                         Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2985/Natural-History">
#                                         Natural History</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/es/category/283/Poetry-Drama">
#                                         Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/es/category/375/Reference">
#                                         Reference</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3120/Religion">
#                                         Religion</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2630/Romance">
#                                         Romance</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1476/Science-Geography">
#                                         Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/es/category/2623/Science-Fiction-Fantasy-Horror">
#                                         Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/es/category/632/Society-Social-Sciences">
#                                         Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3013/Sport">
#                                         Sport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3385/Stationery">
#                                         Stationery</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3328/Teaching-Resources-Education">
#                                         Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/es/category/1708/Technology-Engineering">
#                                         Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3391/Teen-Young-Adult">
#                                         Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/es/category/2967/Transport">
#                                         Transport</a>
# </li>
# <li data-order="0">
# <a href="/es/category/3098/Travel-Holiday-Guides">
#                                         Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Libros infantiles por edades</p>
# </li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/es/category/3392/Books-for-Ages-0-2">
#                                 Ages 0-2</a>
# </li>
# <li>
# <a href="/es/category/3393/Books-for-Ages-3-5">
#                                 Ages 3-5</a>
# </li>
# <li>
# <a href="/es/category/3394/Books-for-Ages-6-8">
#                                 Ages 6-8</a>
# </li>
# <li>
# <a href="/es/category/3395/Books-for-Ages-9-11">
#                                 Ages 9-11</a>
# </li>
# <li>
# <a href="/es/category/3391/Teen-Young-Adult">
#                                 Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Top Authors">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Bestselling Series">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-container block-wrap sidebar">
# <div class="block-header" id="Books By Language">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/es/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/es/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/es/bestsellers">Los más vendidos</a></li>
# <li class="mob-nav-shop"><a href="/es/comingsoon">Próximamente </a></li>
# <li class="mob-nav-shop"><a href="/es/top-new-releases">Nuevos lanzamientos</a>
# </li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         Español</a>
# <div class="metrics_data_container" data-datalayer-reader="locale" data-page-locale="es_ES" hidden=""></div>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Idiomas</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             Inglés (English)</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Español</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="Español">
# <select id="selectLanguage" name="selectLanguage">
# <option value="en_US">
#                     English</option>
# <option selected="selected" value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="/es/Atomic-Habits-James-Clear/9781847941831" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/es/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="metrics_data_container" data-datalayer-reader="loginStatus" data-val="guest" hidden=""></div>
# <div class="content-wrap">
# <div class="metrics_data_container" data-datalayer-reader="pageType" data-page-type="detail" hidden=""></div>
# <div class="metrics_data_container" data-datalayer-reader="pageName" data-page-name="detail" hidden=""></div>
# <div class="metrics_data_container" data-datalayer-reader="sitesection" data-page-sitesection="detail" hidden=""></div>
# <div class="metrics_data_container" data-datalayer-reader="sitesection2" data-page-sitesection="Book Atomic Habits" hidden=""></div>
# <div onclick="void(0);">
# <div class="main-content no-borders book-page full-width">
# <ol class="breadcrumb">
# <li class="title">Categorías:</li>
# <li>
# <a href="/es/category/763/Social-Group-Or-Collective-Psychology">
#                                             Social, Group Or Collective Psychology</a>
# </li>
# <li>
# <a href="/es/category/770/Cognition-Cognitive-Psychology">
#                                             Cognition &amp; Cognitive Psychology</a>
# </li>
# <li>
# <a href="/es/category/956/Finance-Accounting">
#                                             Finance &amp; Accounting</a>
# </li>
# <li>
# <a href="/es/category/2793/Dating-Relationships-Living-Together-Marriage">
#                                             Dating, Relationships, Living Together &amp; Marriage</a>
# </li>
# <li>
# <a href="/es/category/2802/Personal-Development">
#                                             Personal Development</a>
# </li>
# <li>
# <a href="/es/category/2804/Advice-On-Careers-Achieving-Success">
#                                             Advice On Careers &amp; Achieving Success</a>
# </li>
# <li>
# <a href="/es/category/2812/Popular-Psychology">
#                                             Popular Psychology</a>
# </li>
# <li>
# <a class="active" href="/es/category/2813/Assertiveness-Motivation-Self-esteem">
#                                             Assertiveness, Motivation &amp; Self-esteem</a>
# </li>
# </ol>
# <div class="item-wrap" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-block">
# <meta content="/es/Atomic-Habits-James-Clear/9781847941831" itemprop="url"/>
# <span itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="http://schema.org/InStock" itemprop="availability"/>
# <meta content="http://schema.org/NewCondition" itemprop="itemCondition"/>
# </span>
# <div class="item-img">
# <i class="icon-mobile-zoom"></i>
# <div class="item-img-content">
# <img alt="Atomic Habits" class="book-img" itemprop="image" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8479/9781847941831.jpg"/>
# </div>
# <div class="copy-content visible-md" data-target=".social-wrap"></div>
# </div>
# <div class="item-info">
# <h1 itemprop="name">Atomic Habits : the life-changing million-copy #1 bestseller</h1>
# <div class="rating-wrap hidden-md" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <a href="#rating-distribution">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# <span itemprop="ratingValue">
#                                     4.38</span>
# <span class="rating-count">
#                                     (567,225 opiniones de clientes de Goodreads)
# </span>
# <meta content="567225" itemprop="ratingCount"/>
# </div>
# <ul class="meta-info hidden-md">
# <li>Paperback</li>
# <li>
# <span itemprop="inLanguage" itemtype="http://schema.org/Language">
# <a href="/es/search/advanced?searchLang=123">English</a></span>
# </li>
# </ul>
# <div class="author-info hidden-md">
#                             By (author)
#
#                                 <span itemprop="author" itemscope="James Clear" itemtype="http://schema.org/Person">
# <a href="/es/author/James+Clear" itemprop="url">
# <span itemprop="name">
#                                     James Clear</span>
# </a>
# </span>
# </div>
# <ul class="social-wrap hidden-xs hidden-sm hidden-md">
# <li class="label">Compartir</li>
# <li><a href="mailto:?subject=Sharing a book&amp;body=I saw this book at Book Depository and thought you might like it:%0D%0A%0D%0Ahttps://www.bookdepository.com/es/Atomic-Habits-James-Clear/9781847941831" target="_blank"><i class="icon-em"></i></a></li>
# <li><a href="/es/share/book?id=37098319&amp;service=facebook&amp;mess=book" target="_blank"><i class="icon-fb"></i></a></li>
# <li><a href="https://twitter.com/intent/tweet?text=I've+discovered+Atomic+Habits&amp;url=https%3a%2f%2fwww.bookdepository.com%2fes%2fAtomic-Habits-James-Clear%2f9781847941831&amp;via=bookdepository" target="_blank"><i class="icon-tw"></i></a></li>
# <li><a href="http://pinterest.com/pin/create/button/?url=https://www.bookdepository.com/es/Atomic-Habits-James-Clear/9781847941831&amp;media=https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8479/9781847941831.jpg&amp;description=THE-PHENOMENAL-INTERNATIONAL-BESTSELLER-1-MILLION-COPIES-SOLD-Transform-your-life-with-tiny-changes-in-behaviour-starting-now-People-think-that-when-you-want-to-change-your-life-you-need-to-think-big" target="_blank"><i class="icon-pi"></i></a></li>
# </ul>
# </div>
# <div class="item-tools">
# <div class="checkout-tools">
# <div class="rating-wrap visible-md">
# <a href="#rating-distribution">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# <span>
#                                         4.38</span>
# <span class="rating-count">
#                                         (567,225 opiniones de clientes de Goodreads)
# </span>
# </div>
# <div class="price-info-wrap">
# <div class="item-info-wrap">
# <div class="copy-content visible-md" data-target=".meta-info"></div>
# <div class="copy-content visible-md" data-target=".author-info"></div>
# <div class="hidden-xs hidden-sm">
# <div class="price item-price-wrap" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
# <span class="sale-price">21,40 €</span>
# <meta content="EUR" itemprop="priceCurrency"/>
# <meta content="21.40" itemprop="price"/>
# <span class="price-save-link-omnibus">
# <a href="/es/help/topic/HelpId/RRP#helpContent">
#                                                          PVPR</a>:
#                                                 </span>
# <span class="list-price">22,00 €</span>
# <p class="price-save omnibus">
# <a href="/es/help/topic/HelpId/lowestprice#helpContent">
#                                                                             Precio mínimo 30 días</a>:
#                                                                         <span>20,87 €</span>
# </p>
# </div>
# </div>
# <div class="copy-content visible-md visible-xs visible-sm" data-target=".formats-wrap"></div>
# <div class="free-delivery-text">
# <i class="icon-rocket"></i>
# <p>Envío gratis</p>
# </div>
# <div class="gst-disclaimer" id="brexit_no_fee_message">
# <i class="icon-check"></i>
# <p>El precio incluye IVA/impuestos de importación para envíos a la UE</p>
# </div>
# <div class="availability-text">
# <i class="icon-check"></i>
# <div class="edd-availability-text">
# <p>Disponible. Entrega estimada a Spain en 6-11 días laborables.</p>
# <br/>
# <a class="edd-help-page-link" href="/es/help/topic/HelpId/2/When-will-my-order-arrive" target="_blank">
#                                                                         ¿La dirección de tu pedido no está en Spain? Click <span class="edd-help-page-link-here">aquí.<span></span></span></a>
# <br/>
# </div>
# </div>
# </div>
# </div>
# <div class="btn-wrap">
# <div class="copy-content visible-xs visible-sm" data-target=".item-price-wrap"></div>
# <a class="btn btn-primary add-to-basket" data-currency="EUR" data-isbn="9781847941831" data-price="21.40" data-show-related="true" href="/es/basket/addisbn/isbn13/9781847941831">
#                                             Añadir a la cesta<input id="isOmnibusApplicable" type="hidden"/>
# </a>
# <a class="btn btn-grey add-to-wishlist" data-isbn="9781847941831" href="/es/account/wishlistItemUpdate?mainAction=add&amp;isbn13=9781847941831" rel="nofollow">
#                                     Añadir a la Lista de deseos</a>
# <div class="copy-content visible-xs visible-sm" data-target=".social-wrap"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="item-description">
# <h2>Descripción</h2>
# <div class="item-excerpt trunc" data-height="230" itemprop="description">
#
#                             THE PHENOMENAL INTERNATIONAL BESTSELLER: OVER 1O MILLION COPIES SOLD WORLDWIDE<br/>
# <br/>
#                             Transform your life with tiny changes in behaviour, starting now.<br/>
# <br/>
#                             People think that when you want to change your life, you need to think big. But world-renowned habits expert James Clear has discovered another way. He knows that real change comes from the compound effect of hundreds of small decisions: doing two push-ups a day, waking up five minutes early, or holding a single short phone call.<br/>
# <br/>
#                             He calls them atomic habits.<br/>
# <br/>
#                             In this ground-breaking book, Clears reveals exactly how these minuscule changes can grow into such life-altering outcomes. He uncovers a handful of simple life hacks (the forgotten art of Habit Stacking, the unexpected power of the Two Minute Rule, or the trick to entering the Goldilocks Zone), and delves into cutting-edge psychology and neuroscience to explain why they matter. Along the way, he tells inspiring stories of Olympic gold medalists, leading CEOs, and distinguished scientists who have used the science of tiny habits to stay productive, motivated, and happy.<br/>
# <br/>
#                             These small changes will have a revolutionary effect on your career, your relationships, and your life.<br/>
#                             ________________________________<br/>
#                             A NEW YORK TIMES AND SUNDAY TIMES BESTSELLER<br/>
# <br/>
#                             'A supremely practical and useful book.' Mark Manson, author of The Subtle Art of Not Giving A F*ck<br/>
# <br/>
#                             'James Clear has spent years honing the art and studying the science of habits. This engaging, hands-on book is the guide you need to break bad routines and make good ones.' Adam Grant, author of Originals<br/>
# <br/>
#                             'Atomic Habits is a step-by-step manual for changing routines.' Books of the Month, Financial Times<br/>
# <br/>
#                             'A special book that will change how you approach your day and live your life.' Ryan Holiday, author of The Obstacle is the Way<br/>
# <a class="read-more" tabindex="0">ver más</a>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script>
# <div class="hero-quick-promo-wrap">
# <h2 class="hero-quick-promo-title"><a href="https://www.bookdepository.com/spanish">¡Descubre Miles de Libros en Español!</a></h2>
# <div class="hero-quick-promo-container">
# <div class="img-container">
# <img src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/content/COUNTRY_1112.jpg"/>
# </div>
# <div class="text-container">
# <a href="https://www.bookdepository.com/spanish">Tenemos más de <strong>1.000.000 libros </strong> en Español!!</a>
# </div>
# </div>
# </div>
# <div class="biblio-wrap">
# <div class="biblio-info-wrap">
# <h2 class="biblio-title">
#                             Detalles del producto</h2>
# <ul class="biblio-info">
# <li>
# <label>Formato</label>
# <span>
#                                 Paperback
#                                     | <span itemprop="numberOfPages">320 páginas
# </span>
# </span>
# </li>
# <li>
# <label>Dimensiones</label>
# <span>
#                                 153
#                                     x 234
#                                     x 23mm
#
#                                     | 390g
#                                 </span>
# </li>
# <li>
# <label>Fecha de publicación</label>
# <span itemprop="datePublished">27 Nov 2018</span>
# </li>
# <li>
# <label>Editorial</label>
# <span itemprop="publisher" itemscope="Cornerstone" itemtype="http://schema.org/Organization">
# <a href="/es/publishers/Cornerstone" itemprop="url">
# <span itemprop="name">
#                                         Cornerstone</span>
# </a>
# </span>
# </li>
# <li>
# <label>Sello editorial</label>
# <span>Random House Business Books</span>
# </li>
# <li>
# <label>Ciudad/País de publicación</label>
# <span>
#                                 London, United Kingdom</span>
# </li>
# <li>
# <label>Idioma</label>
# <span>
#                                 English</span>
# </li>
# <li>
# <label>ISBN13</label>
# <span itemprop="isbn">9781847941831</span>
# </li>
# <li>
# <label>Ranking en los libros más vendidos</label>
# <span>
#                                 2</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="detail-page-carousel-wrap">
# </div><ol class="breadcrumb category-footer">
# <li class="title">Categorías:</li>
# <li>
# <a href="/es/category/763/Social-Group-Or-Collective-Psychology">
#                                         Social, Group Or Collective Psychology</a>
# </li>
# <li>
# <a href="/es/category/770/Cognition-Cognitive-Psychology">
#                                         Cognition &amp; Cognitive Psychology</a>
# </li>
# <li>
# <a href="/es/category/956/Finance-Accounting">
#                                         Finance &amp; Accounting</a>
# </li>
# <li>
# <a href="/es/category/2793/Dating-Relationships-Living-Together-Marriage">
#                                         Dating, Relationships, Living Together &amp; Marriage</a>
# </li>
# <li>
# <a href="/es/category/2802/Personal-Development">
#                                         Personal Development</a>
# </li>
# <li>
# <a href="/es/category/2804/Advice-On-Careers-Achieving-Success">
#                                         Advice On Careers &amp; Achieving Success</a>
# </li>
# <li>
# <a href="/es/category/2812/Popular-Psychology">
#                                         Popular Psychology</a>
# </li>
# <li class="active">
# <a href="/es/category/2813/Assertiveness-Motivation-Self-esteem">
#                                         Assertiveness, Motivation &amp; Self-esteem</a>
# </li>
# </ol>
# <div class="item-annotation-wrap" id="item-annotation">
# <div class="item-annotation">
# <h2>Review Text</h2>
# <div class="block text-block trunc" data-height="100">
#                                     James Clear has spent years honing the art and studying the science of habits. This engaging, hands-on book is the guide you need to break bad routines and make good ones.<br/>
# <a class="read-more" tabindex="0">ver más</a>
# </div>
# </div>
# <div class="item-annotation">
# <h2>Review quote</h2>
# <div class="block text-block trunc" data-height="100">
#                                     A supremely practical and useful book. James Clear distils the most fundamental information about habit formation, so you can accomplish more by focusing on less. -- Mark Manson, author of The Subtle Art of Not Giving a F*ck It's an absolutely fabulous book and it doesn't surprise me that it's sold so many copies . . . Very useful, very practical, super well-researched. -- Dr Rangan Chatterjee Atomic Habits is a step-by-step manual for changing routines . . . Inspiring real-life stories. * Financial Times * James Clear has spent years honing the art and studying the science of habits. This engaging, hands-on book is the guide you need to break bad routines and make good ones. A special book that will change how you approach your day and live your life. Excellent . . .  I'm almost done with my PhD in organisational psychology and James did a brilliant job describing much of the science in psychology and neuroscience. * Inc. * I'd attribute about 60 per cent of my good habits to [James Clear's] blog and this book is rapidly filling in the other 40 per cent. Zeroes in on the science behind building good habits and breaking bad ones . . . enlightening. * Business Insider * Atomic Habits [is] a new book by James Clear that I'm relying on to develop realistic goals. * Financial Times * In Atomic Habits, author and self-improvement guru James Clear outlines a practical framework for improving just about every aspect of your life through the power of habit. * Globe and Mail * James Clear argues that the key [to changing your behaviour] is in making tiny changes that, over time, compound into large transformations. This book shows you how. * Fast Company * Want to improve your fitness this year? Start with small ambitions - the results will be better . . . It's a theory that has caught the imagination of James Clear, the author of a new book called Atomic Habits. * The Times * Illuminating . . . The attractive message . . . is that life doesn't have to be a chore or a bore . . . The first move toward order might be a step as small as putting on your exercise clothes. * Wall Street Journal * You may have heard the key to habit formation is starting small. But you've likely never considered starting as small as James Clear suggests in his new book Atomic Habits. * New York Times * Full of practical insights and tips, this will inspire you to make that tiny change today. * Sun * If you are someone looking to gain some knowledge about creativity, happiness, health, productivity, picking this book is the right choice. [Clear's] book is the proper blueprint that tells how to form some good habits, let go of your bad ones and what little changes one needs to bring to become better. And in case you thought it is all talk, let us tell you the book is packed with evidence-based strategies. Clear's book actually has the potential to change a lot of things. * Entrepreneur * If you are someone looking to gain some knowledge about creativity, happiness, health, productivity, picking this book is the right choice. [Clear's] book is the proper blueprint that tells how to form some good habits, let go of your bad ones and what little changes one needs to bring to become better. And in case you thought it is all talk, let us tell you the book is packed with evidence-based strategies. Clear's book actually has the potential to change a lot of things. * Entrepreneur * When talking about habits we can't enter the habit debate without James Clear . . . It was satisfying to read this book as it felt like I was getting validation from this guy . . . Powerful sh*t. -- The James Smith Podcast A no-nonsense, pragmatic guide that draws on proven frameworks from biology, psychology and neuroscience to determine how to build long-lasting good habits and decisively break bad ones . . . Clear imparts a vast supply of practical advice that enables readers to take concrete steps towards achieving their goals. * Oxford Student * Simpl ...
# <a class="read-more" tabindex="0">ver más</a>
# </div>
# </div>
# <div class="item-annotation">
# <h2>About James Clear</h2>
# <div class="block text-block trunc" data-height="100">
#                                     James Clear is an expert on habits and decision making. He made his name as the author of one of the fastest-growing email newsletters in history, which grew from zero to 100,000 subscribers in under two years. Today, his newsletter has over 400,000 subscribers, and his articles at jamesclear.com receive 10 million hits each year. His work frequently appears in publications including the New York Times, Forbes and Business Insider.<br/>
# <a class="read-more" tabindex="0">ver más</a>
# </div>
# </div>
# </div>
# <div class="rating-distribution-wrap">
# <div class="rating-distribution" id="rating-distribution">
# <h2>Opiniones de clientes</h2>
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# <div class="rating_count_and_value">
# <div itemprop="ratingValue">
#                    4.38 de 5 estrellas</div>
# <span class="rating-separator">-</span>
# <span class="rating-count">
#                     (567,225 opiniones)</span>
# </div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         5</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="54.69698973070651"></span>
# </span>
#
#                     55% (310,255)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         4</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="32.274141654546256"></span>
# </span>
#
#                     32% (183,067)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         3</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="10.283220944069814"></span>
# </span>
#
#                     10% (58,329)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         2</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="1.8564061880206268"></span>
# </span>
#
#                     2% (10,530)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         1</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="0.889241482656794"></span>
# </span>
#
#                     1% (5,044)</div>
# </div>
# </div>
# <div class="ratings-credit-wrap">
# <div class="ratings-credit">
#                             Opiniones de clientes de <span id="goodreads-credit"> Goodreads</span></div>
# <div class="goodreads-credit-extended">
# <a class="exit-to-goodreads" href="/es/external/GR/60616246" target="_blank">Goodreads</a> es el sitio más grande del mundo para lectores con más de 50 millones de opiniones. Te mostramos millones de opiniones de clientes de Goodreads en nuestro sitio web para ayudarte a seleccionar tu siguiente libro.<span class="goodreads-close">
#                         Cerrar</span>
# <span class="goodreads-close-x">
#                          X</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-top">
# <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/es/newsletter/add">
# <div class="form-group">
# <input aria-label="Dirección de correo electrónico para suscribirte a nuestro Newsletter" class="form-control" name="newsletterEmailAddress" placeholder="" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                                 Sign up now
#                             </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-social-wrap">
# <h4>
#             Síguenos</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository_es" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Explorar</h4>
# <ul>
# <li><a href="/es/about-us" rel="nofollow">
#                             Acerca de nosotros</a></li>
# <li><a href="/es/sitemap">
#                             Mapa del sitio</a></li>
# <li><a href="/es/bookmarks">
#                             Favoritos</a></li>
# <li><a href="/es/blog">
#                             Book Blog</a></li>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account">
#                                     Iniciar sesión/Crear cuenta</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>¿Cómo podemos ayudarte?</h4>
# <ul>
# <li>
# <a href="/es/help" rel="nofollow">
#                                 Ayuda</a>
# </li>
# <li>
# <a href="/es/contactus">
#                                 Contáctanos</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                                 ¿Dónde está mi pedido?</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                                 ¿Dónde entregan?</a>
# </li>
# <li>
# <a href="/es/cancelorder" rel="nofollow">
#                                 Cancelar mi pedido</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/112#helpContent" rel="nofollow">
#                                 Devolver mi pedido</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Únete a nosotros</h4>
# <ul>
# <li><a href="/es/affiliate">
#                             Afiliados</a></li>
# <li><a href="/es/jobs">
#                             Trabajos</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Información importante</h4>
# <ul>
# <li>
# <a href="/es/help/topic/HelpId/Complaints#helpContent" rel="nofollow">
#                                 Reclamaciones</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                                 Cookies</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                                 Política de privacidad</a>
# </li>
# <li>
# <a href="/es/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                                 Términos y condiciones</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/es/account/login/to/account" rel="nofollow">
#                                     Iniciar sesión/Crear cuenta</a></li>
# <li><a href="/es/track">
#                             Mis pedidos</a></li>
# <li><a href="/es/contactus">
#                             Contáctanos</a></li>
# <li><a href="/es/help">
#                             Ayuda</a></li>
# <li><a href="/es/about-us" rel="nofollow">
#                             Acerca de nosotros</a></li>
# <li><a href="/es/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                             Términos y condiciones</a></li>
# <li><a href="/es/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                             Política de privacidad</a></li>
# <li><a href="/es/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                             Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>Aceptamos estos métodos de pago </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2022-6', requestTime='0.04 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='90.75.129.53', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Tue Feb 28 08:30:54 UTC 2023, cacheEnabled=true}}">
#                         © 2023
#                         The Book Depository Ltd.UK.<br/>Número de registro de la compañía: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#       window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/js/app.js";
#     </script>
# <script type="text/javascript">
#       csmWidgetStart('firstload-js-download');
#     </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.74/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Comprar","bd_js_too_long_for_shipping_label":"Eso es demasiado largo para nuestras etiquetas de envío","bd_js_why_are_you_leaving":"¿Por qué te vas?","bd_omnibus_ph1_price_statement_suffix":"vs RRP","bd_js_too_long":"Eso es demasiado largo","bd_js_could_not_find_address_try_again":"No pudimos encontrar la dirección. Inténtalo de nuevo","bd_js_lack_of_reviews":"Falta de opiniones","bd_saving_percent_off":"Ahorra&lt;br&gt;{0}%","bd_js_missing_book_information":"Falta la información del libro o la portada","bd_js_total_basket_count":"{0, plural, one {Tienes &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;producto&lt;/span&gt;&lt;/b&gt; en el carrito} other {Tienes &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;productos&lt;/span&gt;&lt;/b&gt; en el carrito}}","bd_js_total_cost":"Costo total: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"mostrar menos","bd_try_abe_books":"Prueba AbeBooks","bd_js_item_added_to_your_basket":"Se agregó el producto en el carrito","bd_js_quick_view":"Vista rápida","bd_js_lack_of_inside_images":"Falta de imágenes internas","bd_rrp":"PVPR","bd_link_prefix":"/es","bd_js_wrong_book_information":"Información o portada incorrecta del libro","bd_js_unable_get_address_enter_manually":"No podemos obtener la dirección. Ingrésala manualmente:","bd_js_keep_typing_to_refine_search_results":"Sigue escribiendo para ajustar los resultados de búsqueda","bd_pre_order":"Comprar en preventa","bd_js_top_categories":"Categorías principales","bd_price_save":"Ahorra {0}","bd_notify_me":"Notificarme","bd_js_name_only_letters":"El nombre completo solo puede contener letras","bd_js_show_more":"mostrar más","bd_js_enter_valid_email_address":"Ingresa una dirección de correo electrónico válida","bd_js_delivery_time":"Hora de entrega","bd_js_enter_address_manually":"Ingresar la dirección manualmente","bd_js_more_categories":"Más categorías","bd_30_day_low_price_carousel":"Más bajo","bd_js_continue_shopping":"Seguir comprando","bd_js_account_and_help":"Cuenta y ayuda","bd_js_price":"Precio","bd_js_basket_checkout":"Carrito/proceder al pago","bd_add_to_basket":"Añadir a la cesta","bd_js_enter_first_last_name":"Ingresa un nombre y apellido","bd_js_please_enter_your":"Ingresa tu"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#         var iCookieLength = 30; // Cookie length in days
#         var sCookieName = "source"; // Name of the first party cookie to utilise for last click referrer de-duplication
#         var sSourceParameterName = "source"; // The parameter used by networks and other marketing channels to tell you who drove the traffic
#         var domain = "example.com"; // top level domain
#
#         var _getQueryStringValue = function (sParameterName) {
#             var aQueryStringPairs = document.location.search.substring(1).split("&");
#             for (var i = 0; i < aQueryStringPairs.length; i++) {
#                 var aQueryStringParts = aQueryStringPairs[i].split("=");
#                 if (sParameterName.toLowerCase() == aQueryStringParts[0].toLowerCase()) {
#                     return aQueryStringParts[1];
#                 }
#             }
#         };
#
#         var _setCookie = function (sCookieName, sCookieContents, iCookieLength, tlDomain) {
#             var dCookieExpires = new Date();
#             dCookieExpires.setTime(dCookieExpires.getTime() + (iCookieLength * 24 * 60 * 60 * 1000));
#             document.cookie = sCookieName + "=" + sCookieContents + "; expires=" + dCookieExpires.toGMTString() +";domain=" + tlDomain + "; path=/;";
#         };
#
#         if (_getQueryStringValue(sSourceParameterName)) {
#             _setCookie(sCookieName, _getQueryStringValue(sSourceParameterName), iCookieLength, domain);
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# Obtenemos el titulo del libro

# %%
soup.h1.get_text()
# Out:
# 'Los más vendidos — nuestros artículos más populares, actualizados diariamente.'

# %% [markdown]
# El rating

# %%
rating_count = soup_libro.find('span', class_='rating-count')\
        .get_text(strip=True)[1:].split()[0]\
        .replace(',','')
rating_count = int(rating_count)
rating_count
# Out:
# 567225

# %%
price = soup_libro.find('span',class_= 'sale-price')\
        .get_text().split()[0].replace(',', '.')
price = float(price)
price
# Out:
# 21.4

# %% [markdown]
#  Cuantas opiniones tiene el libro

# %%
rating_count = soup_libro.find("span", class_="rating-count").get_text()
rating_count
# Out:
# '\n                                    (567,225 opiniones de clientes de Goodreads)\n'

# %% [markdown]
# Tipo de formato

# %%
# Out:
# 'Paperback'

# %% [markdown]
# Autor

# %%
# Out:
# 'James Clear'

# %% [markdown]
# Precio

# %%
# Out:
# 20.81

# %% [markdown]
# Url de la portada

# %%
# Out:
# <img alt="Atomic Habits" class="book-img" itemprop="image" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8479/9781847941831.jpg"/>

# %%
# Out:
# 'https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8479/9781847941831.jpg'

# %% [markdown]
# Ahora lo automatizamos para hacer un web scraping

# %%
pages = np.arange(1,3)
count = 1
for page in pages:
    URL = "https://www.bookdepository.com/es/bestsellers?page=" + str(page)
    r = requests.get(URL)
    soup = bs(r.text, "lxml")
    libros_grid = soup.find_all("div", class_="item-img")
    count_libro = 1
   
    for libro in libros_grid:
        #print del seguimiento de descarga
        print("Libro {} de {}, pag {} / {}".format(
            count_libro, len(libros_grid), page, len(pages)
        ))
        URL_libro = libro.find("a")["href"]
        r = requests.get(url_principal+URL_libro)
        soup_libro = bs(r.text, "lxml")

        

        #establecer ID para cada libro
        id_libro = "lb_" + str(count)
        
        name = soup_libro.find("h1").getText()
        try:
            price = float(soup_libro.find(class_="sale-price").text.split(" ")[0].replace(",","."))
        except:
            price = None

        print("Titulo {}: {}€".format(name, price))
        count_libro+=1
        count +=1
        
        #diccionario
        data  = {"id_libro": id_libro,
                 "name": name,
                 "price": price
                 }
# Out:
# Libro 1 de 30, pag 1 / 2
# Titulo How to Paint Without a Brush : The Art of Red Hong Yi: 31.0€
# Libro 2 de 30, pag 1 / 2
# Titulo Atomic Habits : the life-changing million-copy #1 bestseller: 20.87€
# Libro 3 de 30, pag 1 / 2
# Titulo Young Forever : The Secrets to Living Your Longest, Healthiest Life: 22.49€
# Libro 4 de 30, pag 1 / 2
# Titulo Things We Hide From The Light : the unforgettable sequel to global bestseller Things We Never Got Over: 14.49€
# Libro 5 de 30, pag 1 / 2
# Titulo It Ends With Us: The most heartbreaking novel you'll ever read : The most heartbreaking novel you'll ever read: 13.09€
# Libro 6 de 30, pag 1 / 2
# Titulo The Letters I Will Never Send : poems to read, to write and to share: 18.5€
# Libro 7 de 30, pag 1 / 2
# Titulo The Parenting Map : Step-by-Step Solutions to Consciously Create the Ultimate Parent-Child Relationship: 31.55€
# Libro 8 de 30, pag 1 / 2
# Titulo UPROAR! : Satire, Scandal and Printmakers in Georgian London: 28.69€
# Libro 9 de 30, pag 1 / 2
# Titulo The Parenting Map : Step-by-Step Solutions to Consciously Create the Ultimate Parent-Child Relationship: 21.0€
# Libro 10 de 30, pag 1 / 2
# Titulo I Don't Need Therapy : (and other lies I've told myself): 35.16€
# Libro 11 de 30, pag 1 / 2
# Titulo Seven Husbands of Evelyn Hugo : The Sunday Times Bestseller: 13.14€
# Libro 12 de 30, pag 1 / 2
# Titulo Before the Coffee Gets Cold: 13.74€
# Libro 13 de 30, pag 1 / 2
# Titulo Final Offer : meet the new Dreamland billionaire...: 13.39€
# Libro 14 de 30, pag 1 / 2
# Titulo The Body Keeps the Score : Mind, Brain and Body in the Transformation of Trauma: 17.05€
# Libro 15 de 30, pag 1 / 2
# Titulo Twisted Love: 12.72€
# Libro 16 de 30, pag 1 / 2
# Titulo Verity : The thriller that will capture your heart and blow your mind: 13.11€
# Libro 17 de 30, pag 1 / 2
# Titulo The Psychology of Money : Timeless lessons on wealth, greed, and happiness: 18.17€
# Libro 18 de 30, pag 1 / 2
# Titulo Small Things Like These : Shortlisted for the Booker Prize 2022: 16.22€
# Libro 19 de 30, pag 1 / 2
# Titulo Things We Never Got Over : the must-read romantic comedy and TikTok bestseller!: 12.7€
# Libro 20 de 30, pag 1 / 2
# Titulo Twisted Games: 13.0€
# Libro 21 de 30, pag 1 / 2
# Titulo Foster : by the Booker-shortlisted author of Small Things Like These: 12.75€
# Libro 22 de 30, pag 1 / 2
# Titulo Icebreaker: 13.56€
# Libro 23 de 30, pag 1 / 2
# Titulo The Midnight Library : The No.1 Sunday Times bestseller and worldwide phenomenon: 17.46€
# Libro 24 de 30, pag 1 / 2
# Titulo Rethink Your Position : Reshape Your Exercise, Yoga, and Everyday Movement, One Part at a Time: 21.71€
# Libro 25 de 30, pag 1 / 2
# Titulo The Fine Print: 12.98€
# Libro 26 de 30, pag 1 / 2
# Titulo Spare: 26.27€
# Libro 27 de 30, pag 1 / 2
# Titulo Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 5: 20.15€
# Libro 28 de 30, pag 1 / 2
# Titulo The Boy, The Mole, The Fox and The Horse: 21.26€
# Libro 29 de 30, pag 1 / 2
# Titulo Me vs Brain : An Overthinker's Guide to Life: 31.28€
# Libro 30 de 30, pag 1 / 2
# Titulo The Adventure Zone: The Eleventh Hour: 19.77€
# Libro 1 de 30, pag 2 / 2
# Titulo Terms and Conditions: 13.12€
# Libro 2 de 30, pag 2 / 2
# Titulo The One Thing : The Surprisingly Simple Truth Behind Extraordinary Results: Achieve your goals with one of the world's bestselling success books: 16.18€
# Libro 3 de 30, pag 2 / 2
# Titulo Twisted Hate: 13.21€
# Libro 4 de 30, pag 2 / 2
# Titulo Twisted Lies: 13.34€
# Libro 5 de 30, pag 2 / 2
# Titulo Loss : Poems to better weather the many waves of grief: 12.23€
# Libro 6 de 30, pag 2 / 2
# Titulo Strong Female Character : The Sunday Times Bestseller: None€
# Libro 7 de 30, pag 2 / 2
# Titulo Bored of Lunch: The Healthy Slow Cooker Book : THE NUMBER ONE BESTSELLER: 23.66€
# Libro 8 de 30, pag 2 / 2
# Titulo Daisy Jones and The Six: 14.17€
# Libro 9 de 30, pag 2 / 2
# Titulo Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 5 (Special Edition): 28.0€
# Libro 10 de 30, pag 2 / 2
# Titulo The Kindness Method : The Highly Effective (and extremely enjoyable) Way to Change Your Habits: 13.62€
# Libro 11 de 30, pag 2 / 2
# Titulo Four Thousand Weeks : Embrace your limits. Change your life. Make your four thousand weeks count.: 14.66€
# Libro 12 de 30, pag 2 / 2
# Titulo The Daily Stoic : 366 Meditations on Wisdom, Perseverance, and the Art of Living:  Featuring new translations of Seneca, Epictetus, and Marcus Aurelius: 14.42€
# Libro 13 de 30, pag 2 / 2
# Titulo Lessons in Chemistry : The No. 1 Sunday Times bestseller and BBC Between the Covers Book Club pick: 14.62€
# Libro 14 de 30, pag 2 / 2
# Titulo Scattered Minds : The Origins and Healing of Attention Deficit Disorder: 16.46€
# Libro 15 de 30, pag 2 / 2
# Titulo Grandmaster of Demonic Cultivation: Mo Dao Zu Shi (Novel) Vol. 4: 19.16€
# Libro 16 de 30, pag 2 / 2
# Titulo The Silent Patient : The record-breaking, multimillion copy Sunday Times bestselling thriller and TikTok sensation: 12.04€
# Libro 17 de 30, pag 2 / 2
# Titulo Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 4: 19.46€
# Libro 18 de 30, pag 2 / 2
# Titulo 12 Rules for Life : An Antidote to Chaos: 15.07€
# Libro 19 de 30, pag 2 / 2
# Titulo Amygdala: 132.09€
# Libro 20 de 30, pag 2 / 2
# Titulo The Power of Now : (20th Anniversary Edition): 14.09€
# Libro 21 de 30, pag 2 / 2
# Titulo Cleopatra and Frankenstein: 14.51€
# Libro 22 de 30, pag 2 / 2
# Titulo Heaven Official's Blessing: Tian Guan Ci Fu (Novel) Vol. 3: 18.22€
# Libro 23 de 30, pag 2 / 2
# Titulo Magnolia Parks : TikTok made me buy it! The addictive romance sensation - Book 1: 15.86€
# Libro 24 de 30, pag 2 / 2
# Titulo Thinking, Fast and Slow: 17.46€
# Libro 25 de 30, pag 2 / 2
# Titulo Sasaki and Miyano, Vol. 7: 14.43€
# Libro 26 de 30, pag 2 / 2
# Titulo The Creative Act : A Way of Being: The Sunday Times bestseller: None€
# Libro 27 de 30, pag 2 / 2
# Titulo When the Body Says No : The Cost of Hidden Stress: 16.32€
# Libro 28 de 30, pag 2 / 2
# Titulo The Husky and His White Cat Shizun: Erha He Ta De Bai Mao Shizun (Novel) Vol. 2: 20.15€
# Libro 29 de 30, pag 2 / 2
# Titulo Better Than the Movies: 14.1€
# Libro 30 de 30, pag 2 / 2
# Titulo The Secret History : From the Pulitzer Prize-winning author of The Goldfinch: 14.93€

# %% [markdown]
# ---------------

# %%
# Out:
#    id_libro                                               name  price  \
# 0      lb_1       Me vs Brain : An Overthinker's Guide to Life  26.90
# 1      lb_2  Atomic Habits : the life-changing million-copy...  20.81
# 2      lb_3  The Letters I Will Never Send : poems to read,...  18.50
# 3      lb_4  It Ends With Us: The most heartbreaking novel ...  12.58
# 4      lb_5  Final Offer : meet the new Dreamland billionai...  13.36
# 5      lb_6  The Body Keeps the Score : Mind, Brain and Bod...  17.01
# 6      lb_7  UPROAR! : Satire, Scandal and Printmakers in G...  30.50
# 7      lb_8  Verity : The thriller that will capture your h...  13.06
# 8      lb_9                                         Icebreaker  12.59
# 9     lb_10  Timeless Textured Baby Crochet : 20 heirloom c...  22.27
# 10    lb_11  The Midnight Library : The No.1 Sunday Times b...  12.36
# 11    lb_12                        Before the Coffee Gets Cold  13.70
# 12    lb_13  Seven Husbands of Evelyn Hugo : The Sunday Tim...  12.49
# 13    lb_14  The Psychology of Money : Timeless lessons on ...  18.12
# 14    lb_15                                     The Fine Print  12.94
# 15    lb_16  How to Paint Without a Brush : The Art of Red ...  30.50
# 16    lb_17  The Reverse Coloring Book (R) : The Book Has t...  32.74
# 17    lb_18                                       Twisted Love  12.68
# 18    lb_19  The Mini ADHD Coach : How to (finally) Underst...  21.47
# 19    lb_20  Small Things Like These : Shortlisted for the ...  12.43
# 20    lb_21                               Terms and Conditions  13.09
# 21    lb_22           12 Rules for Life : An Antidote to Chaos  15.03
# 22    lb_23  The Daily Stoic : 366 Meditations on Wisdom, P...  14.25
# 23    lb_24  Things We Never Got Over : the must-read roman...  12.50
# 24    lb_25  I Don't Need Therapy : (and other lies I've to...  21.37
# 25    lb_26  Glucose Revolution : The life-changing power o...  16.98
# 26    lb_27  Heaven Official's Blessing: Tian Guan Ci Fu (N...  19.67
# 27    lb_28                                              Spare  26.16
# 28    lb_29  Things We Hide From The Light : the unforgetta...  13.19
# 29    lb_30  The Silent Patient : The record-breaking, mult...  12.01
# 30    lb_31                            Strong Female Character  19.89
# 31    lb_32  Grandmaster of Demonic Cultivation: Mo Dao Zu ...  28.00
# 32    lb_33  The Silent Patient : The record-breaking, mult...  12.01
# 33    lb_34           The Boy, The Mole, The Fox and The Horse  20.80
# 34    lb_35  The One Thing : The Surprisingly Simple Truth ...  12.49
# 35    lb_36  Bored of Lunch: The Healthy Slow Cooker Book :...  23.20
# 36    lb_37  Foster : by the Booker-shortlisted author of S...  12.72
# 37    lb_38  Glucose Revolution : The life-changing power o...  16.98
# 38    lb_39                            Daisy Jones and The Six  14.13
# 39    lb_40  Attached : Are you Anxious, Avoidant or Secure...  14.70
# 40    lb_41  The Parenting Map : Step-by-Step Solutions to ...  31.23
# 41    lb_42                            Thinking, Fast and Slow  17.42
# 42    lb_43  The Parenting Map : Step-by-Step Solutions to ...  21.00
# 43    lb_44                                    Chain of Thorns  29.96
# 44    lb_45                                       Twisted Lies  13.31
# 45    lb_46  Four Thousand Weeks : Embrace your limits. Cha...  14.63
# 46    lb_47                                       Twisted Hate  13.18
# 47    lb_48  The Secret History : From the Pulitzer Prize-w...  14.89
# 48    lb_49  No Bad Parts : Healing Trauma and Restoring Wh...  15.58
# 49    lb_50  The Husky and His White Cat Shizun: Erha He Ta...  20.42
# 50    lb_51  Heaven Official's Blessing: Tian Guan Ci Fu (N...  19.39
# 51    lb_52  Grandmaster of Demonic Cultivation: Mo Dao Zu ...  18.57
# 52    lb_53                            Where the Crawdads Sing  12.50
# 53    lb_54  A Man Called Ove : Now a major film starring T...  12.25
# 54    lb_55                                            Climate  18.27
# 55    lb_56                                           Manifest  19.68
# 56    lb_57                  Vagabond (VIZBIG Edition), Vol. 2  22.79
# 57    lb_58                               The Song of Achilles  13.94
# 58    lb_59  King of Wrath : from the bestselling author of...  12.82
# 59    lb_60                       The Concise 48 Laws Of Power  13.12
#
#                              author     format  rating  rating_count  \
# 0                     Hayley Morris   Hardback     NaN           NaN
# 1                       James Clear  Paperback    4.38      567225.0
# 2                    Isabella Dorta  Paperback    1.00           1.0
# 3                    Colleen Hoover  Paperback    4.30     2215115.0
# 4                      Lauren Asher  Paperback    4.64        1330.0
# 5               Bessel van der Kolk  Paperback    4.46      121368.0
# 6                      Alice Loxton   Hardback    4.50           4.0
# 7                    Colleen Hoover  Paperback    4.38     1663104.0
# 8                      Hannah Grace  Paperback    4.13      127592.0
# 9                        Vita Apala  Paperback     NaN           NaN
# 10                        Matt Haig  Paperback    4.02     1286701.0
# 11              Toshikazu Kawaguchi  Paperback    3.75      207042.0
# 12              Taylor Jenkins Reid  Paperback    4.46     1927116.0
# 13                    Morgan Housel  Paperback    4.38       98673.0
# 14                     Lauren Asher  Paperback    3.97      182874.0
# 15                      Red Hong Yi   Hardback     NaN           NaN
# 16                    Kendra Norton  Paperback    4.42          24.0
# 17                        Ana Huang  Paperback    3.78      289195.0
# 18                    Alice Gendron   Hardback    5.00           1.0
# 19                    Claire Keegan  Paperback    4.21       57404.0
# 20                     Lauren Asher  Paperback    4.23      125903.0
# 21               Jordan B. Peterson  Paperback    3.93      184038.0
# 22                     Ryan Holiday  Paperback    4.36       30090.0
# 23                       Lucy Score  Paperback    4.27      305631.0
# 24                       Toni Lodge  Paperback    4.00           3.0
# 25                 Jessie Inchauspe  Paperback    4.52        7409.0
# 26                Mo Xiang Tong Xiu  Paperback    4.76        2386.0
# 27  Prince Harry the Duke of Sussex   Hardback    4.07      110750.0
# 28                       Lucy Score  Paperback    4.30         598.0
# 29                 Alex Michaelides  Paperback    4.18     1416064.0
# 30                       Fern Brady   Hardback    4.86         119.0
# 31               Mo Xiang Tong Xiu;  Paperback    4.71           7.0
# 32                 Alex Michaelides  Paperback    4.18     1416064.0
# 33                  Charlie Mackesy   Hardback    4.56      145114.0
# 34                      Gary Keller  Paperback    4.13       59312.0
# 35                   Nathan Anthony   Hardback    4.38          13.0
# 36                    Claire Keegan  Paperback    4.33       19866.0
# 37                 Jessie Inchauspe  Paperback    4.52        7409.0
# 38              Taylor Jenkins Reid  Paperback    4.24      903885.0
# 39                      Amir Levine  Paperback    4.15       60364.0
# 40                  Shefali Tsabary   Hardback    4.50           2.0
# 41                  Daniel Kahneman  Paperback    4.18      442455.0
# 42               Dr Shefali Tsabary  Paperback     NaN           NaN
# 43                  Cassandra Clare   Hardback    4.45         818.0
# 44                        Ana Huang  Paperback    4.29      115952.0
# 45                  Oliver Burkeman  Paperback    4.25       44744.0
# 46                        Ana Huang  Paperback    4.10      139388.0
# 47                      Donna Tartt  Paperback    4.17      546145.0
# 48              Richard C. Schwartz  Paperback    4.23        2780.0
# 49               Rou Bao Bu Chi Rou  Paperback    4.67         609.0
# 50                Mo Xiang Tong Xiu  Paperback    4.81        3933.0
# 51                Mo Xiang Tong Xiu  Paperback    4.76        2256.0
# 52                      Delia Owens  Paperback    4.42     2380120.0
# 53                  Fredrik Backman  Paperback    4.37      863045.0
# 54                   Whitney Hanson  Paperback    4.53         141.0
# 55                    Roxie Nafousi   Hardback    4.36        2267.0
# 56                   Takehiko Inoue  Paperback    4.60        1341.0
# 57                  Madeline Miller  Paperback    4.37     1100253.0
# 58                        Ana Huang  Paperback    4.11       66971.0
# 59                    Robert Greene  Paperback    4.16        3194.0
#
#                                                imagen
# 0   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 1   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 2   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 3   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 4   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 5   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 6   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 7   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 8   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 9   https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 10  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 11  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 12  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 13  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 14  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 15  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 16  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 17  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 18  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 19  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 20  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 21  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 22  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 23  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 24  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 25  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 26  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 27  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 28  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 29  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 30  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 31  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 32  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 33  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 34  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 35  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 36  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 37  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 38  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 39  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 40  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 41  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 42  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 43  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 44  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 45  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 46  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 47  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 48  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 49  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 50  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 51  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 52  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 53  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 54  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 55  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 56  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 57  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 58  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
# 59  https://d1w7fb2mkkr3kw.cloudfront.net/assets/i...
